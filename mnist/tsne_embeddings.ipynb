# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('tsne_custom.csv')

# %%
data.head()
# Out:
#      embed_x    embed_y  labels  time_to_change
# 0  -1.817682  69.548320     0.0              -1
# 1 -20.782250  64.064606     0.0              -1
# 2 -26.811735  56.403230     0.0              -1
# 3 -26.056710  56.344627     0.0              -1
# 4 -29.481955  55.864655     0.0              -1

# %%
plt.figure(figsize=(10, 10))
plt.plot(data.loc[data['time_to_change'] == -1, 'embed_x'], 
         data.loc[data['time_to_change'] == -1, 'embed_y'], 'o', alpha=0.5, markersize=3, label='Normal data');

plt.plot(data.loc[(data['time_to_change'] > -1) & (data['time_to_change'] < 20), 'embed_x'], 
         data.loc[(data['time_to_change'] > -1) & (data['time_to_change'] < 20), 'embed_y'], 
         's', alpha=0.8, markersize=3, label='Time after change < 20');

plt.plot(data.loc[(data['time_to_change'] > 20) & (data['time_to_change'] < 60), 'embed_x'], 
         data.loc[(data['time_to_change'] > 20) & (data['time_to_change'] < 60), 'embed_y'], 
         'd', alpha=0.5, markersize=3, label='Time after change > 20', c='#bcbd22');

plt.legend(loc='upper right', markerscale=3, fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig('tsne_embeddings_custom.pdf', bbox_inches='tight')

# %%
data = pd.read_csv('tsne_bce.csv')

# %%
plt.figure(figsize=(10, 10))
plt.plot(data.loc[data['time_to_change'] == -1, 'embed_x'], 
         data.loc[data['time_to_change'] == -1, 'embed_y'], 'o', alpha=0.5, markersize=3, label='Normal data');

plt.plot(data.loc[(data['time_to_change'] > -1) & (data['time_to_change'] < 20), 'embed_x'], 
         data.loc[(data['time_to_change'] > -1) & (data['time_to_change'] < 20), 'embed_y'], 
         's', alpha=0.8, markersize=3, label='Time after change < 20');

plt.plot(data.loc[(data['time_to_change'] > 20) & (data['time_to_change'] < 200), 'embed_x'], 
         data.loc[(data['time_to_change'] > 20) & (data['time_to_change'] < 200), 'embed_y'], 
         'd', alpha=0.5, markersize=3, label='Time after change > 20', c='#bcbd22');

plt.legend(loc='upper right', markerscale=3, fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig('tsne_embeddings_bce.pdf', bbox_inches='tight')

# %%
data = pd.read_csv('tsne_combined.csv')

# %%
plt.figure(figsize=(10, 10))
plt.plot(data.loc[data['time_to_change'] == -1, 'embed_x'], 
         data.loc[data['time_to_change'] == -1, 'embed_y'], 'o', alpha=0.5, markersize=3, label='Normal data');

plt.plot(data.loc[(data['time_to_change'] > -1) & (data['time_to_change'] < 20), 'embed_x'], 
         data.loc[(data['time_to_change'] > -1) & (data['time_to_change'] < 20), 'embed_y'], 
         's', alpha=0.8, markersize=3, label='Time after change < 20');

plt.plot(data.loc[(data['time_to_change'] > 20) & (data['time_to_change'] < 200), 'embed_x'], 
         data.loc[(data['time_to_change'] > 20) & (data['time_to_change'] < 200), 'embed_y'], 
         'd', alpha=0.5, markersize=3, label='Time after change > 20', c='#bcbd22');

plt.legend(loc='upper right', markerscale=3, fontsize=24)
plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.savefig('tsne_embeddings_combined.pdf', bbox_inches='tight')

# %%
import torch

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

# %%
df_names = pd.read_csv('data/features.txt', header=None)

# %%
names = df_names[0]

# %%
idxs = []

for i, name in enumerate(names):
    if 'Mean' in name or 'STD' in name:
        idxs.append(i)

# %%
def load_data(path, idxs, type_="train"):
    data_path = path + "/T" + type_[1:] + "/X_" + type_ + ".txt"
    labels_path = path + "/T" + type_[1:] + "/y_" + type_ + ".txt"
    subjects_path = path + "/T" + type_[1:] + "/subject_id_" + type_ + ".txt"
    
    data = pd.read_csv(data_path, sep=" ", header=None)
    labels = pd.read_csv(labels_path, sep=" ", header=None)
    subjects = pd.read_csv(subjects_path, sep=" ", header=None)
    
    data = data[idxs]
    
    data["subject"] = subjects
    data["labels"] = labels
    
    return data

# %%
def find_change(array):
    count_ = 0
    changes = []
    len_ = len(array)
    for i in range(len_):             
        if i < len_-3:
            value_current = array[i]
            value_ahead = array[i+1]

            if value_current!=value_ahead:
                changes.append(i)
    return changes


def find_idx(data):
    subjects = np.unique(data.subject)
    changes_global = np.array([])
    for subject in subjects:
        local = data[data.subject==subject]
        local = local.reset_index(drop=True)

        changes_ = find_change(local.labels)
        changes_ = np.append([0], changes_)
        start = 0
        len_ = len(changes_)
        changes_local = np.array([])
        while True:
            changes_local = np.append(changes_local, changes_[start:start+4])
            start += 2
            if start > len_-4:
                break
        changes_global = np.append(changes_global, changes_local)       
    return changes_global


def prepare_idx(changes_global):
    max_len = 20
    
    changes_global = changes_global.reshape(changes_global.shape[0]//4, 4)
    changes_global[:, 0] += 1
    changes_global[0, 0] -= 1
    
    changes_global_final = []   

    for i, change in enumerate(changes_global):
        len_ = change[3] - change[0]
        diff = len_ - max_len
        if diff > 0:
            if ((changes_global[i][1]-changes_global[i][0])<max_len) and (changes_global[i][1]-changes_global[i][0])>0:
                changes_global_final.append([changes_global[i][0], changes_global[i][1], changes_global[i][2], changes_global[i][0] + max_len])
            #else:
            #    changes_global_final.append([changes_global[i][0], changes_global[i][0] + max_len, changes_global[i][0] + max_len, changes_global[i][0] + max_len])

    return changes_global_final


def prepare_data(data, changes_global_final):
    max_len = int(changes_global_final[0][3] - changes_global_final[0][0])
    train_set = torch.tensor([])

    for i, change in enumerate(changes_global_final):
        start, end = int(change[0]), int(change[3])
        element = data[start:end].to_numpy()[:, :len(idxs)]
        if len(train_set) == 0:
            train_set = torch.tensor(element)
        else:
            train_set = torch.cat([train_set, torch.tensor(element)])
            
    train_set = train_set.reshape(len(train_set)//max_len, max_len, len(idxs))
    return train_set


def prepare_labels(changes_global_final):
    labels = []
    max_len = int(changes_global_final[0][3] - changes_global_final[0][0])
    
    for change in changes_global_final:
        position = int(change[2]-change[0])
        if position < max_len:
            labels_local = np.append(np.zeros(position), np.ones(max_len-position))
            labels.append(labels_local)
    return torch.tensor(labels, dtype=torch.int)

def preprocess(data):
    changes_global = find_idx(data)
    changes_global_final = prepare_idx(changes_global)
    set_ = prepare_data(data, changes_global_final)
    labels = prepare_labels(changes_global_final)
    return set_, labels

# %%
# %%time

data_train = load_data("./data", idxs, type_="train")
train_features, train_labels = preprocess(data_train)

data_test = load_data("./data/", idxs, type_="test")
test_features, test_labels = preprocess(data_test)
# Out:
# CPU times: user 2.78 s, sys: 12 ms, total: 2.8 s
# Wall time: 1.24 s

# %%
import numpy as np
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

from scipy.stats import norm
from sklearn.model_selection import train_test_split
from tqdm.notebook import tqdm
from sklearn.metrics import average_precision_score

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
torch.manual_seed(1);

# %%
import os
SEQ_LEN = 20
IM_SIZE = len(idxs)

# %%
all_data = np.vstack((train_features, test_features))
all_labels = np.vstack((train_labels, test_labels))

# %%
all_data.shape
# Out:
# (319, 20, 79)

# %%
train_data, val_data, train_labels, val_labels = train_test_split(all_data, all_labels, 
                                                                    test_size=0.2, shuffle=True,
                                                                    random_state=42)

test_data = val_data
test_labels = val_labels
#test_data, val_data, test_labels, val_labels = train_test_split(test_data, test_labels, 
#                                                                test_size=0.5, shuffle=True,
#                                                                random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-483-6866ce951df8> in <module>
#       1 train_data, val_data, train_labels, val_labels = train_test_split(all_data, all_labels,
#       2                                                                     test_size=0.2, shuffle=True,
# ----> 3                                                                     random_state=42)
#       4
#       5 test_data = val_data
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/model_selection/_split.py in train_test_split(*arrays, **options)
#    2125         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2126
# -> 2127     arrays = indexable(*arrays)
#    2128
#    2129     n_samples = _num_samples(arrays[0])
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     290     """
#     291     result = [_make_indexable(X) for X in iterables]
# --> 292     check_consistent_length(*result)
#     293     return result
#     294
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     254     if len(uniques) > 1:
#     255         raise ValueError("Found input variables with inconsistent numbers of"
# --> 256                          " samples: %r" % [int(l) for l in lengths])
#     257
#     258
#
# ValueError: Found input variables with inconsistent numbers of samples: [319, 245]

# %%
print(train_data.shape)
print(val_data.shape)
print(test_data.shape)
# Out:
# (255, 20, 79)
# (64, 20, 79)
# (64, 20, 79)

# %%
# !nvidia-smi
# Out:
# Thu May 27 18:28:00 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.80.02    Driver Version: 450.80.02    CUDA Version: 11.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce GTX 108...  Off  | 00000000:01:00.0 Off |                  N/A |
# | 23%   30C    P8     8W / 250W |   5270MiB / 11177MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce GTX 108...  Off  | 00000000:02:00.0 Off |                  N/A |
# | 29%   51C    P2    56W / 250W |   1736MiB / 11178MiB |     23%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1464      G   /usr/lib/xorg/Xorg                 18MiB |
# |    0   N/A  N/A      5948      C   ...kova/anaconda3/bin/python      757MiB |
# |    0   N/A  N/A     21289      C   ...eva/miniconda3/bin/python      687MiB |
# |    0   N/A  N/A     29625      C   ...kova/anaconda3/bin/python     3801MiB |
# |    1   N/A  N/A      5730      C   ...kova/anaconda3/bin/python      815MiB |
# |    1   N/A  N/A      5948      C   ...kova/anaconda3/bin/python      917MiB |
# +-----------------------------------------------------------------------------+

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
device = torch.device('cuda:0')

# %%
def loss_delay_detection_2(p_slice):
    n = p_slice.size(0)
    prod = torch.ones(n).to(device)
    p_slice = p_slice.to(device)
    prod[1:] -= p_slice[:-1]
    cumprod = torch.cumprod(prod, dim=0).to(device)
    loss = torch.arange(1, n + 1).to(device) * p_slice * cumprod
    loss = torch.sum(loss)
    return loss


def loss_delay_detection(p_slice, w):
    n = p_slice.size(0) 
    prod = torch.ones(n).to(device)
    p_slice = p_slice.to(device)
    
    prod[1:] -= p_slice[:-1].to(device)
    cumprod = torch.cumprod(prod, dim=0).to(device)
    # TODO drop either n or w
    loss = (torch.arange(1, n + 1).to(device) * p_slice * cumprod 
            + (w + 1) * torch.prod(prod[1:]) * (1 - p_slice[-1]))
    loss = torch.sum(loss)
    return loss

def loss_false_alarms(p_slice):
    length = len(p_slice)
    loss = 0
    
    start_ind = 0
    end_ind = 0

    #mb it should be recommented
    
    #while end_ind < length:
    #    start_ind = end_ind - 1
    #    if start_ind < 0:
    #        start_ind = 0
    #    end_ind = np.random.randint(start_ind, length + 2)
    #    if end_ind == start_ind:
    #        end_ind = end_ind + 1
    #    loss += 1 - loss_delay_detection_2(p_slice[start_ind: end_ind + 1])

    loss += 1 - loss_delay_detection_2(p_slice[start_ind: length])            
    #loss = torch.sum(loss)
    return loss

# %%
class CustomLoss(nn.Module):
    
    def __init__(self):
        super(CustomLoss, self).__init__()
        
    def forward(self, outputs, labels):
        loss = torch.zeros(labels.size(0))
        for i, label in enumerate(labels):
            ind = torch.where(label != label[0])[0]
            if ind.size()[0] == 0:
                loss[i] = loss_false_alarms(outputs[i, :])
            else:
                w = 16
                alpha = 0.5
                loss[i] = (alpha * loss_delay_detection(outputs[i, ind[0]:(ind[0] + w)], w) + 
                           (1 - alpha) * loss_false_alarms(outputs[i, :ind[0]]))
        loss = torch.mean(loss)
        return loss

# %%
# input data parameters
input_size = len(idxs)
output_size = SEQ_LEN
seq_len = SEQ_LEN

# model hyperparameters
hidden_dim = 8
n_layers = 1
num_workers = 1
learning_rate = 1e-4

batch_size = 16

# %%
def prepare_loader(data, labels, seq_len, input_size, batch_size, shuffle=True, num_workers=1):
    data = torch.FloatTensor(data)
    labels = torch.FloatTensor(labels)
    data = data.view(-1, seq_len, input_size)
    labels = labels.view(-1, seq_len)

    all_data = TensorDataset(data, labels) 
    data_loader = DataLoader(all_data, batch_size=batch_size, shuffle=shuffle, num_workers=num_workers)
    
    return data_loader

# %%
train_loader = prepare_loader(train_data, train_labels, seq_len, input_size, batch_size, shuffle=True)
val_loader = prepare_loader(val_data, val_labels, seq_len, input_size, batch_size, shuffle=False)
test_loader = prepare_loader(test_data, test_labels, seq_len, input_size, batch_size, shuffle=False)

# %%
def train_model(model, loss_function, epochs=100, print_every=30, LSTM_flag=False, RNN_flag=False):
    optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
    valid_loss_min = np.Inf

    loss_list = []
    acc_list = []
    overall_val_loss_list = []
    counter = 0
    model.train()

    out_list = []
    labels_list = []

    model.train()
    for i in range(epochs):
        # for inputs, labels in tqdm(train_loader):
        for inputs, labels in train_loader:
            if inputs.shape[0] < batch_size:
                break

            counter += 1
            inputs, labels = inputs.to(device), labels.to(device)  

            if LSTM_flag:
                h = model.init_hidden(batch_size)
                h = tuple([e.data for e in h])
                output, h = model(inputs, h)
            elif RNN_flag:
                h = model.init_hidden(batch_size)
                h = torch.stack([e.data for e in h])
                h = torch.zeros(2, batch_size, hidden_dim).to(device)
                output, h = model(inputs, h)                
            else:
                output = model(inputs)

            loss = loss_function(output.squeeze(), labels.float())
            loss_list += [loss.cpu().clone().detach()]
            accuracy = (output > 0.5).long() == labels
            acc_list += [accuracy.cpu().detach().float().mean()]
            out_list.append(output.cpu().detach().float())
            labels_list.append(labels.cpu().detach().float())

            loss.backward()
            optimizer.step()
            optimizer.zero_grad()

            if counter%print_every == 0:
                val_losses = []
                val_outputs = []
                model.eval()
                for val_inputs, val_labels in val_loader:
                    if val_inputs.shape[0] < batch_size:
                        break
                    val_inputs, val_labels = val_inputs.to(device), val_labels.to(device)

                    if LSTM_flag:
                        val_h = model.init_hidden(batch_size)
                        val_h = tuple([each.data for each in val_h])
                        val_out, val_h = model(val_inputs, val_h)
                    elif RNN_flag:
                        val_h = model.init_hidden(batch_size)
                        val_h = torch.stack([each.data for each in val_h])
                        val_h = torch.zeros(2, batch_size, hidden_dim).to(device)
                        val_out, val_h = model(val_inputs, val_h)
                    else:
                        val_out = model(val_inputs)
                        
                    val_loss = loss_function(val_out.squeeze(), val_labels.float())
                    val_losses.append(val_loss.item())
                    val_outputs += [val_out.cpu().clone().detach()]

                val_outputs_one = torch.cat(val_outputs, 0)

                overall_val_loss_list.append(np.mean(val_losses))

                model.train()
                print("Epoch: {}/{}...".format(i+1, epochs),
                      "Step: {}...".format(counter),
                      "Loss: {:.6f}...".format(loss.item()),
                      "Val Loss: {:.6f}".format(np.mean(val_losses)))
    return model, (loss_list, acc_list, overall_val_loss_list)

# %%
# !rm -rf experiments
# !mkdir experiments

# %% [markdown]
# ### LSTM Model

# %%
class LSTM(nn.Module):
    def __init__(self, input_size, output_size, hidden_dim, n_layers, drop_prob=0.1):
        
        super(LSTM, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim        
        # if batch_first, than shape of lstm_in: [batch_size, seq_len, input_size]
        self.lstm = nn.LSTM(input_size, hidden_dim, n_layers, dropout=drop_prob, batch_first=True)
        self.dropout = nn.Dropout(drop_prob)
        self.linear_1 = nn.Linear(hidden_dim, 1)        
        #self.linear_1 = nn.Linear(hidden_dim, hidden_dim//2)
        #self.linear_2 = nn.Linear(hidden_dim//2, 1)
        self.activation = nn.Sigmoid()
        self.relu = nn.ReLU()
        
    def forward(self, input_seq, hidden):
        batch_size = input_seq.size(0)
        lstm_out, hidden = self.lstm(input_seq, hidden)  
        lstm_out = lstm_out.contiguous().view(-1, self.hidden_dim)   
        out = self.dropout(lstm_out)        
        out = self.linear_1(out)
        #out = self.relu(out)
        #out = self.linear_2(out)
        out = self.activation(out)
        out = out.view(batch_size, -1)

        return out, hidden

    def init_hidden(self, batch_size):
        weight = next(self.parameters()).data
        
        hidden = (weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device),
                  weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device))
        return hidden

# %%
model_LSTM_custom = LSTM(input_size=input_size, output_size=output_size, hidden_dim=hidden_dim, n_layers=n_layers)
loss_function = CustomLoss()
model_LSTM_custom.to(device)
# Out:
# /home/eromanenkova/anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py:63: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# LSTM(
#   (lstm): LSTM(79, 8, batch_first=True, dropout=0.1)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (linear_1): Linear(in_features=8, out_features=1, bias=True)
#   (activation): Sigmoid()
#   (relu): ReLU()
# )

# %% [raw]
# batch, labels = next(iter(val_loader))
# batch = batch.to(device)
#
# hidden = model_LSTM_custom.init_hidden(batch.shape[0])
# hidden = tuple([each.data for each in hidden])

# %% [raw]
# plt.plot(batch[9][:, :10].detach().cpu().numpy());
# plt.vlines(7.5, -0.1, 0.1, color='red')

# %% [raw]
# for i in range(100):
#     model_LSTM_custom, (loss_list, acc_list,
#                         overall_val_loss_list) = train_model(model_LSTM_custom, loss_function, 1, 5, LSTM_flag=True)
#
#     model_LSTM_custom = model_LSTM_custom.eval()
#     #torch.save(model_LSTM_custom, "experiments/model_LSTM_custom.pth")
#
#
#     predictions = model_LSTM_custom(batch, hidden)
#
#     i = 9
#     plt.plot(predictions[0][i].detach().cpu().numpy())
#     plt.plot(labels[i].detach().cpu().numpy())
#     #plt.plot(batch[i][:, 0].detach().cpu().numpy());
#     plt.show()
#
#     i = 5
#     plt.plot(predictions[0][i].detach().cpu().numpy())
#     plt.plot(labels[i].detach().cpu().numpy())
#     #plt.plot(batch[i][:, 0].detach().cpu().numpy());
#     plt.show()

# %%
model_LSTM_custom, (loss_list, acc_list, 
                    overall_val_loss_list) = train_model(model_LSTM_custom, loss_function, 1, 5, LSTM_flag=True)

model_LSTM_custom = model_LSTM_custom.eval() 
torch.save(model_LSTM_custom, "experiments/model_LSTM_custom.pth")

# %%
model_LSTM_bce = LSTM(input_size=input_size, output_size=output_size, hidden_dim=hidden_dim, n_layers=n_layers)
bce_loss_function = torch.nn.BCELoss()
model_LSTM_bce.to(device)
# Out:
# /home/eromanenkova/anaconda3/lib/python3.7/site-packages/torch/nn/modules/rnn.py:63: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
#   "num_layers={}".format(dropout, num_layers))
# LSTM(
#   (lstm): LSTM(79, 8, batch_first=True, dropout=0.1)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (linear_1): Linear(in_features=8, out_features=4, bias=True)
#   (linear_2): Linear(in_features=4, out_features=1, bias=True)
#   (activation): Sigmoid()
#   (relu): ReLU()
# )

# %%
model_LSTM_bce, (bce_loss_list, bce_acc_list, bce_overall_val_loss_list) = train_model(model_LSTM_bce, bce_loss_function, 
                                                                                       60, 5, LSTM_flag=True)
model_LSTM_bce = model_LSTM_bce.eval()
torch.save(model_LSTM_bce, "experiments/model_LSTM_bce.pth")
# Out:
# Epoch: 1/60... Step: 5... Loss: 0.696742... Val Loss: 0.692147
# Epoch: 1/60... Step: 10... Loss: 0.707942... Val Loss: 0.689824
# Epoch: 1/60... Step: 15... Loss: 0.673837... Val Loss: 0.687633
# Epoch: 2/60... Step: 20... Loss: 0.669226... Val Loss: 0.685652
# Epoch: 2/60... Step: 25... Loss: 0.677193... Val Loss: 0.683710
# Epoch: 2/60... Step: 30... Loss: 0.666987... Val Loss: 0.681478
# Epoch: 3/60... Step: 35... Loss: 0.684540... Val Loss: 0.679252
# Epoch: 3/60... Step: 40... Loss: 0.690297... Val Loss: 0.676915
# Epoch: 3/60... Step: 45... Loss: 0.659840... Val Loss: 0.674625
# Epoch: 4/60... Step: 50... Loss: 0.664906... Val Loss: 0.672346
# Epoch: 4/60... Step: 55... Loss: 0.672051... Val Loss: 0.670205
# Epoch: 4/60... Step: 60... Loss: 0.664990... Val Loss: 0.667919
# Epoch: 5/60... Step: 65... Loss: 0.657786... Val Loss: 0.664854
# Epoch: 5/60... Step: 70... Loss: 0.660652... Val Loss: 0.661053
# Epoch: 5/60... Step: 75... Loss: 0.655203... Val Loss: 0.658440
# Epoch: 6/60... Step: 80... Loss: 0.648886... Val Loss: 0.653914
# Epoch: 6/60... Step: 85... Loss: 0.644447... Val Loss: 0.651138
# Epoch: 6/60... Step: 90... Loss: 0.649115... Val Loss: 0.648311
# Epoch: 7/60... Step: 95... Loss: 0.633552... Val Loss: 0.646232
# Epoch: 7/60... Step: 100... Loss: 0.630953... Val Loss: 0.644691
# Epoch: 7/60... Step: 105... Loss: 0.628462... Val Loss: 0.641948
# Epoch: 8/60... Step: 110... Loss: 0.628568... Val Loss: 0.639016
# Epoch: 8/60... Step: 115... Loss: 0.628358... Val Loss: 0.637153
# Epoch: 8/60... Step: 120... Loss: 0.634339... Val Loss: 0.637472
# Epoch: 9/60... Step: 125... Loss: 0.620941... Val Loss: 0.632661
# Epoch: 9/60... Step: 130... Loss: 0.624210... Val Loss: 0.630174
# Epoch: 9/60... Step: 135... Loss: 0.616950... Val Loss: 0.628035
# Epoch: 10/60... Step: 140... Loss: 0.624288... Val Loss: 0.623790
# Epoch: 10/60... Step: 145... Loss: 0.606676... Val Loss: 0.621977
# Epoch: 10/60... Step: 150... Loss: 0.603607... Val Loss: 0.619296
# Epoch: 11/60... Step: 155... Loss: 0.602145... Val Loss: 0.615136
# Epoch: 11/60... Step: 160... Loss: 0.601305... Val Loss: 0.614213
# Epoch: 11/60... Step: 165... Loss: 0.623484... Val Loss: 0.609743
# Epoch: 12/60... Step: 170... Loss: 0.622914... Val Loss: 0.608569
# Epoch: 12/60... Step: 175... Loss: 0.578307... Val Loss: 0.611984
# Epoch: 12/60... Step: 180... Loss: 0.601567... Val Loss: 0.602900
# Epoch: 13/60... Step: 185... Loss: 0.599335... Val Loss: 0.600176
# Epoch: 13/60... Step: 190... Loss: 0.597401... Val Loss: 0.596912
# Epoch: 13/60... Step: 195... Loss: 0.552877... Val Loss: 0.592884
# Epoch: 14/60... Step: 200... Loss: 0.545158... Val Loss: 0.589301
# Epoch: 14/60... Step: 205... Loss: 0.575608... Val Loss: 0.588071
# Epoch: 14/60... Step: 210... Loss: 0.570521... Val Loss: 0.586042
# Epoch: 15/60... Step: 215... Loss: 0.587905... Val Loss: 0.584675
# Epoch: 15/60... Step: 220... Loss: 0.575624... Val Loss: 0.582536
# Epoch: 15/60... Step: 225... Loss: 0.597785... Val Loss: 0.583450
# Epoch: 16/60... Step: 230... Loss: 0.548487... Val Loss: 0.576848
# Epoch: 16/60... Step: 235... Loss: 0.550215... Val Loss: 0.573342
# Epoch: 16/60... Step: 240... Loss: 0.538366... Val Loss: 0.571016
# Epoch: 17/60... Step: 245... Loss: 0.551838... Val Loss: 0.570075
# Epoch: 17/60... Step: 250... Loss: 0.531593... Val Loss: 0.569023
# Epoch: 17/60... Step: 255... Loss: 0.520652... Val Loss: 0.567069
# Epoch: 18/60... Step: 260... Loss: 0.544124... Val Loss: 0.561312
# Epoch: 18/60... Step: 265... Loss: 0.577054... Val Loss: 0.560035
# Epoch: 18/60... Step: 270... Loss: 0.550359... Val Loss: 0.555787
# Epoch: 19/60... Step: 275... Loss: 0.540343... Val Loss: 0.554719
# Epoch: 19/60... Step: 280... Loss: 0.490101... Val Loss: 0.553413
# Epoch: 19/60... Step: 285... Loss: 0.529165... Val Loss: 0.552445
# Epoch: 20/60... Step: 290... Loss: 0.557205... Val Loss: 0.552579
# Epoch: 20/60... Step: 295... Loss: 0.533941... Val Loss: 0.561688
# Epoch: 20/60... Step: 300... Loss: 0.530623... Val Loss: 0.550421
# Epoch: 21/60... Step: 305... Loss: 0.492616... Val Loss: 0.546410
# Epoch: 21/60... Step: 310... Loss: 0.603760... Val Loss: 0.550382
# Epoch: 21/60... Step: 315... Loss: 0.492637... Val Loss: 0.561206
# Epoch: 22/60... Step: 320... Loss: 0.515515... Val Loss: 0.543337
# Epoch: 22/60... Step: 325... Loss: 0.532118... Val Loss: 0.539614
# Epoch: 22/60... Step: 330... Loss: 0.552246... Val Loss: 0.562970
# Epoch: 23/60... Step: 335... Loss: 0.541493... Val Loss: 0.532913
# Epoch: 23/60... Step: 340... Loss: 0.530118... Val Loss: 0.541437
# Epoch: 23/60... Step: 345... Loss: 0.494813... Val Loss: 0.545285
# Epoch: 24/60... Step: 350... Loss: 0.495911... Val Loss: 0.535123
# Epoch: 24/60... Step: 355... Loss: 0.513644... Val Loss: 0.532621
# Epoch: 24/60... Step: 360... Loss: 0.450863... Val Loss: 0.532508
# Epoch: 25/60... Step: 365... Loss: 0.509693... Val Loss: 0.529991
# Epoch: 25/60... Step: 370... Loss: 0.478684... Val Loss: 0.525920
# Epoch: 25/60... Step: 375... Loss: 0.466144... Val Loss: 0.524230
# Epoch: 26/60... Step: 380... Loss: 0.506130... Val Loss: 0.528201
# Epoch: 26/60... Step: 385... Loss: 0.464141... Val Loss: 0.520103
# Epoch: 26/60... Step: 390... Loss: 0.521626... Val Loss: 0.536769
# Epoch: 27/60... Step: 395... Loss: 0.516255... Val Loss: 0.523048
# Epoch: 27/60... Step: 400... Loss: 0.499301... Val Loss: 0.527612
# Epoch: 27/60... Step: 405... Loss: 0.513987... Val Loss: 0.513841
# Epoch: 28/60... Step: 410... Loss: 0.500340... Val Loss: 0.515631
# Epoch: 28/60... Step: 415... Loss: 0.528232... Val Loss: 0.541453
# Epoch: 28/60... Step: 420... Loss: 0.484729... Val Loss: 0.526839
# Epoch: 29/60... Step: 425... Loss: 0.522454... Val Loss: 0.512217
# Epoch: 29/60... Step: 430... Loss: 0.544844... Val Loss: 0.536479
# Epoch: 29/60... Step: 435... Loss: 0.468882... Val Loss: 0.511979
# Epoch: 30/60... Step: 440... Loss: 0.470255... Val Loss: 0.515665
# Epoch: 30/60... Step: 445... Loss: 0.510159... Val Loss: 0.516165
# Epoch: 30/60... Step: 450... Loss: 0.460170... Val Loss: 0.505467
# Epoch: 31/60... Step: 455... Loss: 0.579389... Val Loss: 0.514709
# Epoch: 31/60... Step: 460... Loss: 0.462945... Val Loss: 0.517164
# Epoch: 31/60... Step: 465... Loss: 0.486947... Val Loss: 0.503663
# Epoch: 32/60... Step: 470... Loss: 0.472024... Val Loss: 0.514581
# Epoch: 32/60... Step: 475... Loss: 0.494838... Val Loss: 0.508173
# Epoch: 32/60... Step: 480... Loss: 0.484835... Val Loss: 0.504752
# Epoch: 33/60... Step: 485... Loss: 0.431345... Val Loss: 0.505316
# Epoch: 33/60... Step: 490... Loss: 0.461973... Val Loss: 0.510309
# Epoch: 33/60... Step: 495... Loss: 0.442402... Val Loss: 0.521631
# Epoch: 34/60... Step: 500... Loss: 0.452909... Val Loss: 0.506440
# Epoch: 34/60... Step: 505... Loss: 0.440391... Val Loss: 0.528380
# Epoch: 34/60... Step: 510... Loss: 0.480690... Val Loss: 0.498815
# Epoch: 35/60... Step: 515... Loss: 0.466240... Val Loss: 0.502461
# Epoch: 35/60... Step: 520... Loss: 0.448059... Val Loss: 0.502101
# Epoch: 35/60... Step: 525... Loss: 0.466135... Val Loss: 0.504036
# Epoch: 36/60... Step: 530... Loss: 0.511962... Val Loss: 0.495824
# Epoch: 36/60... Step: 535... Loss: 0.466897... Val Loss: 0.490294
# Epoch: 36/60... Step: 540... Loss: 0.503297... Val Loss: 0.492625
# Epoch: 37/60... Step: 545... Loss: 0.513767... Val Loss: 0.489597
# Epoch: 37/60... Step: 550... Loss: 0.381613... Val Loss: 0.492036
# Epoch: 37/60... Step: 555... Loss: 0.451717... Val Loss: 0.491234
# Epoch: 38/60... Step: 560... Loss: 0.460708... Val Loss: 0.491787
# Epoch: 38/60... Step: 565... Loss: 0.536879... Val Loss: 0.497857
# Epoch: 38/60... Step: 570... Loss: 0.430549... Val Loss: 0.497750
# Epoch: 39/60... Step: 575... Loss: 0.405945... Val Loss: 0.488451
# Epoch: 39/60... Step: 580... Loss: 0.453791... Val Loss: 0.495045
# Epoch: 39/60... Step: 585... Loss: 0.410915... Val Loss: 0.504006
# Epoch: 40/60... Step: 590... Loss: 0.506854... Val Loss: 0.488921
# Epoch: 40/60... Step: 595... Loss: 0.411244... Val Loss: 0.486169
# Epoch: 40/60... Step: 600... Loss: 0.443276... Val Loss: 0.502254
# Epoch: 41/60... Step: 605... Loss: 0.470484... Val Loss: 0.500103
# Epoch: 41/60... Step: 610... Loss: 0.563457... Val Loss: 0.500323
# Epoch: 41/60... Step: 615... Loss: 0.482345... Val Loss: 0.505218
# Epoch: 42/60... Step: 620... Loss: 0.476024... Val Loss: 0.484028
# Epoch: 42/60... Step: 625... Loss: 0.455826... Val Loss: 0.484806
# Epoch: 42/60... Step: 630... Loss: 0.445353... Val Loss: 0.492893
# Epoch: 43/60... Step: 635... Loss: 0.469748... Val Loss: 0.483126
# Epoch: 43/60... Step: 640... Loss: 0.409494... Val Loss: 0.486011
# Epoch: 43/60... Step: 645... Loss: 0.441029... Val Loss: 0.497871
# Epoch: 44/60... Step: 650... Loss: 0.541360... Val Loss: 0.483702
# Epoch: 44/60... Step: 655... Loss: 0.484858... Val Loss: 0.485147
# Epoch: 44/60... Step: 660... Loss: 0.488277... Val Loss: 0.508301
# Epoch: 45/60... Step: 665... Loss: 0.500103... Val Loss: 0.481911
# Epoch: 45/60... Step: 670... Loss: 0.473545... Val Loss: 0.481688
# Epoch: 45/60... Step: 675... Loss: 0.453863... Val Loss: 0.493832
# Epoch: 46/60... Step: 680... Loss: 0.416127... Val Loss: 0.478556
# Epoch: 46/60... Step: 685... Loss: 0.476218... Val Loss: 0.475455
# Epoch: 46/60... Step: 690... Loss: 0.459680... Val Loss: 0.478979
# Epoch: 47/60... Step: 695... Loss: 0.475883... Val Loss: 0.489450
# Epoch: 47/60... Step: 700... Loss: 0.479337... Val Loss: 0.484295
# Epoch: 47/60... Step: 705... Loss: 0.430202... Val Loss: 0.475179
# Epoch: 48/60... Step: 710... Loss: 0.484658... Val Loss: 0.472168
# Epoch: 48/60... Step: 715... Loss: 0.466494... Val Loss: 0.486674
# Epoch: 48/60... Step: 720... Loss: 0.427675... Val Loss: 0.479073
# Epoch: 49/60... Step: 725... Loss: 0.477302... Val Loss: 0.475472
# Epoch: 49/60... Step: 730... Loss: 0.471330... Val Loss: 0.486816
# Epoch: 49/60... Step: 735... Loss: 0.454998... Val Loss: 0.472633
# Epoch: 50/60... Step: 740... Loss: 0.454495... Val Loss: 0.477398
# Epoch: 50/60... Step: 745... Loss: 0.459365... Val Loss: 0.497286
# Epoch: 50/60... Step: 750... Loss: 0.414052... Val Loss: 0.472488
# Epoch: 51/60... Step: 755... Loss: 0.434493... Val Loss: 0.473622
# Epoch: 51/60... Step: 760... Loss: 0.491781... Val Loss: 0.485516
# Epoch: 51/60... Step: 765... Loss: 0.420939... Val Loss: 0.473378
# Epoch: 52/60... Step: 770... Loss: 0.436491... Val Loss: 0.469920
# Epoch: 52/60... Step: 775... Loss: 0.433001... Val Loss: 0.478423
# Epoch: 52/60... Step: 780... Loss: 0.464650... Val Loss: 0.468369
# Epoch: 53/60... Step: 785... Loss: 0.395825... Val Loss: 0.472439
# Epoch: 53/60... Step: 790... Loss: 0.401615... Val Loss: 0.476092
# Epoch: 53/60... Step: 795... Loss: 0.497517... Val Loss: 0.468547
# Epoch: 54/60... Step: 800... Loss: 0.399766... Val Loss: 0.466907
# Epoch: 54/60... Step: 805... Loss: 0.420770... Val Loss: 0.466179
# Epoch: 54/60... Step: 810... Loss: 0.520276... Val Loss: 0.468903
# Epoch: 55/60... Step: 815... Loss: 0.366340... Val Loss: 0.465613
# Epoch: 55/60... Step: 820... Loss: 0.503213... Val Loss: 0.464326
# Epoch: 55/60... Step: 825... Loss: 0.454821... Val Loss: 0.465542
# Epoch: 56/60... Step: 830... Loss: 0.395518... Val Loss: 0.468535
# Epoch: 56/60... Step: 835... Loss: 0.386354... Val Loss: 0.468171
# Epoch: 56/60... Step: 840... Loss: 0.476291... Val Loss: 0.464618
# Epoch: 57/60... Step: 845... Loss: 0.409560... Val Loss: 0.461576
# Epoch: 57/60... Step: 850... Loss: 0.476936... Val Loss: 0.460334
# Epoch: 57/60... Step: 855... Loss: 0.437349... Val Loss: 0.459681
# Epoch: 58/60... Step: 860... Loss: 0.484057... Val Loss: 0.466551
# Epoch: 58/60... Step: 865... Loss: 0.436381... Val Loss: 0.467398
# Epoch: 58/60... Step: 870... Loss: 0.391096... Val Loss: 0.473843
# Epoch: 59/60... Step: 875... Loss: 0.374195... Val Loss: 0.464895
# Epoch: 59/60... Step: 880... Loss: 0.437803... Val Loss: 0.481350
# Epoch: 59/60... Step: 885... Loss: 0.437675... Val Loss: 0.465362
# Epoch: 60/60... Step: 890... Loss: 0.443273... Val Loss: 0.462161
# Epoch: 60/60... Step: 895... Loss: 0.487467... Val Loss: 0.478769
# Epoch: 60/60... Step: 900... Loss: 0.426422... Val Loss: 0.463413

# %%
batch, labels = next(iter(val_loader))
batch = batch.to(device)

hidden = model_LSTM_bce.init_hidden(batch.shape[0])
hidden = tuple([each.data for each in hidden])

predictions = model_LSTM_bce(batch, hidden)

# %%
i = 4
plt.plot(predictions[0][i].detach().cpu().numpy())
plt.plot(labels[i].detach().cpu().numpy())
#plt.plot(batch[i][:, 0].detach().cpu().numpy());

# %%
model_LSTM_combined = LSTM(input_size=input_size, output_size=output_size, hidden_dim=hidden_dim, n_layers=n_layers)
first_bce_loss_function = torch.nn.BCELoss()
second_custom_loss_function = CustomLoss()
model_LSTM_combined.to(device)
# Out:
# LSTM(
#   (lstm): LSTM(561, 8, num_layers=2, batch_first=True, dropout=0.1)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (linear_1): Linear(in_features=8, out_features=4, bias=True)
#   (linear_2): Linear(in_features=4, out_features=1, bias=True)
#   (activation): Sigmoid()
#   (relu): ReLU()
# )

# %%
model_LSTM_combined, _ = train_model(model_LSTM_combined, first_bce_loss_function, 60, 5, 
                                    LSTM_flag=True)

model_LSTM_combined, _ = train_model(model_LSTM_combined, second_custom_loss_function, 60, 5, 
                                    LSTM_flag=True)


model_LSTM_combined = model_LSTM_combined.eval()
torch.save(model_LSTM_combined, "experiments/model_LSTM_combined.pth")
# Out:
# Epoch: 1/60... Step: 5... Loss: 0.726997... Val Loss: 0.737780
# Epoch: 1/60... Step: 10... Loss: 0.700505... Val Loss: 0.736609
# Epoch: 1/60... Step: 15... Loss: 0.743389... Val Loss: 0.735519
# Epoch: 2/60... Step: 20... Loss: 0.711873... Val Loss: 0.734623
# Epoch: 2/60... Step: 25... Loss: 0.696280... Val Loss: 0.733829
# Epoch: 2/60... Step: 30... Loss: 0.740528... Val Loss: 0.732986
# Epoch: 3/60... Step: 35... Loss: 0.716664... Val Loss: 0.732239
# Epoch: 3/60... Step: 40... Loss: 0.738906... Val Loss: 0.731449
# Epoch: 3/60... Step: 45... Loss: 0.718116... Val Loss: 0.730650
# Epoch: 3/60... Step: 50... Loss: 0.709947... Val Loss: 0.730002
# Epoch: 4/60... Step: 55... Loss: 0.706433... Val Loss: 0.729269
# Epoch: 4/60... Step: 60... Loss: 0.701946... Val Loss: 0.728429
# Epoch: 4/60... Step: 65... Loss: 0.739407... Val Loss: 0.727711
# Epoch: 5/60... Step: 70... Loss: 0.717565... Val Loss: 0.726742
# Epoch: 5/60... Step: 75... Loss: 0.725410... Val Loss: 0.725809
# Epoch: 5/60... Step: 80... Loss: 0.739737... Val Loss: 0.724812
# Epoch: 5/60... Step: 85... Loss: 0.725455... Val Loss: 0.723735
# Epoch: 6/60... Step: 90... Loss: 0.696416... Val Loss: 0.722762
# Epoch: 6/60... Step: 95... Loss: 0.697884... Val Loss: 0.721918
# Epoch: 6/60... Step: 100... Loss: 0.708136... Val Loss: 0.720700
# Epoch: 7/60... Step: 105... Loss: 0.717532... Val Loss: 0.719482
# Epoch: 7/60... Step: 110... Loss: 0.709958... Val Loss: 0.717964
# Epoch: 7/60... Step: 115... Loss: 0.719915... Val Loss: 0.717320
# Epoch: 8/60... Step: 120... Loss: 0.701425... Val Loss: 0.715537
# Epoch: 8/60... Step: 125... Loss: 0.712557... Val Loss: 0.714837
# Epoch: 8/60... Step: 130... Loss: 0.681555... Val Loss: 0.712859
# Epoch: 8/60... Step: 135... Loss: 0.651023... Val Loss: 0.711881
# Epoch: 9/60... Step: 140... Loss: 0.699241... Val Loss: 0.710540
# Epoch: 9/60... Step: 145... Loss: 0.712858... Val Loss: 0.710496
# Epoch: 9/60... Step: 150... Loss: 0.698608... Val Loss: 0.706954
# Epoch: 10/60... Step: 155... Loss: 0.661165... Val Loss: 0.704792
# Epoch: 10/60... Step: 160... Loss: 0.643818... Val Loss: 0.704246
# Epoch: 10/60... Step: 165... Loss: 0.695432... Val Loss: 0.702896
# Epoch: 10/60... Step: 170... Loss: 0.703356... Val Loss: 0.702734
# Epoch: 11/60... Step: 175... Loss: 0.638363... Val Loss: 0.699935
# Epoch: 11/60... Step: 180... Loss: 0.642702... Val Loss: 0.699004
# Epoch: 11/60... Step: 185... Loss: 0.675575... Val Loss: 0.697436
# Epoch: 12/60... Step: 190... Loss: 0.629222... Val Loss: 0.693197
# Epoch: 12/60... Step: 195... Loss: 0.722067... Val Loss: 0.691608
# Epoch: 12/60... Step: 200... Loss: 0.654818... Val Loss: 0.691774
# Epoch: 13/60... Step: 205... Loss: 0.608749... Val Loss: 0.687908
# Epoch: 13/60... Step: 210... Loss: 0.700842... Val Loss: 0.687191
# Epoch: 13/60... Step: 215... Loss: 0.687404... Val Loss: 0.685288
# Epoch: 13/60... Step: 220... Loss: 0.657417... Val Loss: 0.683454
# Epoch: 14/60... Step: 225... Loss: 0.613196... Val Loss: 0.681611
# Epoch: 14/60... Step: 230... Loss: 0.631910... Val Loss: 0.678469
# Epoch: 14/60... Step: 235... Loss: 0.621044... Val Loss: 0.679427
# Epoch: 15/60... Step: 240... Loss: 0.626195... Val Loss: 0.668193
# Epoch: 15/60... Step: 245... Loss: 0.615487... Val Loss: 0.663256
# Epoch: 15/60... Step: 250... Loss: 0.583080... Val Loss: 0.654804
# Epoch: 15/60... Step: 255... Loss: 0.600735... Val Loss: 0.649710
# Epoch: 16/60... Step: 260... Loss: 0.562212... Val Loss: 0.651328
# Epoch: 16/60... Step: 265... Loss: 0.625282... Val Loss: 0.641574
# Epoch: 16/60... Step: 270... Loss: 0.594252... Val Loss: 0.628412
# Epoch: 17/60... Step: 275... Loss: 0.747178... Val Loss: 0.621051
# Epoch: 17/60... Step: 280... Loss: 0.570190... Val Loss: 0.621967
# Epoch: 17/60... Step: 285... Loss: 0.539274... Val Loss: 0.600380
# Epoch: 18/60... Step: 290... Loss: 0.553816... Val Loss: 0.604199
# Epoch: 18/60... Step: 295... Loss: 0.509635... Val Loss: 0.591830
# Epoch: 18/60... Step: 300... Loss: 0.522110... Val Loss: 0.590008
# Epoch: 18/60... Step: 305... Loss: 0.444431... Val Loss: 0.584479
# Epoch: 19/60... Step: 310... Loss: 0.526999... Val Loss: 0.581170
# Epoch: 19/60... Step: 315... Loss: 0.542779... Val Loss: 0.568940
# Epoch: 19/60... Step: 320... Loss: 0.493183... Val Loss: 0.565181
# Epoch: 20/60... Step: 325... Loss: 0.474409... Val Loss: 0.562047
# Epoch: 20/60... Step: 330... Loss: 0.414450... Val Loss: 0.569029
# Epoch: 20/60... Step: 335... Loss: 0.571064... Val Loss: 0.561022
# Epoch: 20/60... Step: 340... Loss: 0.578601... Val Loss: 0.572332
# Epoch: 21/60... Step: 345... Loss: 0.447711... Val Loss: 0.553251
# Epoch: 21/60... Step: 350... Loss: 0.488077... Val Loss: 0.548198
# Epoch: 21/60... Step: 355... Loss: 0.457387... Val Loss: 0.554157
# Epoch: 22/60... Step: 360... Loss: 0.482165... Val Loss: 0.554799
# Epoch: 22/60... Step: 365... Loss: 0.424198... Val Loss: 0.546095
# Epoch: 22/60... Step: 370... Loss: 0.425580... Val Loss: 0.548415
# Epoch: 23/60... Step: 375... Loss: 0.466078... Val Loss: 0.546983
# Epoch: 23/60... Step: 380... Loss: 0.390267... Val Loss: 0.549668
# Epoch: 23/60... Step: 385... Loss: 0.497709... Val Loss: 0.555454
# Epoch: 23/60... Step: 390... Loss: 0.490207... Val Loss: 0.551918
# Epoch: 24/60... Step: 395... Loss: 0.479348... Val Loss: 0.545783
# Epoch: 24/60... Step: 400... Loss: 0.422946... Val Loss: 0.553773
# Epoch: 24/60... Step: 405... Loss: 0.424517... Val Loss: 0.561174
# Epoch: 25/60... Step: 410... Loss: 0.500070... Val Loss: 0.561725
# Epoch: 25/60... Step: 415... Loss: 0.470774... Val Loss: 0.564472
# Epoch: 25/60... Step: 420... Loss: 0.396917... Val Loss: 0.565678
# Epoch: 25/60... Step: 425... Loss: 0.543761... Val Loss: 0.553205
# Epoch: 26/60... Step: 430... Loss: 0.377655... Val Loss: 0.552115
# Epoch: 26/60... Step: 435... Loss: 0.412055... Val Loss: 0.550723
# Epoch: 26/60... Step: 440... Loss: 0.439766... Val Loss: 0.558888
# Epoch: 27/60... Step: 445... Loss: 0.479735... Val Loss: 0.560349
# Epoch: 27/60... Step: 450... Loss: 0.491785... Val Loss: 0.557676
# Epoch: 27/60... Step: 455... Loss: 0.457978... Val Loss: 0.554687
# Epoch: 28/60... Step: 460... Loss: 0.366381... Val Loss: 0.559032
# Epoch: 28/60... Step: 465... Loss: 0.403399... Val Loss: 0.571397
# Epoch: 28/60... Step: 470... Loss: 0.501877... Val Loss: 0.568526
# Epoch: 28/60... Step: 475... Loss: 0.432022... Val Loss: 0.568892
# Epoch: 29/60... Step: 480... Loss: 0.351828... Val Loss: 0.560994
# Epoch: 29/60... Step: 485... Loss: 0.527652... Val Loss: 0.555256
# Epoch: 29/60... Step: 490... Loss: 0.365427... Val Loss: 0.558514
# Epoch: 30/60... Step: 495... Loss: 0.477124... Val Loss: 0.574963
# Epoch: 30/60... Step: 500... Loss: 0.470943... Val Loss: 0.568074
# Epoch: 30/60... Step: 505... Loss: 0.450207... Val Loss: 0.571585
# Epoch: 30/60... Step: 510... Loss: 0.485494... Val Loss: 0.554946
# Epoch: 31/60... Step: 515... Loss: 0.533825... Val Loss: 0.560776
# Epoch: 31/60... Step: 520... Loss: 0.418214... Val Loss: 0.561337
# Epoch: 31/60... Step: 525... Loss: 0.362123... Val Loss: 0.570566
# Epoch: 32/60... Step: 530... Loss: 0.478514... Val Loss: 0.560892
# Epoch: 32/60... Step: 535... Loss: 0.355658... Val Loss: 0.556630
# Epoch: 32/60... Step: 540... Loss: 0.420814... Val Loss: 0.561736
# Epoch: 33/60... Step: 545... Loss: 0.317624... Val Loss: 0.565727
# Epoch: 33/60... Step: 550... Loss: 0.435379... Val Loss: 0.562484
# Epoch: 33/60... Step: 555... Loss: 0.304042... Val Loss: 0.566324
# Epoch: 33/60... Step: 560... Loss: 0.373489... Val Loss: 0.574390
# Epoch: 34/60... Step: 565... Loss: 0.504962... Val Loss: 0.568356
# Epoch: 34/60... Step: 570... Loss: 0.473841... Val Loss: 0.564187
# Epoch: 34/60... Step: 575... Loss: 0.569122... Val Loss: 0.557727
# Epoch: 35/60... Step: 580... Loss: 0.408878... Val Loss: 0.554168
# Epoch: 35/60... Step: 585... Loss: 0.407818... Val Loss: 0.553708
# Epoch: 35/60... Step: 590... Loss: 0.480393... Val Loss: 0.565303
# Epoch: 35/60... Step: 595... Loss: 0.416938... Val Loss: 0.570070
# Epoch: 36/60... Step: 600... Loss: 0.377293... Val Loss: 0.564745
# Epoch: 36/60... Step: 605... Loss: 0.442179... Val Loss: 0.562357
# Epoch: 36/60... Step: 610... Loss: 0.485946... Val Loss: 0.550857
# Epoch: 37/60... Step: 615... Loss: 0.505431... Val Loss: 0.554104
# Epoch: 37/60... Step: 620... Loss: 0.469540... Val Loss: 0.561497
# Epoch: 37/60... Step: 625... Loss: 0.327402... Val Loss: 0.548001
# Epoch: 38/60... Step: 630... Loss: 0.350926... Val Loss: 0.569157
# Epoch: 38/60... Step: 635... Loss: 0.437119... Val Loss: 0.554616
# Epoch: 38/60... Step: 640... Loss: 0.393537... Val Loss: 0.562972
# Epoch: 38/60... Step: 645... Loss: 0.446532... Val Loss: 0.571388
# Epoch: 39/60... Step: 650... Loss: 0.425698... Val Loss: 0.559936
# Epoch: 39/60... Step: 655... Loss: 0.399320... Val Loss: 0.555321
# Epoch: 39/60... Step: 660... Loss: 0.424334... Val Loss: 0.555298
# Epoch: 40/60... Step: 665... Loss: 0.410949... Val Loss: 0.563201
# Epoch: 40/60... Step: 670... Loss: 0.367899... Val Loss: 0.564583
# Epoch: 40/60... Step: 675... Loss: 0.338121... Val Loss: 0.574098
# Epoch: 40/60... Step: 680... Loss: 0.439067... Val Loss: 0.555223
# Epoch: 41/60... Step: 685... Loss: 0.434868... Val Loss: 0.561151
# Epoch: 41/60... Step: 690... Loss: 0.405513... Val Loss: 0.544106
# Epoch: 41/60... Step: 695... Loss: 0.362861... Val Loss: 0.545221
# Epoch: 42/60... Step: 700... Loss: 0.361601... Val Loss: 0.557778
# Epoch: 42/60... Step: 705... Loss: 0.334678... Val Loss: 0.551801
# Epoch: 42/60... Step: 710... Loss: 0.433523... Val Loss: 0.549190
# Epoch: 43/60... Step: 715... Loss: 0.354656... Val Loss: 0.550203
# Epoch: 43/60... Step: 720... Loss: 0.346367... Val Loss: 0.556961
# Epoch: 43/60... Step: 725... Loss: 0.381076... Val Loss: 0.559262
# Epoch: 43/60... Step: 730... Loss: 0.408561... Val Loss: 0.548055
# Epoch: 44/60... Step: 735... Loss: 0.274887... Val Loss: 0.556290
# Epoch: 44/60... Step: 740... Loss: 0.379802... Val Loss: 0.559871
# Epoch: 44/60... Step: 745... Loss: 0.506203... Val Loss: 0.542673
# Epoch: 45/60... Step: 750... Loss: 0.461936... Val Loss: 0.536504
# Epoch: 45/60... Step: 755... Loss: 0.370794... Val Loss: 0.550083
# Epoch: 45/60... Step: 760... Loss: 0.418901... Val Loss: 0.550217
# Epoch: 45/60... Step: 765... Loss: 0.427224... Val Loss: 0.565010
# Epoch: 46/60... Step: 770... Loss: 0.386208... Val Loss: 0.577468
# Epoch: 46/60... Step: 775... Loss: 0.365120... Val Loss: 0.550801
# Epoch: 46/60... Step: 780... Loss: 0.406426... Val Loss: 0.553868
# Epoch: 47/60... Step: 785... Loss: 0.339354... Val Loss: 0.552222
# Epoch: 47/60... Step: 790... Loss: 0.562445... Val Loss: 0.552950
# Epoch: 47/60... Step: 795... Loss: 0.420190... Val Loss: 0.552456
# Epoch: 48/60... Step: 800... Loss: 0.386549... Val Loss: 0.559899
# Epoch: 48/60... Step: 805... Loss: 0.374595... Val Loss: 0.572556
# Epoch: 48/60... Step: 810... Loss: 0.366537... Val Loss: 0.556202
# Epoch: 48/60... Step: 815... Loss: 0.350183... Val Loss: 0.546449
# Epoch: 49/60... Step: 820... Loss: 0.389989... Val Loss: 0.548425
# Epoch: 49/60... Step: 825... Loss: 0.401661... Val Loss: 0.552122
# Epoch: 49/60... Step: 830... Loss: 0.410651... Val Loss: 0.555599
# Epoch: 50/60... Step: 835... Loss: 0.409058... Val Loss: 0.561447
# Epoch: 50/60... Step: 840... Loss: 0.441136... Val Loss: 0.560724
# Epoch: 50/60... Step: 845... Loss: 0.411544... Val Loss: 0.548864
# Epoch: 50/60... Step: 850... Loss: 0.488974... Val Loss: 0.555502
# Epoch: 51/60... Step: 855... Loss: 0.481344... Val Loss: 0.554725
# Epoch: 51/60... Step: 860... Loss: 0.400874... Val Loss: 0.565001
# Epoch: 51/60... Step: 865... Loss: 0.538039... Val Loss: 0.556395
# Epoch: 52/60... Step: 870... Loss: 0.349120... Val Loss: 0.551959
# Epoch: 52/60... Step: 875... Loss: 0.355942... Val Loss: 0.549630
# Epoch: 52/60... Step: 880... Loss: 0.405294... Val Loss: 0.551976
# Epoch: 53/60... Step: 885... Loss: 0.422385... Val Loss: 0.547009
# Epoch: 53/60... Step: 890... Loss: 0.381696... Val Loss: 0.542495
# Epoch: 53/60... Step: 895... Loss: 0.321941... Val Loss: 0.541204
# Epoch: 53/60... Step: 900... Loss: 0.335568... Val Loss: 0.546713
# Epoch: 54/60... Step: 905... Loss: 0.350610... Val Loss: 0.551875
# Epoch: 54/60... Step: 910... Loss: 0.346575... Val Loss: 0.543468
# Epoch: 54/60... Step: 915... Loss: 0.505312... Val Loss: 0.541268
# Epoch: 55/60... Step: 920... Loss: 0.522890... Val Loss: 0.543380
# Epoch: 55/60... Step: 925... Loss: 0.449699... Val Loss: 0.547462
# Epoch: 55/60... Step: 930... Loss: 0.334688... Val Loss: 0.548737
# Epoch: 55/60... Step: 935... Loss: 0.429160... Val Loss: 0.560960
# Epoch: 56/60... Step: 940... Loss: 0.361996... Val Loss: 0.565795
# Epoch: 56/60... Step: 945... Loss: 0.353898... Val Loss: 0.566655
# Epoch: 56/60... Step: 950... Loss: 0.326354... Val Loss: 0.568448
# Epoch: 57/60... Step: 955... Loss: 0.339694... Val Loss: 0.565903
# Epoch: 57/60... Step: 960... Loss: 0.450790... Val Loss: 0.544923
# Epoch: 57/60... Step: 965... Loss: 0.406074... Val Loss: 0.541690
# Epoch: 58/60... Step: 970... Loss: 0.298838... Val Loss: 0.536606
# Epoch: 58/60... Step: 975... Loss: 0.370023... Val Loss: 0.535378
# Epoch: 58/60... Step: 980... Loss: 0.417851... Val Loss: 0.547093
# Epoch: 58/60... Step: 985... Loss: 0.402694... Val Loss: 0.547729
# Epoch: 59/60... Step: 990... Loss: 0.361464... Val Loss: 0.552033
# Epoch: 59/60... Step: 995... Loss: 0.424793... Val Loss: 0.552849
# Epoch: 59/60... Step: 1000... Loss: 0.504572... Val Loss: 0.537971
# Epoch: 60/60... Step: 1005... Loss: 0.356237... Val Loss: 0.535191
# Epoch: 60/60... Step: 1010... Loss: 0.381865... Val Loss: 0.532435
# Epoch: 60/60... Step: 1015... Loss: 0.320771... Val Loss: 0.544807
# Epoch: 60/60... Step: 1020... Loss: 0.310150... Val Loss: 0.539878
# Epoch: 1/60... Step: 5... Loss: -1.325351... Val Loss: -0.566350
# Epoch: 1/60... Step: 10... Loss: -0.604302... Val Loss: -0.513588
# Epoch: 1/60... Step: 15... Loss: -0.717926... Val Loss: -0.596879
# Epoch: 2/60... Step: 20... Loss: -1.293450... Val Loss: -0.558276
# Epoch: 2/60... Step: 25... Loss: -0.044674... Val Loss: -0.677096
# Epoch: 2/60... Step: 30... Loss: -0.928006... Val Loss: -0.523579
# Epoch: 3/60... Step: 35... Loss: -1.029849... Val Loss: -0.638370
# Epoch: 3/60... Step: 40... Loss: -1.195664... Val Loss: -0.566502
# Epoch: 3/60... Step: 45... Loss: -1.068925... Val Loss: -0.655304
# Epoch: 3/60... Step: 50... Loss: -1.170792... Val Loss: -0.826225
# Epoch: 4/60... Step: 55... Loss: -1.604887... Val Loss: -0.688574
# Epoch: 4/60... Step: 60... Loss: -1.222587... Val Loss: -0.780727
# Epoch: 4/60... Step: 65... Loss: -1.535864... Val Loss: -0.773871
# Epoch: 5/60... Step: 70... Loss: -1.200544... Val Loss: -0.945940
# Epoch: 5/60... Step: 75... Loss: -0.895854... Val Loss: -0.719053
# Epoch: 5/60... Step: 80... Loss: -1.300828... Val Loss: -0.744503
# Epoch: 5/60... Step: 85... Loss: -1.234702... Val Loss: -0.779717
# Epoch: 6/60... Step: 90... Loss: -0.939390... Val Loss: -0.920076
# Epoch: 6/60... Step: 95... Loss: -2.177843... Val Loss: -0.925523
# Epoch: 6/60... Step: 100... Loss: -0.904364... Val Loss: -0.845159
# Epoch: 7/60... Step: 105... Loss: -1.363954... Val Loss: -0.920591
# Epoch: 7/60... Step: 110... Loss: -0.581694... Val Loss: -0.867889
# Epoch: 7/60... Step: 115... Loss: -1.160752... Val Loss: -0.763672
# Epoch: 8/60... Step: 120... Loss: -1.656041... Val Loss: -0.850206
# Epoch: 8/60... Step: 125... Loss: -0.850446... Val Loss: -0.815205
# Epoch: 8/60... Step: 130... Loss: -1.756712... Val Loss: -0.867987
# Epoch: 8/60... Step: 135... Loss: -1.279030... Val Loss: -0.820585
# Epoch: 9/60... Step: 140... Loss: -0.864780... Val Loss: -0.964512
# Epoch: 9/60... Step: 145... Loss: -1.146745... Val Loss: -0.826674
# Epoch: 9/60... Step: 150... Loss: -1.485609... Val Loss: -0.796079
# Epoch: 10/60... Step: 155... Loss: -1.004614... Val Loss: -1.081345
# Epoch: 10/60... Step: 160... Loss: -1.476131... Val Loss: -1.158808
# Epoch: 10/60... Step: 165... Loss: -0.432895... Val Loss: -0.877487
# Epoch: 10/60... Step: 170... Loss: -1.605905... Val Loss: -1.024918
# Epoch: 11/60... Step: 175... Loss: -1.787023... Val Loss: -0.959440
# Epoch: 11/60... Step: 180... Loss: -2.061580... Val Loss: -0.976916
# Epoch: 11/60... Step: 185... Loss: -1.475024... Val Loss: -0.986477
# Epoch: 12/60... Step: 190... Loss: -0.954527... Val Loss: -0.887932
# Epoch: 12/60... Step: 195... Loss: -1.900527... Val Loss: -0.948702
# Epoch: 12/60... Step: 200... Loss: -1.166952... Val Loss: -0.717702
# Epoch: 13/60... Step: 205... Loss: -1.487614... Val Loss: -0.913237
# Epoch: 13/60... Step: 210... Loss: -1.475733... Val Loss: -0.960036
# Epoch: 13/60... Step: 215... Loss: -0.871695... Val Loss: -0.913936
# Epoch: 13/60... Step: 220... Loss: -0.679098... Val Loss: -1.103812
# Epoch: 14/60... Step: 225... Loss: -2.227445... Val Loss: -0.868500
# Epoch: 14/60... Step: 230... Loss: -1.702636... Val Loss: -0.930031
# Epoch: 14/60... Step: 235... Loss: -1.596745... Val Loss: -0.861314
# Epoch: 15/60... Step: 240... Loss: -1.326059... Val Loss: -1.079154
# Epoch: 15/60... Step: 245... Loss: -0.861377... Val Loss: -0.889374
# Epoch: 15/60... Step: 250... Loss: -1.492373... Val Loss: -0.946665
# Epoch: 15/60... Step: 255... Loss: -1.679897... Val Loss: -0.854053
# Epoch: 16/60... Step: 260... Loss: -1.703916... Val Loss: -1.098296
# Epoch: 16/60... Step: 265... Loss: -1.846948... Val Loss: -0.815257
# Epoch: 16/60... Step: 270... Loss: -1.940768... Val Loss: -1.012921
# Epoch: 17/60... Step: 275... Loss: -1.230511... Val Loss: -1.001413
# Epoch: 17/60... Step: 280... Loss: -1.408413... Val Loss: -1.171931
# Epoch: 17/60... Step: 285... Loss: -2.926049... Val Loss: -1.182213
# Epoch: 18/60... Step: 290... Loss: -1.595781... Val Loss: -0.978196
# Epoch: 18/60... Step: 295... Loss: -1.531829... Val Loss: -1.202602
# Epoch: 18/60... Step: 300... Loss: -1.264874... Val Loss: -0.843932
# Epoch: 18/60... Step: 305... Loss: -1.787232... Val Loss: -1.095484
# Epoch: 19/60... Step: 310... Loss: -1.861410... Val Loss: -1.050593
# Epoch: 19/60... Step: 315... Loss: -2.851180... Val Loss: -1.277947
# Epoch: 19/60... Step: 320... Loss: -1.442675... Val Loss: -0.900959
# Epoch: 20/60... Step: 325... Loss: -0.462370... Val Loss: -1.197059
# Epoch: 20/60... Step: 330... Loss: -1.941066... Val Loss: -1.242716
# Epoch: 20/60... Step: 335... Loss: -1.863138... Val Loss: -1.282371
# Epoch: 20/60... Step: 340... Loss: -1.793482... Val Loss: -0.839447
# Epoch: 21/60... Step: 345... Loss: -1.097423... Val Loss: -0.864309
# Epoch: 21/60... Step: 350... Loss: -2.088827... Val Loss: -1.169560
# Epoch: 21/60... Step: 355... Loss: -0.850358... Val Loss: -0.985770
# Epoch: 22/60... Step: 360... Loss: -1.057173... Val Loss: -1.079816
# Epoch: 22/60... Step: 365... Loss: -2.174430... Val Loss: -1.022332
# Epoch: 22/60... Step: 370... Loss: -1.785182... Val Loss: -1.111156
# Epoch: 23/60... Step: 375... Loss: -1.122809... Val Loss: -1.082213
# Epoch: 23/60... Step: 380... Loss: -1.581302... Val Loss: -1.234269
# Epoch: 23/60... Step: 385... Loss: -1.334743... Val Loss: -0.944742
# Epoch: 23/60... Step: 390... Loss: -0.649969... Val Loss: -1.331854
# Epoch: 24/60... Step: 395... Loss: -1.057228... Val Loss: -1.200918
# Epoch: 24/60... Step: 400... Loss: -0.621501... Val Loss: -1.231842
# Epoch: 24/60... Step: 405... Loss: -1.113223... Val Loss: -1.102204
# Epoch: 25/60... Step: 410... Loss: -1.847732... Val Loss: -1.140533
# Epoch: 25/60... Step: 415... Loss: -1.398821... Val Loss: -0.916375
# Epoch: 25/60... Step: 420... Loss: -1.807530... Val Loss: -1.211933
# Epoch: 25/60... Step: 425... Loss: -1.048423... Val Loss: -1.263081
# Epoch: 26/60... Step: 430... Loss: -1.063425... Val Loss: -1.228902
# Epoch: 26/60... Step: 435... Loss: -1.338365... Val Loss: -1.190755
# Epoch: 26/60... Step: 440... Loss: -1.544296... Val Loss: -0.865321
# Epoch: 27/60... Step: 445... Loss: -2.413647... Val Loss: -1.149013
# Epoch: 27/60... Step: 450... Loss: -2.095351... Val Loss: -1.183679
# Epoch: 27/60... Step: 455... Loss: -1.995942... Val Loss: -1.064042
# Epoch: 28/60... Step: 460... Loss: -2.168778... Val Loss: -0.918909
# Epoch: 28/60... Step: 465... Loss: -1.681868... Val Loss: -1.033238
# Epoch: 28/60... Step: 470... Loss: -1.380803... Val Loss: -1.291032
# Epoch: 28/60... Step: 475... Loss: -1.792384... Val Loss: -0.908988
# Epoch: 29/60... Step: 480... Loss: -1.123078... Val Loss: -1.427261
# Epoch: 29/60... Step: 485... Loss: -1.620341... Val Loss: -1.073986
# Epoch: 29/60... Step: 490... Loss: -0.788793... Val Loss: -0.944833
# Epoch: 30/60... Step: 495... Loss: -1.211467... Val Loss: -1.129088
# Epoch: 30/60... Step: 500... Loss: -1.061190... Val Loss: -0.727937
# Epoch: 30/60... Step: 505... Loss: -1.860319... Val Loss: -1.098753
# Epoch: 30/60... Step: 510... Loss: -0.806562... Val Loss: -1.261381
# Epoch: 31/60... Step: 515... Loss: -0.941831... Val Loss: -1.326635
# Epoch: 31/60... Step: 520... Loss: -0.557658... Val Loss: -1.059743
# Epoch: 31/60... Step: 525... Loss: -2.340281... Val Loss: -0.726679
# Epoch: 32/60... Step: 530... Loss: -1.268010... Val Loss: -1.325547
# Epoch: 32/60... Step: 535... Loss: -1.647182... Val Loss: -0.978566
# Epoch: 32/60... Step: 540... Loss: -1.976748... Val Loss: -1.091317
# Epoch: 33/60... Step: 545... Loss: -1.650667... Val Loss: -1.214961
# Epoch: 33/60... Step: 550... Loss: -1.395861... Val Loss: -0.824885
# Epoch: 33/60... Step: 555... Loss: -1.205815... Val Loss: -0.741871
# Epoch: 33/60... Step: 560... Loss: -1.318025... Val Loss: -0.782378
# Epoch: 34/60... Step: 565... Loss: -1.348621... Val Loss: -1.334971
# Epoch: 34/60... Step: 570... Loss: -1.527854... Val Loss: -0.967606
# Epoch: 34/60... Step: 575... Loss: -0.887738... Val Loss: -0.954776
# Epoch: 35/60... Step: 580... Loss: -1.694968... Val Loss: -0.969317
# Epoch: 35/60... Step: 585... Loss: -1.797237... Val Loss: -1.314974
# Epoch: 35/60... Step: 590... Loss: -1.063539... Val Loss: -0.769359
# Epoch: 35/60... Step: 595... Loss: -1.494818... Val Loss: -1.014117
# Epoch: 36/60... Step: 600... Loss: -1.083539... Val Loss: -1.179821
# Epoch: 36/60... Step: 605... Loss: -1.624869... Val Loss: -1.398935
# Epoch: 36/60... Step: 610... Loss: -1.719890... Val Loss: -1.190079
# Epoch: 37/60... Step: 615... Loss: -0.221659... Val Loss: -0.963062
# Epoch: 37/60... Step: 620... Loss: -1.109236... Val Loss: -1.184954
# Epoch: 37/60... Step: 625... Loss: -1.525309... Val Loss: -1.063353
# Epoch: 38/60... Step: 630... Loss: -1.479265... Val Loss: -1.142286
# Epoch: 38/60... Step: 635... Loss: -1.961766... Val Loss: -1.093574
# Epoch: 38/60... Step: 640... Loss: -1.875646... Val Loss: -1.116571
# Epoch: 38/60... Step: 645... Loss: -1.374002... Val Loss: -0.941677
# Epoch: 39/60... Step: 650... Loss: -1.124246... Val Loss: -1.033419
# Epoch: 39/60... Step: 655... Loss: -1.613201... Val Loss: -1.223115
# Epoch: 39/60... Step: 660... Loss: -0.637007... Val Loss: -1.322342
# Epoch: 40/60... Step: 665... Loss: -1.108160... Val Loss: -1.427004
# Epoch: 40/60... Step: 670... Loss: -1.650596... Val Loss: -1.052677
# Epoch: 40/60... Step: 675... Loss: -1.489180... Val Loss: -1.166657
# Epoch: 40/60... Step: 680... Loss: -1.599051... Val Loss: -1.044559
# Epoch: 41/60... Step: 685... Loss: -1.232659... Val Loss: -1.314975
# Epoch: 41/60... Step: 690... Loss: -2.825132... Val Loss: -0.871464
# Epoch: 41/60... Step: 695... Loss: -1.792709... Val Loss: -1.094396
# Epoch: 42/60... Step: 700... Loss: -1.830843... Val Loss: -1.365023
# Epoch: 42/60... Step: 705... Loss: -1.078103... Val Loss: -1.090552
# Epoch: 42/60... Step: 710... Loss: -1.600922... Val Loss: -0.980557
# Epoch: 43/60... Step: 715... Loss: -1.904298... Val Loss: -0.925326
# Epoch: 43/60... Step: 720... Loss: -1.350071... Val Loss: -1.038148
# Epoch: 43/60... Step: 725... Loss: -0.970991... Val Loss: -1.371283
# Epoch: 43/60... Step: 730... Loss: -1.689400... Val Loss: -1.301098
# Epoch: 44/60... Step: 735... Loss: -0.912176... Val Loss: -1.412765
# Epoch: 44/60... Step: 740... Loss: -0.912137... Val Loss: -1.057157
# Epoch: 44/60... Step: 745... Loss: -1.573826... Val Loss: -1.260252
# Epoch: 45/60... Step: 750... Loss: -1.548243... Val Loss: -1.084156
# Epoch: 45/60... Step: 755... Loss: -1.859703... Val Loss: -1.391178
# Epoch: 45/60... Step: 760... Loss: -1.258638... Val Loss: -0.824950
# Epoch: 45/60... Step: 765... Loss: -1.288524... Val Loss: -1.024035
# Epoch: 46/60... Step: 770... Loss: -1.842688... Val Loss: -1.209941
# Epoch: 46/60... Step: 775... Loss: -1.218136... Val Loss: -1.126570
# Epoch: 46/60... Step: 780... Loss: -1.412103... Val Loss: -1.064112
# Epoch: 47/60... Step: 785... Loss: -1.727671... Val Loss: -1.013797
# Epoch: 47/60... Step: 790... Loss: -0.433681... Val Loss: -0.925631
# Epoch: 47/60... Step: 795... Loss: -1.581071... Val Loss: -1.419818
# Epoch: 48/60... Step: 800... Loss: -2.018125... Val Loss: -1.124730
# Epoch: 48/60... Step: 805... Loss: -1.725157... Val Loss: -1.278919
# Epoch: 48/60... Step: 810... Loss: 0.219779... Val Loss: -1.506503
# Epoch: 48/60... Step: 815... Loss: -0.997444... Val Loss: -1.367348
# Epoch: 49/60... Step: 820... Loss: -1.491911... Val Loss: -1.254239
# Epoch: 49/60... Step: 825... Loss: -1.378839... Val Loss: -1.148547
# Epoch: 49/60... Step: 830... Loss: -0.845356... Val Loss: -1.135782
# Epoch: 50/60... Step: 835... Loss: -1.602949... Val Loss: -1.378785
# Epoch: 50/60... Step: 840... Loss: -1.595493... Val Loss: -1.114148
# Epoch: 50/60... Step: 845... Loss: -2.511180... Val Loss: -1.268993
# Epoch: 50/60... Step: 850... Loss: -2.438204... Val Loss: -0.710330
# Epoch: 51/60... Step: 855... Loss: -1.147304... Val Loss: -1.435565
# Epoch: 51/60... Step: 860... Loss: -1.519478... Val Loss: -1.192513
# Epoch: 51/60... Step: 865... Loss: -1.593469... Val Loss: -1.223338
# Epoch: 52/60... Step: 870... Loss: -2.270931... Val Loss: -1.290681
# Epoch: 52/60... Step: 875... Loss: -1.235957... Val Loss: -0.599159
# Epoch: 52/60... Step: 880... Loss: -1.195348... Val Loss: -1.144396
# Epoch: 53/60... Step: 885... Loss: -1.535825... Val Loss: -0.815796
# Epoch: 53/60... Step: 890... Loss: -1.738933... Val Loss: -1.151311
# Epoch: 53/60... Step: 895... Loss: -1.687925... Val Loss: -0.724526
# Epoch: 53/60... Step: 900... Loss: -1.525793... Val Loss: -0.997205
# Epoch: 54/60... Step: 905... Loss: -1.528489... Val Loss: -0.927204
# Epoch: 54/60... Step: 910... Loss: -0.706067... Val Loss: -1.265205
# Epoch: 54/60... Step: 915... Loss: -1.603914... Val Loss: -1.250653
# Epoch: 55/60... Step: 920... Loss: -1.388812... Val Loss: -0.923694
# Epoch: 55/60... Step: 925... Loss: -2.319084... Val Loss: -1.248059
# Epoch: 55/60... Step: 930... Loss: -2.548415... Val Loss: -1.507887
# Epoch: 55/60... Step: 935... Loss: -1.321342... Val Loss: -1.144000
# Epoch: 56/60... Step: 940... Loss: -1.228123... Val Loss: -1.270221
# Epoch: 56/60... Step: 945... Loss: -2.055023... Val Loss: -1.346612
# Epoch: 56/60... Step: 950... Loss: -2.007418... Val Loss: -1.048845
# Epoch: 57/60... Step: 955... Loss: -1.479202... Val Loss: -1.034322
# Epoch: 57/60... Step: 960... Loss: -1.885055... Val Loss: -1.047246
# Epoch: 57/60... Step: 965... Loss: -2.193332... Val Loss: -1.026003
# Epoch: 58/60... Step: 970... Loss: -1.843995... Val Loss: -1.439535
# Epoch: 58/60... Step: 975... Loss: -1.060362... Val Loss: -1.232835
# Epoch: 58/60... Step: 980... Loss: -1.696091... Val Loss: -1.351325
# Epoch: 58/60... Step: 985... Loss: -1.803634... Val Loss: -0.839782
# Epoch: 59/60... Step: 990... Loss: -1.732607... Val Loss: -1.294460
# Epoch: 59/60... Step: 995... Loss: -0.895368... Val Loss: -0.825805
# Epoch: 59/60... Step: 1000... Loss: -1.563619... Val Loss: -1.089718
# Epoch: 60/60... Step: 1005... Loss: -1.970668... Val Loss: -1.147471
# Epoch: 60/60... Step: 1010... Loss: -1.691522... Val Loss: -0.921348
# Epoch: 60/60... Step: 1015... Loss: -0.990005... Val Loss: -1.176265
# Epoch: 60/60... Step: 1020... Loss: -1.172341... Val Loss: -1.240529

# %% [markdown]
# ### RNN

# %%
class RNN(nn.Module):
    def __init__(self, input_size, output_size, hidden_dim, n_layers, drop_prob=0.5):
        
        super(RNN, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim        
        # if batch_first, than shape of lstm_in: [batch_size, seq_len, input_size]
        self.rnn = nn.RNN(input_size, hidden_dim, n_layers, dropout=drop_prob, batch_first=True)
        self.dropout = nn.Dropout(drop_prob)
        self.linear_1 = nn.Linear(hidden_dim, hidden_dim//2)
        self.linear_2 = nn.Linear(hidden_dim//2, 1)
        self.activation = nn.Sigmoid()
        self.relu = nn.ReLU()
        
    def forward(self, input_seq, hidden):
        batch_size = input_seq.size(0)
        rnn_out, hidden = self.rnn(input_seq, hidden)  
        rnn_out = rnn_out.contiguous().view(-1, self.hidden_dim)      
        out = self.linear_1(rnn_out)
        out = self.dropout(out)
        out = self.relu(out)
        out = self.linear_2(out)
        out = self.activation(out)
        out = out.view(batch_size, -1)

        return out, hidden

    def init_hidden(self, batch_size):
        weight = next(self.parameters()).data
        
        hidden = (weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device),
                  weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device))
        return hidden

# %%
model_RNN_custom = RNN(input_size=input_size, output_size=output_size, hidden_dim=hidden_dim, n_layers=n_layers)
loss_function = CustomLoss()
model_RNN_custom.to(device)
# Out:
# RNN(
#   (rnn): RNN(561, 8, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (linear_1): Linear(in_features=8, out_features=4, bias=True)
#   (linear_2): Linear(in_features=4, out_features=1, bias=True)
#   (activation): Sigmoid()
#   (relu): ReLU()
# )

# %%
model_RNN_custom, (loss_list, acc_list, 
                    overall_val_loss_list) = train_model(model_RNN_custom, loss_function, 60, 5, RNN_flag=True)

model_RNN_custom = model_RNN_custom.eval()
torch.save(model_RNN_custom, "experiments/model_RNN_custom.pth")
# Out:
# Epoch: 1/60... Step: 5... Loss: 0.855848... Val Loss: 0.669192
# Epoch: 1/60... Step: 10... Loss: 0.672859... Val Loss: 0.550766
# Epoch: 1/60... Step: 15... Loss: 0.626884... Val Loss: 0.532341
# Epoch: 2/60... Step: 20... Loss: 0.985925... Val Loss: 0.483860
# Epoch: 2/60... Step: 25... Loss: 0.779527... Val Loss: 0.458639
# Epoch: 2/60... Step: 30... Loss: 0.468311... Val Loss: 0.433687
# Epoch: 3/60... Step: 35... Loss: 0.378672... Val Loss: 0.461589
# Epoch: 3/60... Step: 40... Loss: 0.462995... Val Loss: 0.441733
# Epoch: 3/60... Step: 45... Loss: 0.368168... Val Loss: 0.361060
# Epoch: 3/60... Step: 50... Loss: 0.485599... Val Loss: 0.339771
# Epoch: 4/60... Step: 55... Loss: 0.316614... Val Loss: 0.316035
# Epoch: 4/60... Step: 60... Loss: 0.064293... Val Loss: 0.203153
# Epoch: 4/60... Step: 65... Loss: 0.087678... Val Loss: 0.314708
# Epoch: 5/60... Step: 70... Loss: 0.199805... Val Loss: 0.346596
# Epoch: 5/60... Step: 75... Loss: 0.231664... Val Loss: 0.244838
# Epoch: 5/60... Step: 80... Loss: 0.371318... Val Loss: 0.262878
# Epoch: 5/60... Step: 85... Loss: 0.494346... Val Loss: 0.307460
# Epoch: 6/60... Step: 90... Loss: -0.210605... Val Loss: 0.319176
# Epoch: 6/60... Step: 95... Loss: -0.134880... Val Loss: 0.418929
# Epoch: 6/60... Step: 100... Loss: 0.171932... Val Loss: 0.255076
# Epoch: 7/60... Step: 105... Loss: 0.510282... Val Loss: 0.276076
# Epoch: 7/60... Step: 110... Loss: 0.308416... Val Loss: 0.336823
# Epoch: 7/60... Step: 115... Loss: 0.177637... Val Loss: 0.270119
# Epoch: 8/60... Step: 120... Loss: 0.148988... Val Loss: 0.288519
# Epoch: 8/60... Step: 125... Loss: 0.655648... Val Loss: 0.244393
# Epoch: 8/60... Step: 130... Loss: 0.522375... Val Loss: 0.232664
# Epoch: 8/60... Step: 135... Loss: 0.453699... Val Loss: 0.377954
# Epoch: 9/60... Step: 140... Loss: 0.157343... Val Loss: 0.271401
# Epoch: 9/60... Step: 145... Loss: 0.079829... Val Loss: 0.292837
# Epoch: 9/60... Step: 150... Loss: 0.089449... Val Loss: 0.217455
# Epoch: 10/60... Step: 155... Loss: 0.400355... Val Loss: 0.189470
# Epoch: 10/60... Step: 160... Loss: 0.071145... Val Loss: 0.279227
# Epoch: 10/60... Step: 165... Loss: 0.222516... Val Loss: 0.189697
# Epoch: 10/60... Step: 170... Loss: 0.038097... Val Loss: 0.291149
# Epoch: 11/60... Step: 175... Loss: 0.434338... Val Loss: 0.274575
# Epoch: 11/60... Step: 180... Loss: -0.057448... Val Loss: 0.268782
# Epoch: 11/60... Step: 185... Loss: -0.020574... Val Loss: 0.298221
# Epoch: 12/60... Step: 190... Loss: 0.390039... Val Loss: 0.250307
# Epoch: 12/60... Step: 195... Loss: 0.308905... Val Loss: 0.212167
# Epoch: 12/60... Step: 200... Loss: 0.236840... Val Loss: 0.237750
# Epoch: 13/60... Step: 205... Loss: 0.459404... Val Loss: 0.185664
# Epoch: 13/60... Step: 210... Loss: 0.214784... Val Loss: 0.276740
# Epoch: 13/60... Step: 215... Loss: 0.309531... Val Loss: 0.244711
# Epoch: 13/60... Step: 220... Loss: 0.110240... Val Loss: 0.203433
# Epoch: 14/60... Step: 225... Loss: 0.043552... Val Loss: 0.162008
# Epoch: 14/60... Step: 230... Loss: 0.090965... Val Loss: 0.229356
# Epoch: 14/60... Step: 235... Loss: 0.146228... Val Loss: 0.295750
# Epoch: 15/60... Step: 240... Loss: 0.225793... Val Loss: 0.123813
# Epoch: 15/60... Step: 245... Loss: -0.392580... Val Loss: 0.153004
# Epoch: 15/60... Step: 250... Loss: -0.105565... Val Loss: 0.180679
# Epoch: 15/60... Step: 255... Loss: 0.514621... Val Loss: 0.172344
# Epoch: 16/60... Step: 260... Loss: -0.028496... Val Loss: 0.185225
# Epoch: 16/60... Step: 265... Loss: -0.048764... Val Loss: 0.170876
# Epoch: 16/60... Step: 270... Loss: 0.018527... Val Loss: 0.160523
# Epoch: 17/60... Step: 275... Loss: 0.126906... Val Loss: 0.127210
# Epoch: 17/60... Step: 280... Loss: -0.162317... Val Loss: 0.169343
# Epoch: 17/60... Step: 285... Loss: 0.320643... Val Loss: 0.119101
# Epoch: 18/60... Step: 290... Loss: 0.121066... Val Loss: 0.066687
# Epoch: 18/60... Step: 295... Loss: 0.041463... Val Loss: 0.039757
# Epoch: 18/60... Step: 300... Loss: -0.119403... Val Loss: 0.027037
# Epoch: 18/60... Step: 305... Loss: -0.063384... Val Loss: -0.047687
# Epoch: 19/60... Step: 310... Loss: 0.073443... Val Loss: -0.009612
# Epoch: 19/60... Step: 315... Loss: -0.224088... Val Loss: -0.087766
# Epoch: 19/60... Step: 320... Loss: 0.092869... Val Loss: 0.001286
# Epoch: 20/60... Step: 325... Loss: -0.094610... Val Loss: 0.062386
# Epoch: 20/60... Step: 330... Loss: 0.259193... Val Loss: -0.064600
# Epoch: 20/60... Step: 335... Loss: -0.353929... Val Loss: -0.169107
# Epoch: 20/60... Step: 340... Loss: -0.404639... Val Loss: -0.182262
# Epoch: 21/60... Step: 345... Loss: -0.307101... Val Loss: -0.112503
# Epoch: 21/60... Step: 350... Loss: -0.462345... Val Loss: -0.098731
# Epoch: 21/60... Step: 355... Loss: -0.386052... Val Loss: -0.189885
# Epoch: 22/60... Step: 360... Loss: -0.383890... Val Loss: -0.223319
# Epoch: 22/60... Step: 365... Loss: -0.252907... Val Loss: -0.194019
# Epoch: 22/60... Step: 370... Loss: -0.264409... Val Loss: -0.270302
# Epoch: 23/60... Step: 375... Loss: -0.720020... Val Loss: -0.395341
# Epoch: 23/60... Step: 380... Loss: -0.279559... Val Loss: -0.349745
# Epoch: 23/60... Step: 385... Loss: 0.200290... Val Loss: -0.396438
# Epoch: 23/60... Step: 390... Loss: -0.186908... Val Loss: -0.431601
# Epoch: 24/60... Step: 395... Loss: -0.639402... Val Loss: -0.484836
# Epoch: 24/60... Step: 400... Loss: -0.516752... Val Loss: -0.354686
# Epoch: 24/60... Step: 405... Loss: -0.358945... Val Loss: -0.373948
# Epoch: 25/60... Step: 410... Loss: -0.759956... Val Loss: -0.337039
# Epoch: 25/60... Step: 415... Loss: -0.455184... Val Loss: -0.378702
# Epoch: 25/60... Step: 420... Loss: -1.027499... Val Loss: -0.538961
# Epoch: 25/60... Step: 425... Loss: -1.015590... Val Loss: -0.724086
# Epoch: 26/60... Step: 430... Loss: -0.418519... Val Loss: -0.608140
# Epoch: 26/60... Step: 435... Loss: -0.650687... Val Loss: -0.555088
# Epoch: 26/60... Step: 440... Loss: -0.537718... Val Loss: -0.596490
# Epoch: 27/60... Step: 445... Loss: -0.513932... Val Loss: -0.571488
# Epoch: 27/60... Step: 450... Loss: -0.259321... Val Loss: -0.793114
# Epoch: 27/60... Step: 455... Loss: -1.351877... Val Loss: -0.784552
# Epoch: 28/60... Step: 460... Loss: -0.950599... Val Loss: -0.720027
# Epoch: 28/60... Step: 465... Loss: -0.939291... Val Loss: -0.724983
# Epoch: 28/60... Step: 470... Loss: -0.580712... Val Loss: -0.848773
# Epoch: 28/60... Step: 475... Loss: -0.894137... Val Loss: -0.805764
# Epoch: 29/60... Step: 480... Loss: -1.185413... Val Loss: -0.806193
# Epoch: 29/60... Step: 485... Loss: -1.067156... Val Loss: -0.762264
# Epoch: 29/60... Step: 490... Loss: -0.444689... Val Loss: -0.879432
# Epoch: 30/60... Step: 495... Loss: -0.947620... Val Loss: -0.864197
# Epoch: 30/60... Step: 500... Loss: -0.580515... Val Loss: -0.797690
# Epoch: 30/60... Step: 505... Loss: -0.945124... Val Loss: -0.851369
# Epoch: 30/60... Step: 510... Loss: -0.905066... Val Loss: -0.724497
# Epoch: 31/60... Step: 515... Loss: -1.194892... Val Loss: -0.895279
# Epoch: 31/60... Step: 520... Loss: -0.467909... Val Loss: -0.783769
# Epoch: 31/60... Step: 525... Loss: -1.075116... Val Loss: -0.948913
# Epoch: 32/60... Step: 530... Loss: -0.524369... Val Loss: -0.840945
# Epoch: 32/60... Step: 535... Loss: -1.324136... Val Loss: -0.822218
# Epoch: 32/60... Step: 540... Loss: -0.943617... Val Loss: -0.884503
# Epoch: 33/60... Step: 545... Loss: -0.796763... Val Loss: -0.823781
# Epoch: 33/60... Step: 550... Loss: -1.804635... Val Loss: -0.719402
# Epoch: 33/60... Step: 555... Loss: -1.027202... Val Loss: -1.080253
# Epoch: 33/60... Step: 560... Loss: -0.813056... Val Loss: -0.880420
# Epoch: 34/60... Step: 565... Loss: -1.013671... Val Loss: -0.706863
# Epoch: 34/60... Step: 570... Loss: -0.465459... Val Loss: -0.828895
# Epoch: 34/60... Step: 575... Loss: -0.033781... Val Loss: -0.815674
# Epoch: 35/60... Step: 580... Loss: -0.847086... Val Loss: -0.798510
# Epoch: 35/60... Step: 585... Loss: -1.275912... Val Loss: -0.767630
# Epoch: 35/60... Step: 590... Loss: -0.493109... Val Loss: -0.944872
# Epoch: 35/60... Step: 595... Loss: -1.187886... Val Loss: -1.034924
# Epoch: 36/60... Step: 600... Loss: -1.974075... Val Loss: -0.941520
# Epoch: 36/60... Step: 605... Loss: -0.471437... Val Loss: -1.025037
# Epoch: 36/60... Step: 610... Loss: -0.720123... Val Loss: -1.034086
# Epoch: 37/60... Step: 615... Loss: -1.015865... Val Loss: -0.958247
# Epoch: 37/60... Step: 620... Loss: -1.235014... Val Loss: -0.918076
# Epoch: 37/60... Step: 625... Loss: -1.216710... Val Loss: -1.074957
# Epoch: 38/60... Step: 630... Loss: -0.235244... Val Loss: -0.923463
# Epoch: 38/60... Step: 635... Loss: -0.478091... Val Loss: -1.019183
# Epoch: 38/60... Step: 640... Loss: -2.080310... Val Loss: -1.021477
# Epoch: 38/60... Step: 645... Loss: -0.794711... Val Loss: -1.002529
# Epoch: 39/60... Step: 650... Loss: -0.688134... Val Loss: -0.988050
# Epoch: 39/60... Step: 655... Loss: -1.018337... Val Loss: -1.242935
# Epoch: 39/60... Step: 660... Loss: -1.230800... Val Loss: -1.100474
# Epoch: 40/60... Step: 665... Loss: -0.134021... Val Loss: -0.641871
# Epoch: 40/60... Step: 670... Loss: -1.145032... Val Loss: -0.669073
# Epoch: 40/60... Step: 675... Loss: -0.622043... Val Loss: -0.718861
# Epoch: 40/60... Step: 680... Loss: -0.853812... Val Loss: -0.859518
# Epoch: 41/60... Step: 685... Loss: -0.695918... Val Loss: -0.835173
# Epoch: 41/60... Step: 690... Loss: -0.464077... Val Loss: -0.811715
# Epoch: 41/60... Step: 695... Loss: -1.041525... Val Loss: -0.877997
# Epoch: 42/60... Step: 700... Loss: -0.699718... Val Loss: -0.921967
# Epoch: 42/60... Step: 705... Loss: -1.148987... Val Loss: -0.879348
# Epoch: 42/60... Step: 710... Loss: -0.994664... Val Loss: -1.003270
# Epoch: 43/60... Step: 715... Loss: -1.151626... Val Loss: -1.030986
# Epoch: 43/60... Step: 720... Loss: -0.603376... Val Loss: -0.908918
# Epoch: 43/60... Step: 725... Loss: -1.624962... Val Loss: -0.947154
# Epoch: 43/60... Step: 730... Loss: -0.262621... Val Loss: -1.004007
# Epoch: 44/60... Step: 735... Loss: -1.226512... Val Loss: -0.905902
# Epoch: 44/60... Step: 740... Loss: -1.402674... Val Loss: -0.982913
# Epoch: 44/60... Step: 745... Loss: -0.355210... Val Loss: -0.927526
# Epoch: 45/60... Step: 750... Loss: -0.947891... Val Loss: -0.857612
# Epoch: 45/60... Step: 755... Loss: -1.631212... Val Loss: -1.345808
# Epoch: 45/60... Step: 760... Loss: -0.638983... Val Loss: -0.845856
# Epoch: 45/60... Step: 765... Loss: -1.408542... Val Loss: -1.002603
# Epoch: 46/60... Step: 770... Loss: -0.894578... Val Loss: -1.146545
# Epoch: 46/60... Step: 775... Loss: -0.653313... Val Loss: -0.791986
# Epoch: 46/60... Step: 780... Loss: -1.450708... Val Loss: -1.192629
# Epoch: 47/60... Step: 785... Loss: -2.033280... Val Loss: -1.335459
# Epoch: 47/60... Step: 790... Loss: -0.998294... Val Loss: -1.130982
# Epoch: 47/60... Step: 795... Loss: -1.782098... Val Loss: -1.116174
# Epoch: 48/60... Step: 800... Loss: -0.832047... Val Loss: -1.162273
# Epoch: 48/60... Step: 805... Loss: -1.448202... Val Loss: -1.164632
# Epoch: 48/60... Step: 810... Loss: -2.464101... Val Loss: -0.900534
# Epoch: 48/60... Step: 815... Loss: -1.114139... Val Loss: -0.777988
# Epoch: 49/60... Step: 820... Loss: -1.800555... Val Loss: -1.012857
# Epoch: 49/60... Step: 825... Loss: -0.830792... Val Loss: -1.183832
# Epoch: 49/60... Step: 830... Loss: -1.695685... Val Loss: -0.929937
# Epoch: 50/60... Step: 835... Loss: -0.695454... Val Loss: -1.118838
# Epoch: 50/60... Step: 840... Loss: -1.073237... Val Loss: -0.967889
# Epoch: 50/60... Step: 845... Loss: -1.577513... Val Loss: -1.385432
# Epoch: 50/60... Step: 850... Loss: -0.832424... Val Loss: -0.939236
# Epoch: 51/60... Step: 855... Loss: -1.539594... Val Loss: -1.067269
# Epoch: 51/60... Step: 860... Loss: -0.640134... Val Loss: -1.159790
# Epoch: 51/60... Step: 865... Loss: -1.519142... Val Loss: -1.143532
# Epoch: 52/60... Step: 870... Loss: -1.011811... Val Loss: -1.195338
# Epoch: 52/60... Step: 875... Loss: -0.748554... Val Loss: -1.023973
# Epoch: 52/60... Step: 880... Loss: -1.187231... Val Loss: -1.197386
# Epoch: 53/60... Step: 885... Loss: -0.718753... Val Loss: -1.191575
# Epoch: 53/60... Step: 890... Loss: -1.440438... Val Loss: -1.128181
# Epoch: 53/60... Step: 895... Loss: -1.364563... Val Loss: -0.967595
# Epoch: 53/60... Step: 900... Loss: -0.660244... Val Loss: -1.226296
# Epoch: 54/60... Step: 905... Loss: -1.337535... Val Loss: -1.032333
# Epoch: 54/60... Step: 910... Loss: -1.344168... Val Loss: -1.030469
# Epoch: 54/60... Step: 915... Loss: -0.932857... Val Loss: -0.979909
# Epoch: 55/60... Step: 920... Loss: -0.830287... Val Loss: -0.977902
# Epoch: 55/60... Step: 925... Loss: -1.082608... Val Loss: -1.034836
# Epoch: 55/60... Step: 930... Loss: -0.736884... Val Loss: -0.928297
# Epoch: 55/60... Step: 935... Loss: -1.576136... Val Loss: -1.005794
# Epoch: 56/60... Step: 940... Loss: -1.123756... Val Loss: -1.074883
# Epoch: 56/60... Step: 945... Loss: -1.414439... Val Loss: -1.126151
# Epoch: 56/60... Step: 950... Loss: -0.698436... Val Loss: -1.004783
# Epoch: 57/60... Step: 955... Loss: -0.977440... Val Loss: -1.221882
# Epoch: 57/60... Step: 960... Loss: -1.417966... Val Loss: -1.158027
# Epoch: 57/60... Step: 965... Loss: -0.883165... Val Loss: -1.136491
# Epoch: 58/60... Step: 970... Loss: -1.214585... Val Loss: -0.969694
# Epoch: 58/60... Step: 975... Loss: -1.041166... Val Loss: -1.090097
# Epoch: 58/60... Step: 980... Loss: -1.801173... Val Loss: -1.045696
# Epoch: 58/60... Step: 985... Loss: -1.637955... Val Loss: -1.195582
# Epoch: 59/60... Step: 990... Loss: -1.364924... Val Loss: -0.995564
# Epoch: 59/60... Step: 995... Loss: -1.850952... Val Loss: -1.100666
# Epoch: 59/60... Step: 1000... Loss: -0.445751... Val Loss: -1.193413
# Epoch: 60/60... Step: 1005... Loss: -1.045888... Val Loss: -1.132678
# Epoch: 60/60... Step: 1010... Loss: -0.717740... Val Loss: -0.952891
# Epoch: 60/60... Step: 1015... Loss: -0.782952... Val Loss: -0.979112
# Epoch: 60/60... Step: 1020... Loss: -1.309807... Val Loss: -1.257410

# %%
plt.plot(acc_list)

# %%
model_RNN_bce = RNN(input_size=input_size, output_size=output_size, hidden_dim=hidden_dim, n_layers=n_layers)
bce_loss_function = torch.nn.BCELoss()
model_RNN_bce.to(device)
# Out:
# RNN(
#   (rnn): RNN(561, 8, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (linear_1): Linear(in_features=8, out_features=4, bias=True)
#   (linear_2): Linear(in_features=4, out_features=1, bias=True)
#   (activation): Sigmoid()
#   (relu): ReLU()
# )

# %%
model_RNN_bce, (bce_loss_list, bce_acc_list, bce_overall_val_loss_list) = train_model(model_RNN_bce, bce_loss_function, 
                                                                                       60, 5, RNN_flag=True)
model_RNN_bce = model_RNN_bce.eval()
torch.save(model_RNN_bce, "experiments/model_RNN_bce.pth")
# Out:
# Epoch: 1/60... Step: 5... Loss: 0.705449... Val Loss: 0.692557
# Epoch: 1/60... Step: 10... Loss: 0.700015... Val Loss: 0.692981
# Epoch: 1/60... Step: 15... Loss: 0.704064... Val Loss: 0.693735
# Epoch: 2/60... Step: 20... Loss: 0.703331... Val Loss: 0.694257
# Epoch: 2/60... Step: 25... Loss: 0.699423... Val Loss: 0.694853
# Epoch: 2/60... Step: 30... Loss: 0.702685... Val Loss: 0.695046
# Epoch: 3/60... Step: 35... Loss: 0.693484... Val Loss: 0.695409
# Epoch: 3/60... Step: 40... Loss: 0.700474... Val Loss: 0.695369
# Epoch: 3/60... Step: 45... Loss: 0.705110... Val Loss: 0.694803
# Epoch: 3/60... Step: 50... Loss: 0.704278... Val Loss: 0.693809
# Epoch: 4/60... Step: 55... Loss: 0.709038... Val Loss: 0.693266
# Epoch: 4/60... Step: 60... Loss: 0.690751... Val Loss: 0.692674
# Epoch: 4/60... Step: 65... Loss: 0.697359... Val Loss: 0.692061
# Epoch: 5/60... Step: 70... Loss: 0.688427... Val Loss: 0.691694
# Epoch: 5/60... Step: 75... Loss: 0.690227... Val Loss: 0.691606
# Epoch: 5/60... Step: 80... Loss: 0.701118... Val Loss: 0.691176
# Epoch: 5/60... Step: 85... Loss: 0.696319... Val Loss: 0.690835
# Epoch: 6/60... Step: 90... Loss: 0.708872... Val Loss: 0.690986
# Epoch: 6/60... Step: 95... Loss: 0.705163... Val Loss: 0.691252
# Epoch: 6/60... Step: 100... Loss: 0.681787... Val Loss: 0.691131
# Epoch: 7/60... Step: 105... Loss: 0.690852... Val Loss: 0.690446
# Epoch: 7/60... Step: 110... Loss: 0.706108... Val Loss: 0.689564
# Epoch: 7/60... Step: 115... Loss: 0.696750... Val Loss: 0.689155
# Epoch: 8/60... Step: 120... Loss: 0.711589... Val Loss: 0.688726
# Epoch: 8/60... Step: 125... Loss: 0.684266... Val Loss: 0.688454
# Epoch: 8/60... Step: 130... Loss: 0.698268... Val Loss: 0.688485
# Epoch: 8/60... Step: 135... Loss: 0.692771... Val Loss: 0.688564
# Epoch: 9/60... Step: 140... Loss: 0.689269... Val Loss: 0.688883
# Epoch: 9/60... Step: 145... Loss: 0.697998... Val Loss: 0.688199
# Epoch: 9/60... Step: 150... Loss: 0.689573... Val Loss: 0.687225
# Epoch: 10/60... Step: 155... Loss: 0.694460... Val Loss: 0.687051
# Epoch: 10/60... Step: 160... Loss: 0.696293... Val Loss: 0.686762
# Epoch: 10/60... Step: 165... Loss: 0.700028... Val Loss: 0.686630
# Epoch: 10/60... Step: 170... Loss: 0.703188... Val Loss: 0.686403
# Epoch: 11/60... Step: 175... Loss: 0.709165... Val Loss: 0.686220
# Epoch: 11/60... Step: 180... Loss: 0.688160... Val Loss: 0.686276
# Epoch: 11/60... Step: 185... Loss: 0.696399... Val Loss: 0.686113
# Epoch: 12/60... Step: 190... Loss: 0.693732... Val Loss: 0.685529
# Epoch: 12/60... Step: 195... Loss: 0.685382... Val Loss: 0.685176
# Epoch: 12/60... Step: 200... Loss: 0.688528... Val Loss: 0.683718
# Epoch: 13/60... Step: 205... Loss: 0.695216... Val Loss: 0.682913
# Epoch: 13/60... Step: 210... Loss: 0.689699... Val Loss: 0.682608
# Epoch: 13/60... Step: 215... Loss: 0.706811... Val Loss: 0.682686
# Epoch: 13/60... Step: 220... Loss: 0.691747... Val Loss: 0.682736
# Epoch: 14/60... Step: 225... Loss: 0.719984... Val Loss: 0.682126
# Epoch: 14/60... Step: 230... Loss: 0.684394... Val Loss: 0.681706
# Epoch: 14/60... Step: 235... Loss: 0.702770... Val Loss: 0.681362
# Epoch: 15/60... Step: 240... Loss: 0.701764... Val Loss: 0.681120
# Epoch: 15/60... Step: 245... Loss: 0.690695... Val Loss: 0.680801
# Epoch: 15/60... Step: 250... Loss: 0.694821... Val Loss: 0.680556
# Epoch: 15/60... Step: 255... Loss: 0.675182... Val Loss: 0.680511
# Epoch: 16/60... Step: 260... Loss: 0.694576... Val Loss: 0.680687
# Epoch: 16/60... Step: 265... Loss: 0.690185... Val Loss: 0.681132
# Epoch: 16/60... Step: 270... Loss: 0.685824... Val Loss: 0.680738
# Epoch: 17/60... Step: 275... Loss: 0.689044... Val Loss: 0.679554
# Epoch: 17/60... Step: 280... Loss: 0.676512... Val Loss: 0.678661
# Epoch: 17/60... Step: 285... Loss: 0.713425... Val Loss: 0.677667
# Epoch: 18/60... Step: 290... Loss: 0.677345... Val Loss: 0.677405
# Epoch: 18/60... Step: 295... Loss: 0.689983... Val Loss: 0.677480
# Epoch: 18/60... Step: 300... Loss: 0.673490... Val Loss: 0.677842
# Epoch: 18/60... Step: 305... Loss: 0.681367... Val Loss: 0.677550
# Epoch: 19/60... Step: 310... Loss: 0.679717... Val Loss: 0.676273
# Epoch: 19/60... Step: 315... Loss: 0.671985... Val Loss: 0.674916
# Epoch: 19/60... Step: 320... Loss: 0.691089... Val Loss: 0.673933
# Epoch: 20/60... Step: 325... Loss: 0.691838... Val Loss: 0.673192
# Epoch: 20/60... Step: 330... Loss: 0.680826... Val Loss: 0.672542
# Epoch: 20/60... Step: 335... Loss: 0.699646... Val Loss: 0.671569
# Epoch: 20/60... Step: 340... Loss: 0.684712... Val Loss: 0.670594
# Epoch: 21/60... Step: 345... Loss: 0.684440... Val Loss: 0.669335
# Epoch: 21/60... Step: 350... Loss: 0.677445... Val Loss: 0.667853
# Epoch: 21/60... Step: 355... Loss: 0.664393... Val Loss: 0.665619
# Epoch: 22/60... Step: 360... Loss: 0.663744... Val Loss: 0.660041
# Epoch: 22/60... Step: 365... Loss: 0.663977... Val Loss: 0.655618
# Epoch: 22/60... Step: 370... Loss: 0.668042... Val Loss: 0.653423
# Epoch: 23/60... Step: 375... Loss: 0.646195... Val Loss: 0.660091
# Epoch: 23/60... Step: 380... Loss: 0.633769... Val Loss: 0.661293
# Epoch: 23/60... Step: 385... Loss: 0.644727... Val Loss: 0.646691
# Epoch: 23/60... Step: 390... Loss: 0.710157... Val Loss: 0.640166
# Epoch: 24/60... Step: 395... Loss: 0.695486... Val Loss: 0.657449
# Epoch: 24/60... Step: 400... Loss: 0.653110... Val Loss: 0.659718
# Epoch: 24/60... Step: 405... Loss: 0.663894... Val Loss: 0.654910
# Epoch: 25/60... Step: 410... Loss: 0.652733... Val Loss: 0.646407
# Epoch: 25/60... Step: 415... Loss: 0.624988... Val Loss: 0.633113
# Epoch: 25/60... Step: 420... Loss: 0.620358... Val Loss: 0.629418
# Epoch: 25/60... Step: 425... Loss: 0.638872... Val Loss: 0.623585
# Epoch: 26/60... Step: 430... Loss: 0.630769... Val Loss: 0.641106
# Epoch: 26/60... Step: 435... Loss: 0.603497... Val Loss: 0.616479
# Epoch: 26/60... Step: 440... Loss: 0.623732... Val Loss: 0.615498
# Epoch: 27/60... Step: 445... Loss: 0.585004... Val Loss: 0.628711
# Epoch: 27/60... Step: 450... Loss: 0.639131... Val Loss: 0.619898
# Epoch: 27/60... Step: 455... Loss: 0.649399... Val Loss: 0.620559
# Epoch: 28/60... Step: 460... Loss: 0.590859... Val Loss: 0.614308
# Epoch: 28/60... Step: 465... Loss: 0.581906... Val Loss: 0.601921
# Epoch: 28/60... Step: 470... Loss: 0.633371... Val Loss: 0.595208
# Epoch: 28/60... Step: 475... Loss: 0.581169... Val Loss: 0.600149
# Epoch: 29/60... Step: 480... Loss: 0.572163... Val Loss: 0.589952
# Epoch: 29/60... Step: 485... Loss: 0.556419... Val Loss: 0.583259
# Epoch: 29/60... Step: 490... Loss: 0.619143... Val Loss: 0.579490
# Epoch: 30/60... Step: 495... Loss: 0.571856... Val Loss: 0.603003
# Epoch: 30/60... Step: 500... Loss: 0.562081... Val Loss: 0.574667
# Epoch: 30/60... Step: 505... Loss: 0.645201... Val Loss: 0.580040
# Epoch: 30/60... Step: 510... Loss: 0.621358... Val Loss: 0.602391
# Epoch: 31/60... Step: 515... Loss: 0.569667... Val Loss: 0.576246
# Epoch: 31/60... Step: 520... Loss: 0.553254... Val Loss: 0.575997
# Epoch: 31/60... Step: 525... Loss: 0.595896... Val Loss: 0.568048
# Epoch: 32/60... Step: 530... Loss: 0.516340... Val Loss: 0.589783
# Epoch: 32/60... Step: 535... Loss: 0.573072... Val Loss: 0.570645
# Epoch: 32/60... Step: 540... Loss: 0.555126... Val Loss: 0.552243
# Epoch: 33/60... Step: 545... Loss: 0.560491... Val Loss: 0.567278
# Epoch: 33/60... Step: 550... Loss: 0.533602... Val Loss: 0.569640
# Epoch: 33/60... Step: 555... Loss: 0.572900... Val Loss: 0.552752
# Epoch: 33/60... Step: 560... Loss: 0.512946... Val Loss: 0.551912
# Epoch: 34/60... Step: 565... Loss: 0.547057... Val Loss: 0.587377
# Epoch: 34/60... Step: 570... Loss: 0.551666... Val Loss: 0.557542
# Epoch: 34/60... Step: 575... Loss: 0.514316... Val Loss: 0.546458
# Epoch: 35/60... Step: 580... Loss: 0.473410... Val Loss: 0.584363
# Epoch: 35/60... Step: 585... Loss: 0.585009... Val Loss: 0.573119
# Epoch: 35/60... Step: 590... Loss: 0.517331... Val Loss: 0.551279
# Epoch: 35/60... Step: 595... Loss: 0.545934... Val Loss: 0.546797
# Epoch: 36/60... Step: 600... Loss: 0.531366... Val Loss: 0.562817
# Epoch: 36/60... Step: 605... Loss: 0.608585... Val Loss: 0.582698
# Epoch: 36/60... Step: 610... Loss: 0.567408... Val Loss: 0.546179
# Epoch: 37/60... Step: 615... Loss: 0.543101... Val Loss: 0.541318
# Epoch: 37/60... Step: 620... Loss: 0.553579... Val Loss: 0.569854
# Epoch: 37/60... Step: 625... Loss: 0.475935... Val Loss: 0.570040
# Epoch: 38/60... Step: 630... Loss: 0.500063... Val Loss: 0.547661
# Epoch: 38/60... Step: 635... Loss: 0.523631... Val Loss: 0.547539
# Epoch: 38/60... Step: 640... Loss: 0.486442... Val Loss: 0.557223
# Epoch: 38/60... Step: 645... Loss: 0.550461... Val Loss: 0.556259
# Epoch: 39/60... Step: 650... Loss: 0.512663... Val Loss: 0.545753
# Epoch: 39/60... Step: 655... Loss: 0.556584... Val Loss: 0.557729
# Epoch: 39/60... Step: 660... Loss: 0.532462... Val Loss: 0.543279
# Epoch: 40/60... Step: 665... Loss: 0.541897... Val Loss: 0.558623
# Epoch: 40/60... Step: 670... Loss: 0.509885... Val Loss: 0.590618
# Epoch: 40/60... Step: 675... Loss: 0.566916... Val Loss: 0.547285
# Epoch: 40/60... Step: 680... Loss: 0.576172... Val Loss: 0.535173
# Epoch: 41/60... Step: 685... Loss: 0.476479... Val Loss: 0.558569
# Epoch: 41/60... Step: 690... Loss: 0.491571... Val Loss: 0.565761
# Epoch: 41/60... Step: 695... Loss: 0.598537... Val Loss: 0.548804
# Epoch: 42/60... Step: 700... Loss: 0.499578... Val Loss: 0.537012
# Epoch: 42/60... Step: 705... Loss: 0.542899... Val Loss: 0.550917
# Epoch: 42/60... Step: 710... Loss: 0.608545... Val Loss: 0.549084
# Epoch: 43/60... Step: 715... Loss: 0.520109... Val Loss: 0.547853
# Epoch: 43/60... Step: 720... Loss: 0.542478... Val Loss: 0.568179
# Epoch: 43/60... Step: 725... Loss: 0.613518... Val Loss: 0.566256
# Epoch: 43/60... Step: 730... Loss: 0.534920... Val Loss: 0.552621
# Epoch: 44/60... Step: 735... Loss: 0.524541... Val Loss: 0.545491
# Epoch: 44/60... Step: 740... Loss: 0.480300... Val Loss: 0.560607
# Epoch: 44/60... Step: 745... Loss: 0.528135... Val Loss: 0.551812
# Epoch: 45/60... Step: 750... Loss: 0.473586... Val Loss: 0.542819
# Epoch: 45/60... Step: 755... Loss: 0.509180... Val Loss: 0.536725
# Epoch: 45/60... Step: 760... Loss: 0.544093... Val Loss: 0.542971
# Epoch: 45/60... Step: 765... Loss: 0.498506... Val Loss: 0.551170
# Epoch: 46/60... Step: 770... Loss: 0.520124... Val Loss: 0.559315
# Epoch: 46/60... Step: 775... Loss: 0.523128... Val Loss: 0.539068
# Epoch: 46/60... Step: 780... Loss: 0.626630... Val Loss: 0.551504
# Epoch: 47/60... Step: 785... Loss: 0.637262... Val Loss: 0.562411
# Epoch: 47/60... Step: 790... Loss: 0.493418... Val Loss: 0.548254
# Epoch: 47/60... Step: 795... Loss: 0.564892... Val Loss: 0.548466
# Epoch: 48/60... Step: 800... Loss: 0.478612... Val Loss: 0.557212
# Epoch: 48/60... Step: 805... Loss: 0.499827... Val Loss: 0.536961
# Epoch: 48/60... Step: 810... Loss: 0.469254... Val Loss: 0.545250
# Epoch: 48/60... Step: 815... Loss: 0.573262... Val Loss: 0.547709
# Epoch: 49/60... Step: 820... Loss: 0.522347... Val Loss: 0.537415
# Epoch: 49/60... Step: 825... Loss: 0.597715... Val Loss: 0.545665
# Epoch: 49/60... Step: 830... Loss: 0.508095... Val Loss: 0.555276
# Epoch: 50/60... Step: 835... Loss: 0.587388... Val Loss: 0.549943
# Epoch: 50/60... Step: 840... Loss: 0.496755... Val Loss: 0.538156
# Epoch: 50/60... Step: 845... Loss: 0.563592... Val Loss: 0.540038
# Epoch: 50/60... Step: 850... Loss: 0.506701... Val Loss: 0.544811
# Epoch: 51/60... Step: 855... Loss: 0.620904... Val Loss: 0.552844
# Epoch: 51/60... Step: 860... Loss: 0.518482... Val Loss: 0.560072
# Epoch: 51/60... Step: 865... Loss: 0.542680... Val Loss: 0.558862
# Epoch: 52/60... Step: 870... Loss: 0.513420... Val Loss: 0.552191
# Epoch: 52/60... Step: 875... Loss: 0.515539... Val Loss: 0.543840
# Epoch: 52/60... Step: 880... Loss: 0.458258... Val Loss: 0.547380
# Epoch: 53/60... Step: 885... Loss: 0.505756... Val Loss: 0.557626
# Epoch: 53/60... Step: 890... Loss: 0.549149... Val Loss: 0.536140
# Epoch: 53/60... Step: 895... Loss: 0.525921... Val Loss: 0.544030
# Epoch: 53/60... Step: 900... Loss: 0.446171... Val Loss: 0.560128
# Epoch: 54/60... Step: 905... Loss: 0.505369... Val Loss: 0.544453
# Epoch: 54/60... Step: 910... Loss: 0.508941... Val Loss: 0.539349
# Epoch: 54/60... Step: 915... Loss: 0.545168... Val Loss: 0.553724
# Epoch: 55/60... Step: 920... Loss: 0.421431... Val Loss: 0.555957
# Epoch: 55/60... Step: 925... Loss: 0.532939... Val Loss: 0.549795
# Epoch: 55/60... Step: 930... Loss: 0.542407... Val Loss: 0.545568
# Epoch: 55/60... Step: 935... Loss: 0.434303... Val Loss: 0.538564
# Epoch: 56/60... Step: 940... Loss: 0.543566... Val Loss: 0.556457
# Epoch: 56/60... Step: 945... Loss: 0.496917... Val Loss: 0.552780
# Epoch: 56/60... Step: 950... Loss: 0.516088... Val Loss: 0.556118
# Epoch: 57/60... Step: 955... Loss: 0.457476... Val Loss: 0.549079
# Epoch: 57/60... Step: 960... Loss: 0.568530... Val Loss: 0.545332
# Epoch: 57/60... Step: 965... Loss: 0.489472... Val Loss: 0.538669
# Epoch: 58/60... Step: 970... Loss: 0.507344... Val Loss: 0.537473
# Epoch: 58/60... Step: 975... Loss: 0.530314... Val Loss: 0.546156
# Epoch: 58/60... Step: 980... Loss: 0.517039... Val Loss: 0.549920
# Epoch: 58/60... Step: 985... Loss: 0.563785... Val Loss: 0.548301
# Epoch: 59/60... Step: 990... Loss: 0.555384... Val Loss: 0.552032
# Epoch: 59/60... Step: 995... Loss: 0.454639... Val Loss: 0.547269
# Epoch: 59/60... Step: 1000... Loss: 0.542180... Val Loss: 0.545257
# Epoch: 60/60... Step: 1005... Loss: 0.503202... Val Loss: 0.541303
# Epoch: 60/60... Step: 1010... Loss: 0.525521... Val Loss: 0.541272
# Epoch: 60/60... Step: 1015... Loss: 0.472053... Val Loss: 0.542957
# Epoch: 60/60... Step: 1020... Loss: 0.529833... Val Loss: 0.543149

# %%
model_RNN_combined = RNN(input_size=input_size, output_size=output_size, hidden_dim=hidden_dim, n_layers=n_layers)
first_bce_loss_function = torch.nn.BCELoss()
second_custom_loss_function = CustomLoss()
model_RNN_combined.to(device)
# Out:
# RNN(
#   (rnn): RNN(561, 8, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (linear_1): Linear(in_features=8, out_features=4, bias=True)
#   (linear_2): Linear(in_features=4, out_features=1, bias=True)
#   (activation): Sigmoid()
#   (relu): ReLU()
# )

# %%
model_RNN_combined, (bce_loss_list, bce_acc_list, bce_overall_val_loss_list) = train_model(model_RNN_combined, first_bce_loss_function, 60, 5, 
                                    RNN_flag=True)

model_RNN_combined, (bce_loss_list, bce_acc_list, bce_overall_val_loss_list) = train_model(model_RNN_combined, second_custom_loss_function, 60, 5, 
                                    RNN_flag=True)

model_RNN_combined = model_RNN_combined.eval()
torch.save(model_RNN_combined, "experiments/model_RNN_combined.pth")
# Out:
# Epoch: 1/60... Step: 5... Loss: 0.719680... Val Loss: 0.706406
# Epoch: 1/60... Step: 10... Loss: 0.677854... Val Loss: 0.702864
# Epoch: 1/60... Step: 15... Loss: 0.696247... Val Loss: 0.700487
# Epoch: 2/60... Step: 20... Loss: 0.688427... Val Loss: 0.697147
# Epoch: 2/60... Step: 25... Loss: 0.698697... Val Loss: 0.695192
# Epoch: 2/60... Step: 30... Loss: 0.699685... Val Loss: 0.694175
# Epoch: 3/60... Step: 35... Loss: 0.685136... Val Loss: 0.693335
# Epoch: 3/60... Step: 40... Loss: 0.692990... Val Loss: 0.691590
# Epoch: 3/60... Step: 45... Loss: 0.687122... Val Loss: 0.690257
# Epoch: 3/60... Step: 50... Loss: 0.690853... Val Loss: 0.689083
# Epoch: 4/60... Step: 55... Loss: 0.701092... Val Loss: 0.688688
# Epoch: 4/60... Step: 60... Loss: 0.687134... Val Loss: 0.688019
# Epoch: 4/60... Step: 65... Loss: 0.687812... Val Loss: 0.687343
# Epoch: 5/60... Step: 70... Loss: 0.689548... Val Loss: 0.686369
# Epoch: 5/60... Step: 75... Loss: 0.688544... Val Loss: 0.685650
# Epoch: 5/60... Step: 80... Loss: 0.682014... Val Loss: 0.684615
# Epoch: 5/60... Step: 85... Loss: 0.686902... Val Loss: 0.683579
# Epoch: 6/60... Step: 90... Loss: 0.678128... Val Loss: 0.683143
# Epoch: 6/60... Step: 95... Loss: 0.685492... Val Loss: 0.682758
# Epoch: 6/60... Step: 100... Loss: 0.697482... Val Loss: 0.682515
# Epoch: 7/60... Step: 105... Loss: 0.707641... Val Loss: 0.682825
# Epoch: 7/60... Step: 110... Loss: 0.689068... Val Loss: 0.681200
# Epoch: 7/60... Step: 115... Loss: 0.678167... Val Loss: 0.680755
# Epoch: 8/60... Step: 120... Loss: 0.690758... Val Loss: 0.680178
# Epoch: 8/60... Step: 125... Loss: 0.674132... Val Loss: 0.679622
# Epoch: 8/60... Step: 130... Loss: 0.669037... Val Loss: 0.679166
# Epoch: 8/60... Step: 135... Loss: 0.691776... Val Loss: 0.678464
# Epoch: 9/60... Step: 140... Loss: 0.687538... Val Loss: 0.677648
# Epoch: 9/60... Step: 145... Loss: 0.693097... Val Loss: 0.677245
# Epoch: 9/60... Step: 150... Loss: 0.677380... Val Loss: 0.676670
# Epoch: 10/60... Step: 155... Loss: 0.683993... Val Loss: 0.675714
# Epoch: 10/60... Step: 160... Loss: 0.680951... Val Loss: 0.675230
# Epoch: 10/60... Step: 165... Loss: 0.665374... Val Loss: 0.674314
# Epoch: 10/60... Step: 170... Loss: 0.672482... Val Loss: 0.672274
# Epoch: 11/60... Step: 175... Loss: 0.670315... Val Loss: 0.670506
# Epoch: 11/60... Step: 180... Loss: 0.690354... Val Loss: 0.672058
# Epoch: 11/60... Step: 185... Loss: 0.674981... Val Loss: 0.667221
# Epoch: 12/60... Step: 190... Loss: 0.678498... Val Loss: 0.666374
# Epoch: 12/60... Step: 195... Loss: 0.667507... Val Loss: 0.664109
# Epoch: 12/60... Step: 200... Loss: 0.695827... Val Loss: 0.660193
# Epoch: 13/60... Step: 205... Loss: 0.673981... Val Loss: 0.647469
# Epoch: 13/60... Step: 210... Loss: 0.654984... Val Loss: 0.646126
# Epoch: 13/60... Step: 215... Loss: 0.690879... Val Loss: 0.643319
# Epoch: 13/60... Step: 220... Loss: 0.646108... Val Loss: 0.645171
# Epoch: 14/60... Step: 225... Loss: 0.644493... Val Loss: 0.645025
# Epoch: 14/60... Step: 230... Loss: 0.641718... Val Loss: 0.631281
# Epoch: 14/60... Step: 235... Loss: 0.662869... Val Loss: 0.636397
# Epoch: 15/60... Step: 240... Loss: 0.645775... Val Loss: 0.628505
# Epoch: 15/60... Step: 245... Loss: 0.616123... Val Loss: 0.630363
# Epoch: 15/60... Step: 250... Loss: 0.611359... Val Loss: 0.618571
# Epoch: 15/60... Step: 255... Loss: 0.627404... Val Loss: 0.616131
# Epoch: 16/60... Step: 260... Loss: 0.656757... Val Loss: 0.606494
# Epoch: 16/60... Step: 265... Loss: 0.642623... Val Loss: 0.615100
# Epoch: 16/60... Step: 270... Loss: 0.573952... Val Loss: 0.615685
# Epoch: 17/60... Step: 275... Loss: 0.582625... Val Loss: 0.603240
# Epoch: 17/60... Step: 280... Loss: 0.589116... Val Loss: 0.592390
# Epoch: 17/60... Step: 285... Loss: 0.589320... Val Loss: 0.584861
# Epoch: 18/60... Step: 290... Loss: 0.616213... Val Loss: 0.575303
# Epoch: 18/60... Step: 295... Loss: 0.610026... Val Loss: 0.596938
# Epoch: 18/60... Step: 300... Loss: 0.556495... Val Loss: 0.581544
# Epoch: 18/60... Step: 305... Loss: 0.623354... Val Loss: 0.571991
# Epoch: 19/60... Step: 310... Loss: 0.594530... Val Loss: 0.557564
# Epoch: 19/60... Step: 315... Loss: 0.582778... Val Loss: 0.589699
# Epoch: 19/60... Step: 320... Loss: 0.551906... Val Loss: 0.567509
# Epoch: 20/60... Step: 325... Loss: 0.636382... Val Loss: 0.556322
# Epoch: 20/60... Step: 330... Loss: 0.579550... Val Loss: 0.561643
# Epoch: 20/60... Step: 335... Loss: 0.559781... Val Loss: 0.566196
# Epoch: 20/60... Step: 340... Loss: 0.637882... Val Loss: 0.559647
# Epoch: 21/60... Step: 345... Loss: 0.590903... Val Loss: 0.546064
# Epoch: 21/60... Step: 350... Loss: 0.509568... Val Loss: 0.545199
# Epoch: 21/60... Step: 355... Loss: 0.573581... Val Loss: 0.566818
# Epoch: 22/60... Step: 360... Loss: 0.541504... Val Loss: 0.560235
# Epoch: 22/60... Step: 365... Loss: 0.706032... Val Loss: 0.539251
# Epoch: 22/60... Step: 370... Loss: 0.476430... Val Loss: 0.538694
# Epoch: 23/60... Step: 375... Loss: 0.599014... Val Loss: 0.569681
# Epoch: 23/60... Step: 380... Loss: 0.557288... Val Loss: 0.542842
# Epoch: 23/60... Step: 385... Loss: 0.571310... Val Loss: 0.533131
# Epoch: 23/60... Step: 390... Loss: 0.521008... Val Loss: 0.571914
# Epoch: 24/60... Step: 395... Loss: 0.550282... Val Loss: 0.569663
# Epoch: 24/60... Step: 400... Loss: 0.526496... Val Loss: 0.537718
# Epoch: 24/60... Step: 405... Loss: 0.480064... Val Loss: 0.545166
# Epoch: 25/60... Step: 410... Loss: 0.514634... Val Loss: 0.572047
# Epoch: 25/60... Step: 415... Loss: 0.619926... Val Loss: 0.541773
# Epoch: 25/60... Step: 420... Loss: 0.527420... Val Loss: 0.541895
# Epoch: 25/60... Step: 425... Loss: 0.543763... Val Loss: 0.556624
# Epoch: 26/60... Step: 430... Loss: 0.524890... Val Loss: 0.556951
# Epoch: 26/60... Step: 435... Loss: 0.547675... Val Loss: 0.552363
# Epoch: 26/60... Step: 440... Loss: 0.607416... Val Loss: 0.541710
# Epoch: 27/60... Step: 445... Loss: 0.606583... Val Loss: 0.534338
# Epoch: 27/60... Step: 450... Loss: 0.549631... Val Loss: 0.547405
# Epoch: 27/60... Step: 455... Loss: 0.554362... Val Loss: 0.563455
# Epoch: 28/60... Step: 460... Loss: 0.640866... Val Loss: 0.556943
# Epoch: 28/60... Step: 465... Loss: 0.490846... Val Loss: 0.533368
# Epoch: 28/60... Step: 470... Loss: 0.555232... Val Loss: 0.538452
# Epoch: 28/60... Step: 475... Loss: 0.505038... Val Loss: 0.556879
# Epoch: 29/60... Step: 480... Loss: 0.568056... Val Loss: 0.573130
# Epoch: 29/60... Step: 485... Loss: 0.480820... Val Loss: 0.545625
# Epoch: 29/60... Step: 490... Loss: 0.505349... Val Loss: 0.544583
# Epoch: 30/60... Step: 495... Loss: 0.546556... Val Loss: 0.553205
# Epoch: 30/60... Step: 500... Loss: 0.557354... Val Loss: 0.547057
# Epoch: 30/60... Step: 505... Loss: 0.562771... Val Loss: 0.557772
# Epoch: 30/60... Step: 510... Loss: 0.549976... Val Loss: 0.543802
# Epoch: 31/60... Step: 515... Loss: 0.555035... Val Loss: 0.546529
# Epoch: 31/60... Step: 520... Loss: 0.466407... Val Loss: 0.547793
# Epoch: 31/60... Step: 525... Loss: 0.553675... Val Loss: 0.539856
# Epoch: 32/60... Step: 530... Loss: 0.624702... Val Loss: 0.547361
# Epoch: 32/60... Step: 535... Loss: 0.587360... Val Loss: 0.538196
# Epoch: 32/60... Step: 540... Loss: 0.545753... Val Loss: 0.547699
# Epoch: 33/60... Step: 545... Loss: 0.617968... Val Loss: 0.543749
# Epoch: 33/60... Step: 550... Loss: 0.486684... Val Loss: 0.545259
# Epoch: 33/60... Step: 555... Loss: 0.571387... Val Loss: 0.540429
# Epoch: 33/60... Step: 560... Loss: 0.609514... Val Loss: 0.534186
# Epoch: 34/60... Step: 565... Loss: 0.541193... Val Loss: 0.567232
# Epoch: 34/60... Step: 570... Loss: 0.584862... Val Loss: 0.556639
# Epoch: 34/60... Step: 575... Loss: 0.584442... Val Loss: 0.537047
# Epoch: 35/60... Step: 580... Loss: 0.461976... Val Loss: 0.548474
# Epoch: 35/60... Step: 585... Loss: 0.558967... Val Loss: 0.544324
# Epoch: 35/60... Step: 590... Loss: 0.487136... Val Loss: 0.542210
# Epoch: 35/60... Step: 595... Loss: 0.628312... Val Loss: 0.555292
# Epoch: 36/60... Step: 600... Loss: 0.455577... Val Loss: 0.545103
# Epoch: 36/60... Step: 605... Loss: 0.541083... Val Loss: 0.536289
# Epoch: 36/60... Step: 610... Loss: 0.523842... Val Loss: 0.536118
# Epoch: 37/60... Step: 615... Loss: 0.471981... Val Loss: 0.551117
# Epoch: 37/60... Step: 620... Loss: 0.615573... Val Loss: 0.557693
# Epoch: 37/60... Step: 625... Loss: 0.515600... Val Loss: 0.541689
# Epoch: 38/60... Step: 630... Loss: 0.536408... Val Loss: 0.546124
# Epoch: 38/60... Step: 635... Loss: 0.451915... Val Loss: 0.559762
# Epoch: 38/60... Step: 640... Loss: 0.580059... Val Loss: 0.545555
# Epoch: 38/60... Step: 645... Loss: 0.527781... Val Loss: 0.538077
# Epoch: 39/60... Step: 650... Loss: 0.507670... Val Loss: 0.542057
# Epoch: 39/60... Step: 655... Loss: 0.592359... Val Loss: 0.556053
# Epoch: 39/60... Step: 660... Loss: 0.544922... Val Loss: 0.549741
# Epoch: 40/60... Step: 665... Loss: 0.525369... Val Loss: 0.551836
# Epoch: 40/60... Step: 670... Loss: 0.528534... Val Loss: 0.557521
# Epoch: 40/60... Step: 675... Loss: 0.435425... Val Loss: 0.570554
# Epoch: 40/60... Step: 680... Loss: 0.544410... Val Loss: 0.541746
# Epoch: 41/60... Step: 685... Loss: 0.507180... Val Loss: 0.539641
# Epoch: 41/60... Step: 690... Loss: 0.501016... Val Loss: 0.552697
# Epoch: 41/60... Step: 695... Loss: 0.485490... Val Loss: 0.532744
# Epoch: 42/60... Step: 700... Loss: 0.473462... Val Loss: 0.536210
# Epoch: 42/60... Step: 705... Loss: 0.561125... Val Loss: 0.549529
# Epoch: 42/60... Step: 710... Loss: 0.422106... Val Loss: 0.545745
# Epoch: 43/60... Step: 715... Loss: 0.514424... Val Loss: 0.554436
# Epoch: 43/60... Step: 720... Loss: 0.522330... Val Loss: 0.557164
# Epoch: 43/60... Step: 725... Loss: 0.485607... Val Loss: 0.551704
# Epoch: 43/60... Step: 730... Loss: 0.447213... Val Loss: 0.546671
# Epoch: 44/60... Step: 735... Loss: 0.564761... Val Loss: 0.540199
# Epoch: 44/60... Step: 740... Loss: 0.507533... Val Loss: 0.538777
# Epoch: 44/60... Step: 745... Loss: 0.535509... Val Loss: 0.539296
# Epoch: 45/60... Step: 750... Loss: 0.502159... Val Loss: 0.568859
# Epoch: 45/60... Step: 755... Loss: 0.457679... Val Loss: 0.553720
# Epoch: 45/60... Step: 760... Loss: 0.472081... Val Loss: 0.542762
# Epoch: 45/60... Step: 765... Loss: 0.480868... Val Loss: 0.555337
# Epoch: 46/60... Step: 770... Loss: 0.499212... Val Loss: 0.550602
# Epoch: 46/60... Step: 775... Loss: 0.548268... Val Loss: 0.547559
# Epoch: 46/60... Step: 780... Loss: 0.519311... Val Loss: 0.533241
# Epoch: 47/60... Step: 785... Loss: 0.503674... Val Loss: 0.537300
# Epoch: 47/60... Step: 790... Loss: 0.564545... Val Loss: 0.552759
# Epoch: 47/60... Step: 795... Loss: 0.558576... Val Loss: 0.546244
# Epoch: 48/60... Step: 800... Loss: 0.548441... Val Loss: 0.544001
# Epoch: 48/60... Step: 805... Loss: 0.434323... Val Loss: 0.559616
# Epoch: 48/60... Step: 810... Loss: 0.529108... Val Loss: 0.549982
# Epoch: 48/60... Step: 815... Loss: 0.587523... Val Loss: 0.537400
# Epoch: 49/60... Step: 820... Loss: 0.524352... Val Loss: 0.531389
# Epoch: 49/60... Step: 825... Loss: 0.560849... Val Loss: 0.535225
# Epoch: 49/60... Step: 830... Loss: 0.481398... Val Loss: 0.560119
# Epoch: 50/60... Step: 835... Loss: 0.569163... Val Loss: 0.540476
# Epoch: 50/60... Step: 840... Loss: 0.553218... Val Loss: 0.541513
# Epoch: 50/60... Step: 845... Loss: 0.468476... Val Loss: 0.547326
# Epoch: 50/60... Step: 850... Loss: 0.559219... Val Loss: 0.551939
# Epoch: 51/60... Step: 855... Loss: 0.572244... Val Loss: 0.547185
# Epoch: 51/60... Step: 860... Loss: 0.468850... Val Loss: 0.545095
# Epoch: 51/60... Step: 865... Loss: 0.459450... Val Loss: 0.554824
# Epoch: 52/60... Step: 870... Loss: 0.528452... Val Loss: 0.550340
# Epoch: 52/60... Step: 875... Loss: 0.459267... Val Loss: 0.539486
# Epoch: 52/60... Step: 880... Loss: 0.544644... Val Loss: 0.538810
# Epoch: 53/60... Step: 885... Loss: 0.538475... Val Loss: 0.552347
# Epoch: 53/60... Step: 890... Loss: 0.539899... Val Loss: 0.551826
# Epoch: 53/60... Step: 895... Loss: 0.504263... Val Loss: 0.545707
# Epoch: 53/60... Step: 900... Loss: 0.500211... Val Loss: 0.541644
# Epoch: 54/60... Step: 905... Loss: 0.510531... Val Loss: 0.541299
# Epoch: 54/60... Step: 910... Loss: 0.575507... Val Loss: 0.547895
# Epoch: 54/60... Step: 915... Loss: 0.470017... Val Loss: 0.550023
# Epoch: 55/60... Step: 920... Loss: 0.562347... Val Loss: 0.559804
# Epoch: 55/60... Step: 925... Loss: 0.453804... Val Loss: 0.551227
# Epoch: 55/60... Step: 930... Loss: 0.539483... Val Loss: 0.537826
# Epoch: 55/60... Step: 935... Loss: 0.571518... Val Loss: 0.533271
# Epoch: 56/60... Step: 940... Loss: 0.492735... Val Loss: 0.542404
# Epoch: 56/60... Step: 945... Loss: 0.528273... Val Loss: 0.565438
# Epoch: 56/60... Step: 950... Loss: 0.478175... Val Loss: 0.547064
# Epoch: 57/60... Step: 955... Loss: 0.572161... Val Loss: 0.545103
# Epoch: 57/60... Step: 960... Loss: 0.491638... Val Loss: 0.545803
# Epoch: 57/60... Step: 965... Loss: 0.447875... Val Loss: 0.534581
# Epoch: 58/60... Step: 970... Loss: 0.512980... Val Loss: 0.540746
# Epoch: 58/60... Step: 975... Loss: 0.534102... Val Loss: 0.556006
# Epoch: 58/60... Step: 980... Loss: 0.527718... Val Loss: 0.544219
# Epoch: 58/60... Step: 985... Loss: 0.506692... Val Loss: 0.531893
# Epoch: 59/60... Step: 990... Loss: 0.537998... Val Loss: 0.547820
# Epoch: 59/60... Step: 995... Loss: 0.477168... Val Loss: 0.550432
# Epoch: 59/60... Step: 1000... Loss: 0.491575... Val Loss: 0.532231
# Epoch: 60/60... Step: 1005... Loss: 0.437435... Val Loss: 0.538533
# Epoch: 60/60... Step: 1010... Loss: 0.487454... Val Loss: 0.557144
# Epoch: 60/60... Step: 1015... Loss: 0.517588... Val Loss: 0.550670
# Epoch: 60/60... Step: 1020... Loss: 0.569271... Val Loss: 0.537453
# Epoch: 1/60... Step: 5... Loss: -0.828948... Val Loss: -0.316317
# Epoch: 1/60... Step: 10... Loss: -0.645538... Val Loss: -0.359582
# Epoch: 1/60... Step: 15... Loss: -0.610789... Val Loss: -0.360354
# Epoch: 2/60... Step: 20... Loss: -0.912176... Val Loss: -0.410435
# Epoch: 2/60... Step: 25... Loss: -0.257916... Val Loss: -0.470979
# Epoch: 2/60... Step: 30... Loss: -0.636491... Val Loss: -0.422549
# Epoch: 3/60... Step: 35... Loss: -0.459066... Val Loss: -0.410511
# Epoch: 3/60... Step: 40... Loss: -0.585432... Val Loss: -0.446402
# Epoch: 3/60... Step: 45... Loss: -0.620523... Val Loss: -0.472807
# Epoch: 3/60... Step: 50... Loss: -0.939007... Val Loss: -0.486940
# Epoch: 4/60... Step: 55... Loss: -0.220894... Val Loss: -0.511709
# Epoch: 4/60... Step: 60... Loss: -0.855427... Val Loss: -0.469266
# Epoch: 4/60... Step: 65... Loss: -0.361480... Val Loss: -0.452184
# Epoch: 5/60... Step: 70... Loss: -0.961257... Val Loss: -0.478772
# Epoch: 5/60... Step: 75... Loss: -0.550676... Val Loss: -0.524238
# Epoch: 5/60... Step: 80... Loss: -0.778161... Val Loss: -0.536479
# Epoch: 5/60... Step: 85... Loss: -0.598758... Val Loss: -0.469119
# Epoch: 6/60... Step: 90... Loss: -0.569332... Val Loss: -0.548924
# Epoch: 6/60... Step: 95... Loss: -0.793192... Val Loss: -0.582400
# Epoch: 6/60... Step: 100... Loss: -0.738003... Val Loss: -0.597515
# Epoch: 7/60... Step: 105... Loss: -0.818009... Val Loss: -0.624935
# Epoch: 7/60... Step: 110... Loss: -1.024238... Val Loss: -0.666767
# Epoch: 7/60... Step: 115... Loss: -0.345825... Val Loss: -0.551091
# Epoch: 8/60... Step: 120... Loss: -0.663219... Val Loss: -0.689874
# Epoch: 8/60... Step: 125... Loss: -0.738906... Val Loss: -0.704019
# Epoch: 8/60... Step: 130... Loss: -0.680488... Val Loss: -0.677530
# Epoch: 8/60... Step: 135... Loss: -0.673523... Val Loss: -0.550267
# Epoch: 9/60... Step: 140... Loss: -0.944716... Val Loss: -0.672646
# Epoch: 9/60... Step: 145... Loss: -0.638431... Val Loss: -0.705960
# Epoch: 9/60... Step: 150... Loss: -0.799068... Val Loss: -0.590889
# Epoch: 10/60... Step: 155... Loss: -0.848983... Val Loss: -0.681801
# Epoch: 10/60... Step: 160... Loss: -0.772048... Val Loss: -0.680813
# Epoch: 10/60... Step: 165... Loss: -0.809486... Val Loss: -0.712011
# Epoch: 10/60... Step: 170... Loss: -0.233663... Val Loss: -0.725909
# Epoch: 11/60... Step: 175... Loss: -0.880459... Val Loss: -0.666005
# Epoch: 11/60... Step: 180... Loss: -0.653684... Val Loss: -0.785930
# Epoch: 11/60... Step: 185... Loss: -0.809462... Val Loss: -0.766096
# Epoch: 12/60... Step: 190... Loss: -0.968164... Val Loss: -0.771884
# Epoch: 12/60... Step: 195... Loss: -0.864314... Val Loss: -0.783545
# Epoch: 12/60... Step: 200... Loss: -0.647819... Val Loss: -0.765289
# Epoch: 13/60... Step: 205... Loss: -0.701955... Val Loss: -0.740497
# Epoch: 13/60... Step: 210... Loss: -0.760517... Val Loss: -0.826556
# Epoch: 13/60... Step: 215... Loss: -0.193197... Val Loss: -0.731874
# Epoch: 13/60... Step: 220... Loss: -0.524921... Val Loss: -0.795751
# Epoch: 14/60... Step: 225... Loss: -1.338257... Val Loss: -0.693732
# Epoch: 14/60... Step: 230... Loss: -0.534311... Val Loss: -0.728370
# Epoch: 14/60... Step: 235... Loss: -1.582515... Val Loss: -0.752601
# Epoch: 15/60... Step: 240... Loss: -0.929492... Val Loss: -0.718695
# Epoch: 15/60... Step: 245... Loss: -0.259192... Val Loss: -0.827252
# Epoch: 15/60... Step: 250... Loss: -0.759108... Val Loss: -0.730382
# Epoch: 15/60... Step: 255... Loss: -1.136765... Val Loss: -0.782789
# Epoch: 16/60... Step: 260... Loss: -1.252681... Val Loss: -0.573030
# Epoch: 16/60... Step: 265... Loss: -1.019649... Val Loss: -0.820788
# Epoch: 16/60... Step: 270... Loss: -0.703078... Val Loss: -0.799015
# Epoch: 17/60... Step: 275... Loss: -1.028875... Val Loss: -0.924846
# Epoch: 17/60... Step: 280... Loss: -0.961114... Val Loss: -0.707783
# Epoch: 17/60... Step: 285... Loss: -1.167906... Val Loss: -0.761153
# Epoch: 18/60... Step: 290... Loss: -0.959450... Val Loss: -0.654802
# Epoch: 18/60... Step: 295... Loss: -0.564161... Val Loss: -0.902613
# Epoch: 18/60... Step: 300... Loss: -0.834722... Val Loss: -0.866943
# Epoch: 18/60... Step: 305... Loss: -1.026416... Val Loss: -1.028802
# Epoch: 19/60... Step: 310... Loss: -0.767106... Val Loss: -0.841435
# Epoch: 19/60... Step: 315... Loss: -1.156727... Val Loss: -0.775596
# Epoch: 19/60... Step: 320... Loss: -0.573169... Val Loss: -0.761739
# Epoch: 20/60... Step: 325... Loss: -0.685546... Val Loss: -0.986575
# Epoch: 20/60... Step: 330... Loss: -0.751363... Val Loss: -0.955438
# Epoch: 20/60... Step: 335... Loss: -0.421218... Val Loss: -0.871690
# Epoch: 20/60... Step: 340... Loss: -1.045809... Val Loss: -0.883097
# Epoch: 21/60... Step: 345... Loss: -0.244007... Val Loss: -0.753682
# Epoch: 21/60... Step: 350... Loss: -1.042859... Val Loss: -0.865396
# Epoch: 21/60... Step: 355... Loss: -0.267714... Val Loss: -0.840529
# Epoch: 22/60... Step: 360... Loss: -0.867048... Val Loss: -0.734753
# Epoch: 22/60... Step: 365... Loss: -0.751368... Val Loss: -1.039306
# Epoch: 22/60... Step: 370... Loss: -0.895306... Val Loss: -0.984772
# Epoch: 23/60... Step: 375... Loss: -0.703097... Val Loss: -0.982419
# Epoch: 23/60... Step: 380... Loss: -1.608838... Val Loss: -0.833781
# Epoch: 23/60... Step: 385... Loss: -1.018565... Val Loss: -0.962092
# Epoch: 23/60... Step: 390... Loss: -1.192843... Val Loss: -1.026741
# Epoch: 24/60... Step: 395... Loss: -1.187404... Val Loss: -0.826547
# Epoch: 24/60... Step: 400... Loss: -1.030769... Val Loss: -0.823824
# Epoch: 24/60... Step: 405... Loss: -1.396220... Val Loss: -1.000517
# Epoch: 25/60... Step: 410... Loss: -0.270708... Val Loss: -0.797761
# Epoch: 25/60... Step: 415... Loss: -0.528675... Val Loss: -1.008848
# Epoch: 25/60... Step: 420... Loss: -0.976032... Val Loss: -0.949321
# Epoch: 25/60... Step: 425... Loss: -0.801627... Val Loss: -0.911583
# Epoch: 26/60... Step: 430... Loss: -0.579323... Val Loss: -0.810674
# Epoch: 26/60... Step: 435... Loss: -1.164382... Val Loss: -0.740635
# Epoch: 26/60... Step: 440... Loss: -0.925241... Val Loss: -0.830564
# Epoch: 27/60... Step: 445... Loss: -0.830843... Val Loss: -0.960055
# Epoch: 27/60... Step: 450... Loss: -1.049346... Val Loss: -0.949835
# Epoch: 27/60... Step: 455... Loss: -0.951120... Val Loss: -0.971480
# Epoch: 28/60... Step: 460... Loss: -1.197356... Val Loss: -0.929341
# Epoch: 28/60... Step: 465... Loss: -0.573860... Val Loss: -0.914750
# Epoch: 28/60... Step: 470... Loss: -1.156324... Val Loss: -0.902636
# Epoch: 28/60... Step: 475... Loss: -1.003747... Val Loss: -0.700349
# Epoch: 29/60... Step: 480... Loss: -1.778289... Val Loss: -0.962539
# Epoch: 29/60... Step: 485... Loss: -1.329258... Val Loss: -1.075722
# Epoch: 29/60... Step: 490... Loss: -1.503386... Val Loss: -0.881396
# Epoch: 30/60... Step: 495... Loss: -0.619900... Val Loss: -1.187706
# Epoch: 30/60... Step: 500... Loss: -0.565347... Val Loss: -0.612385
# Epoch: 30/60... Step: 505... Loss: -0.443631... Val Loss: -0.893438
# Epoch: 30/60... Step: 510... Loss: -0.801128... Val Loss: -1.059402
# Epoch: 31/60... Step: 515... Loss: -1.280800... Val Loss: -1.020773
# Epoch: 31/60... Step: 520... Loss: -0.758573... Val Loss: -0.952688
# Epoch: 31/60... Step: 525... Loss: -0.920429... Val Loss: -0.628714
# Epoch: 32/60... Step: 530... Loss: -0.782337... Val Loss: -1.163621
# Epoch: 32/60... Step: 535... Loss: -0.915129... Val Loss: -0.916364
# Epoch: 32/60... Step: 540... Loss: -0.665963... Val Loss: -1.062200
# Epoch: 33/60... Step: 545... Loss: -0.843688... Val Loss: -0.911260
# Epoch: 33/60... Step: 550... Loss: -0.778533... Val Loss: -0.928117
# Epoch: 33/60... Step: 555... Loss: -1.763399... Val Loss: -1.080756
# Epoch: 33/60... Step: 560... Loss: -1.318231... Val Loss: -0.874431
# Epoch: 34/60... Step: 565... Loss: -0.626599... Val Loss: -0.929499
# Epoch: 34/60... Step: 570... Loss: -0.449122... Val Loss: -0.844295
# Epoch: 34/60... Step: 575... Loss: -0.718980... Val Loss: -0.982774
# Epoch: 35/60... Step: 580... Loss: -0.928807... Val Loss: -0.894314
# Epoch: 35/60... Step: 585... Loss: -0.632199... Val Loss: -0.973266
# Epoch: 35/60... Step: 590... Loss: -0.594114... Val Loss: -0.659366
# Epoch: 35/60... Step: 595... Loss: -0.929783... Val Loss: -0.832892
# Epoch: 36/60... Step: 600... Loss: -1.043038... Val Loss: -0.905608
# Epoch: 36/60... Step: 605... Loss: -0.717461... Val Loss: -0.965111
# Epoch: 36/60... Step: 610... Loss: -1.171416... Val Loss: -0.830260
# Epoch: 37/60... Step: 615... Loss: -0.830214... Val Loss: -1.285426
# Epoch: 37/60... Step: 620... Loss: -1.165942... Val Loss: -0.969012
# Epoch: 37/60... Step: 625... Loss: -0.901319... Val Loss: -0.966620
# Epoch: 38/60... Step: 630... Loss: -0.616883... Val Loss: -0.845202
# Epoch: 38/60... Step: 635... Loss: -0.822255... Val Loss: -0.905529
# Epoch: 38/60... Step: 640... Loss: -0.932990... Val Loss: -0.842725
# Epoch: 38/60... Step: 645... Loss: -0.974125... Val Loss: -0.871867
# Epoch: 39/60... Step: 650... Loss: -0.986931... Val Loss: -0.991385
# Epoch: 39/60... Step: 655... Loss: -1.450602... Val Loss: -0.797842
# Epoch: 39/60... Step: 660... Loss: -0.175939... Val Loss: -0.979577
# Epoch: 40/60... Step: 665... Loss: -1.736142... Val Loss: -0.848142
# Epoch: 40/60... Step: 670... Loss: -0.725254... Val Loss: -1.048900
# Epoch: 40/60... Step: 675... Loss: -1.741136... Val Loss: -0.780448
# Epoch: 40/60... Step: 680... Loss: -0.565290... Val Loss: -1.125337
# Epoch: 41/60... Step: 685... Loss: -0.443117... Val Loss: -1.128133
# Epoch: 41/60... Step: 690... Loss: -1.838634... Val Loss: -0.813695
# Epoch: 41/60... Step: 695... Loss: -0.866026... Val Loss: -1.050950
# Epoch: 42/60... Step: 700... Loss: -1.399909... Val Loss: -0.999555
# Epoch: 42/60... Step: 705... Loss: -0.900114... Val Loss: -1.004448
# Epoch: 42/60... Step: 710... Loss: -1.214971... Val Loss: -0.927825
# Epoch: 43/60... Step: 715... Loss: -1.059990... Val Loss: -0.832650
# Epoch: 43/60... Step: 720... Loss: -0.869989... Val Loss: -1.144890
# Epoch: 43/60... Step: 725... Loss: -1.043827... Val Loss: -1.184295
# Epoch: 43/60... Step: 730... Loss: -1.102307... Val Loss: -0.831618
# Epoch: 44/60... Step: 735... Loss: -1.088655... Val Loss: -0.941024
# Epoch: 44/60... Step: 740... Loss: -1.287837... Val Loss: -0.837803
# Epoch: 44/60... Step: 745... Loss: -0.607965... Val Loss: -0.933452
# Epoch: 45/60... Step: 750... Loss: -1.618426... Val Loss: -0.931640
# Epoch: 45/60... Step: 755... Loss: -0.515983... Val Loss: -0.914617
# Epoch: 45/60... Step: 760... Loss: -0.820034... Val Loss: -0.965115
# Epoch: 45/60... Step: 765... Loss: -0.975420... Val Loss: -1.253662
# Epoch: 46/60... Step: 770... Loss: -1.745382... Val Loss: -1.134930
# Epoch: 46/60... Step: 775... Loss: -1.308330... Val Loss: -0.928231
# Epoch: 46/60... Step: 780... Loss: -0.976217... Val Loss: -1.143195
# Epoch: 47/60... Step: 785... Loss: -1.190232... Val Loss: -1.038843
# Epoch: 47/60... Step: 790... Loss: -0.813796... Val Loss: -0.932869
# Epoch: 47/60... Step: 795... Loss: -0.803867... Val Loss: -1.095363
# Epoch: 48/60... Step: 800... Loss: -0.550452... Val Loss: -1.223702
# Epoch: 48/60... Step: 805... Loss: -0.519221... Val Loss: -1.127950
# Epoch: 48/60... Step: 810... Loss: -1.000102... Val Loss: -0.880735
# Epoch: 48/60... Step: 815... Loss: -0.827820... Val Loss: -0.944342
# Epoch: 49/60... Step: 820... Loss: -1.188477... Val Loss: -0.806035
# Epoch: 49/60... Step: 825... Loss: -0.652996... Val Loss: -1.088592
# Epoch: 49/60... Step: 830... Loss: -1.361841... Val Loss: -1.029324
# Epoch: 50/60... Step: 835... Loss: -1.130159... Val Loss: -0.615646
# Epoch: 50/60... Step: 840... Loss: -1.386059... Val Loss: -1.112196
# Epoch: 50/60... Step: 845... Loss: -1.030705... Val Loss: -0.920261
# Epoch: 50/60... Step: 850... Loss: -1.253304... Val Loss: -0.981594
# Epoch: 51/60... Step: 855... Loss: -0.609212... Val Loss: -0.923445
# Epoch: 51/60... Step: 860... Loss: -1.739318... Val Loss: -0.889935
# Epoch: 51/60... Step: 865... Loss: -1.636559... Val Loss: -0.882630
# Epoch: 52/60... Step: 870... Loss: -0.983350... Val Loss: -0.995198
# Epoch: 52/60... Step: 875... Loss: -1.405985... Val Loss: -1.054988
# Epoch: 52/60... Step: 880... Loss: -1.312391... Val Loss: -1.172382
# Epoch: 53/60... Step: 885... Loss: -1.628826... Val Loss: -1.097883
# Epoch: 53/60... Step: 890... Loss: -0.917319... Val Loss: -0.991057
# Epoch: 53/60... Step: 895... Loss: -1.341584... Val Loss: -0.846895
# Epoch: 53/60... Step: 900... Loss: -1.437297... Val Loss: -1.144279
# Epoch: 54/60... Step: 905... Loss: -1.457392... Val Loss: -0.936761
# Epoch: 54/60... Step: 910... Loss: -1.359484... Val Loss: -0.862345
# Epoch: 54/60... Step: 915... Loss: -0.923794... Val Loss: -1.016144
# Epoch: 55/60... Step: 920... Loss: -1.353552... Val Loss: -0.955425
# Epoch: 55/60... Step: 925... Loss: -1.096335... Val Loss: -1.048530
# Epoch: 55/60... Step: 930... Loss: -0.792924... Val Loss: -1.232464
# Epoch: 55/60... Step: 935... Loss: -1.053890... Val Loss: -1.079093
# Epoch: 56/60... Step: 940... Loss: -0.907851... Val Loss: -0.865425
# Epoch: 56/60... Step: 945... Loss: -0.487293... Val Loss: -0.894815
# Epoch: 56/60... Step: 950... Loss: -1.274019... Val Loss: -1.271981
# Epoch: 57/60... Step: 955... Loss: -1.269226... Val Loss: -0.837606
# Epoch: 57/60... Step: 960... Loss: -1.686700... Val Loss: -1.194818
# Epoch: 57/60... Step: 965... Loss: -1.175585... Val Loss: -0.867730
# Epoch: 58/60... Step: 970... Loss: -1.038577... Val Loss: -1.153828
# Epoch: 58/60... Step: 975... Loss: -1.050436... Val Loss: -1.173128
# Epoch: 58/60... Step: 980... Loss: -1.180221... Val Loss: -0.898173
# Epoch: 58/60... Step: 985... Loss: -1.282601... Val Loss: -1.181956
# Epoch: 59/60... Step: 990... Loss: -0.639011... Val Loss: -0.919910
# Epoch: 59/60... Step: 995... Loss: -1.644232... Val Loss: -0.921711
# Epoch: 59/60... Step: 1000... Loss: -1.292169... Val Loss: -1.204639
# Epoch: 60/60... Step: 1005... Loss: -0.948115... Val Loss: -0.901579
# Epoch: 60/60... Step: 1010... Loss: -0.249054... Val Loss: -0.902456
# Epoch: 60/60... Step: 1015... Loss: -1.231567... Val Loss: -0.893986
# Epoch: 60/60... Step: 1020... Loss: -0.656886... Val Loss: -0.766510

# %% [markdown]
# ### GRU

# %%
class GRU(nn.Module):
    def __init__(self, input_size, output_size, hidden_dim, n_layers, drop_prob=0.5):
        
        super(GRU, self).__init__()
        self.input_size = input_size
        self.output_size = output_size
        self.n_layers = n_layers
        self.hidden_dim = hidden_dim        
        # if batch_first, than shape of lstm_in: [batch_size, seq_len, input_size]
        self.gru = nn.GRU(input_size, hidden_dim, n_layers, dropout=drop_prob, batch_first=True)
        self.dropout = nn.Dropout(drop_prob)
        self.linear_1 = nn.Linear(hidden_dim, hidden_dim//2)
        self.linear_2 = nn.Linear(hidden_dim//2, 1)
        self.activation = nn.Sigmoid()
        self.relu = nn.ReLU()
        
    def forward(self, input_seq, hidden):
        batch_size = input_seq.size(0)
        gru_out, hidden = self.gru(input_seq, hidden)  
        gru_out = gru_out.contiguous().view(-1, self.hidden_dim)      
        out = self.linear_1(gru_out)
        out = self.dropout(out)
        out = self.relu(out)
        out = self.linear_2(out)
        out = self.activation(out)
        out = out.view(batch_size, -1)

        return out, hidden

    def init_hidden(self, batch_size):
        weight = next(self.parameters()).data
        
        hidden = (weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device),
                  weight.new(self.n_layers, batch_size, self.hidden_dim).zero_().to(device))
        return hidden

# %%
model_GRU_custom = GRU(input_size=input_size, output_size=output_size, hidden_dim=hidden_dim, n_layers=n_layers)
loss_function = CustomLoss()
model_GRU_custom.to(device)
# Out:
# GRU(
#   (gru): GRU(561, 8, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (linear_1): Linear(in_features=8, out_features=4, bias=True)
#   (linear_2): Linear(in_features=4, out_features=1, bias=True)
#   (activation): Sigmoid()
#   (relu): ReLU()
# )

# %%
model_GRU_custom, (loss_list, acc_list, 
                    overall_val_loss_list) = train_model(model_GRU_custom, loss_function, 60, 5, RNN_flag=True)

model_GRU_custom = model_GRU_custom.eval()
torch.save(model_GRU_custom, "experiments/model_GRU_custom.pth")
# Out:
# Epoch: 1/60... Step: 5... Loss: 0.345438... Val Loss: 0.444715
# Epoch: 1/60... Step: 10... Loss: 0.494014... Val Loss: 0.568452
# Epoch: 1/60... Step: 15... Loss: 0.323978... Val Loss: 0.506600
# Epoch: 2/60... Step: 20... Loss: -0.059977... Val Loss: 0.422942
# Epoch: 2/60... Step: 25... Loss: -0.047119... Val Loss: 0.460765
# Epoch: 2/60... Step: 30... Loss: 0.027082... Val Loss: 0.449628
# Epoch: 3/60... Step: 35... Loss: 0.560062... Val Loss: 0.345873
# Epoch: 3/60... Step: 40... Loss: 0.275810... Val Loss: 0.331942
# Epoch: 3/60... Step: 45... Loss: -0.105161... Val Loss: 0.340160
# Epoch: 3/60... Step: 50... Loss: 0.061737... Val Loss: 0.317403
# Epoch: 4/60... Step: 55... Loss: 0.412539... Val Loss: 0.232014
# Epoch: 4/60... Step: 60... Loss: 0.366840... Val Loss: 0.290224
# Epoch: 4/60... Step: 65... Loss: -0.070730... Val Loss: 0.185579
# Epoch: 5/60... Step: 70... Loss: 0.100022... Val Loss: 0.157687
# Epoch: 5/60... Step: 75... Loss: -0.176286... Val Loss: 0.261993
# Epoch: 5/60... Step: 80... Loss: -0.069387... Val Loss: 0.232131
# Epoch: 5/60... Step: 85... Loss: 0.299520... Val Loss: 0.269544
# Epoch: 6/60... Step: 90... Loss: 0.370112... Val Loss: 0.145067
# Epoch: 6/60... Step: 95... Loss: 0.329766... Val Loss: 0.158289
# Epoch: 6/60... Step: 100... Loss: -0.019989... Val Loss: 0.113238
# Epoch: 7/60... Step: 105... Loss: 0.029718... Val Loss: 0.086679
# Epoch: 7/60... Step: 110... Loss: -0.192200... Val Loss: 0.182579
# Epoch: 7/60... Step: 115... Loss: -0.084352... Val Loss: 0.062605
# Epoch: 8/60... Step: 120... Loss: 0.336519... Val Loss: 0.085212
# Epoch: 8/60... Step: 125... Loss: -0.077096... Val Loss: 0.151768
# Epoch: 8/60... Step: 130... Loss: 0.085846... Val Loss: 0.064764
# Epoch: 8/60... Step: 135... Loss: -0.120075... Val Loss: 0.134577
# Epoch: 9/60... Step: 140... Loss: 0.213232... Val Loss: 0.056283
# Epoch: 9/60... Step: 145... Loss: -0.036822... Val Loss: 0.065895
# Epoch: 9/60... Step: 150... Loss: -0.380128... Val Loss: 0.073326
# Epoch: 10/60... Step: 155... Loss: -0.234692... Val Loss: -0.012535
# Epoch: 10/60... Step: 160... Loss: 0.104287... Val Loss: 0.020263
# Epoch: 10/60... Step: 165... Loss: -0.084567... Val Loss: -0.065093
# Epoch: 10/60... Step: 170... Loss: 0.009255... Val Loss: 0.074552
# Epoch: 11/60... Step: 175... Loss: -0.104552... Val Loss: -0.061737
# Epoch: 11/60... Step: 180... Loss: 0.226356... Val Loss: 0.059597
# Epoch: 11/60... Step: 185... Loss: -0.064508... Val Loss: -0.098164
# Epoch: 12/60... Step: 190... Loss: -0.346530... Val Loss: -0.065865
# Epoch: 12/60... Step: 195... Loss: 0.027946... Val Loss: 0.021334
# Epoch: 12/60... Step: 200... Loss: -0.393580... Val Loss: 0.024634
# Epoch: 13/60... Step: 205... Loss: 0.117454... Val Loss: -0.087677
# Epoch: 13/60... Step: 210... Loss: -0.423092... Val Loss: -0.031030
# Epoch: 13/60... Step: 215... Loss: -0.221608... Val Loss: -0.123992
# Epoch: 13/60... Step: 220... Loss: 0.027139... Val Loss: -0.081555
# Epoch: 14/60... Step: 225... Loss: -0.363216... Val Loss: -0.132578
# Epoch: 14/60... Step: 230... Loss: -0.262085... Val Loss: -0.261029
# Epoch: 14/60... Step: 235... Loss: -0.125233... Val Loss: -0.201067
# Epoch: 15/60... Step: 240... Loss: -0.358351... Val Loss: -0.148656
# Epoch: 15/60... Step: 245... Loss: -0.196817... Val Loss: -0.116000
# Epoch: 15/60... Step: 250... Loss: -0.506990... Val Loss: -0.242520
# Epoch: 15/60... Step: 255... Loss: -0.104286... Val Loss: -0.281910
# Epoch: 16/60... Step: 260... Loss: -0.324486... Val Loss: -0.221810
# Epoch: 16/60... Step: 265... Loss: -0.190338... Val Loss: -0.290979
# Epoch: 16/60... Step: 270... Loss: -0.026484... Val Loss: -0.211537
# Epoch: 17/60... Step: 275... Loss: -0.616407... Val Loss: -0.296131
# Epoch: 17/60... Step: 280... Loss: -0.277342... Val Loss: -0.374819
# Epoch: 17/60... Step: 285... Loss: -0.392657... Val Loss: -0.304643
# Epoch: 18/60... Step: 290... Loss: -0.168204... Val Loss: -0.309449
# Epoch: 18/60... Step: 295... Loss: -1.120643... Val Loss: -0.375323
# Epoch: 18/60... Step: 300... Loss: -0.242539... Val Loss: -0.356461
# Epoch: 18/60... Step: 305... Loss: -0.181285... Val Loss: -0.303086
# Epoch: 19/60... Step: 310... Loss: -0.095223... Val Loss: -0.286558
# Epoch: 19/60... Step: 315... Loss: -0.588438... Val Loss: -0.344979
# Epoch: 19/60... Step: 320... Loss: -0.570336... Val Loss: -0.365399
# Epoch: 20/60... Step: 325... Loss: -0.308319... Val Loss: -0.447639
# Epoch: 20/60... Step: 330... Loss: -0.521120... Val Loss: -0.506656
# Epoch: 20/60... Step: 335... Loss: -0.419905... Val Loss: -0.447591
# Epoch: 20/60... Step: 340... Loss: -0.561806... Val Loss: -0.468647
# Epoch: 21/60... Step: 345... Loss: -0.551332... Val Loss: -0.389201
# Epoch: 21/60... Step: 350... Loss: -0.688034... Val Loss: -0.482849
# Epoch: 21/60... Step: 355... Loss: -0.386003... Val Loss: -0.523991
# Epoch: 22/60... Step: 360... Loss: -0.579320... Val Loss: -0.497148
# Epoch: 22/60... Step: 365... Loss: -0.847841... Val Loss: -0.525362
# Epoch: 22/60... Step: 370... Loss: -0.542539... Val Loss: -0.481453
# Epoch: 23/60... Step: 375... Loss: -0.375091... Val Loss: -0.552927
# Epoch: 23/60... Step: 380... Loss: -0.774371... Val Loss: -0.515698
# Epoch: 23/60... Step: 385... Loss: -0.058542... Val Loss: -0.555671
# Epoch: 23/60... Step: 390... Loss: -0.589187... Val Loss: -0.559066
# Epoch: 24/60... Step: 395... Loss: -0.961954... Val Loss: -0.580186
# Epoch: 24/60... Step: 400... Loss: -0.865015... Val Loss: -0.581492
# Epoch: 24/60... Step: 405... Loss: -0.418554... Val Loss: -0.533172
# Epoch: 25/60... Step: 410... Loss: -0.543350... Val Loss: -0.545032
# Epoch: 25/60... Step: 415... Loss: -0.493284... Val Loss: -0.684558
# Epoch: 25/60... Step: 420... Loss: -0.203698... Val Loss: -0.583639
# Epoch: 25/60... Step: 425... Loss: -1.103176... Val Loss: -0.666467
# Epoch: 26/60... Step: 430... Loss: -0.287156... Val Loss: -0.615419
# Epoch: 26/60... Step: 435... Loss: -0.595436... Val Loss: -0.690237
# Epoch: 26/60... Step: 440... Loss: -0.878670... Val Loss: -0.756485
# Epoch: 27/60... Step: 445... Loss: -0.568019... Val Loss: -0.608251
# Epoch: 27/60... Step: 450... Loss: -0.294198... Val Loss: -0.744298
# Epoch: 27/60... Step: 455... Loss: -0.381131... Val Loss: -0.707887
# Epoch: 28/60... Step: 460... Loss: -0.137657... Val Loss: -0.671159
# Epoch: 28/60... Step: 465... Loss: -1.080107... Val Loss: -0.627653
# Epoch: 28/60... Step: 470... Loss: -0.642917... Val Loss: -0.722680
# Epoch: 28/60... Step: 475... Loss: -0.356269... Val Loss: -0.627581
# Epoch: 29/60... Step: 480... Loss: -0.424434... Val Loss: -0.701229
# Epoch: 29/60... Step: 485... Loss: -0.419875... Val Loss: -0.776205
# Epoch: 29/60... Step: 490... Loss: -0.635896... Val Loss: -0.737957
# Epoch: 30/60... Step: 495... Loss: -0.714277... Val Loss: -0.634327
# Epoch: 30/60... Step: 500... Loss: -0.962086... Val Loss: -0.797666
# Epoch: 30/60... Step: 505... Loss: -0.667092... Val Loss: -0.627733
# Epoch: 30/60... Step: 510... Loss: -0.449030... Val Loss: -0.791341
# Epoch: 31/60... Step: 515... Loss: -1.012323... Val Loss: -0.611934
# Epoch: 31/60... Step: 520... Loss: -0.752024... Val Loss: -0.735631
# Epoch: 31/60... Step: 525... Loss: -0.713476... Val Loss: -0.856365
# Epoch: 32/60... Step: 530... Loss: -0.882407... Val Loss: -0.774716
# Epoch: 32/60... Step: 535... Loss: -0.587980... Val Loss: -0.807821
# Epoch: 32/60... Step: 540... Loss: -0.491746... Val Loss: -0.894600
# Epoch: 33/60... Step: 545... Loss: -0.485823... Val Loss: -0.841179
# Epoch: 33/60... Step: 550... Loss: -0.688822... Val Loss: -0.810692
# Epoch: 33/60... Step: 555... Loss: -0.683566... Val Loss: -0.754233
# Epoch: 33/60... Step: 560... Loss: -0.949808... Val Loss: -0.444340
# Epoch: 34/60... Step: 565... Loss: -1.133248... Val Loss: -0.795115
# Epoch: 34/60... Step: 570... Loss: -0.158459... Val Loss: -0.698288
# Epoch: 34/60... Step: 575... Loss: -0.385581... Val Loss: -0.829273
# Epoch: 35/60... Step: 580... Loss: -0.457627... Val Loss: -0.653810
# Epoch: 35/60... Step: 585... Loss: -0.157593... Val Loss: -0.820802
# Epoch: 35/60... Step: 590... Loss: -0.576530... Val Loss: -0.698257
# Epoch: 35/60... Step: 595... Loss: -0.710371... Val Loss: -0.842646
# Epoch: 36/60... Step: 600... Loss: -0.413780... Val Loss: -0.741555
# Epoch: 36/60... Step: 605... Loss: -1.118405... Val Loss: -0.982999
# Epoch: 36/60... Step: 610... Loss: -0.542970... Val Loss: -0.851111
# Epoch: 37/60... Step: 615... Loss: 0.187442... Val Loss: -0.929197
# Epoch: 37/60... Step: 620... Loss: -0.562451... Val Loss: -0.934144
# Epoch: 37/60... Step: 625... Loss: -1.077954... Val Loss: -0.753449
# Epoch: 38/60... Step: 630... Loss: -0.012139... Val Loss: -0.742319
# Epoch: 38/60... Step: 635... Loss: -0.563127... Val Loss: -0.954300
# Epoch: 38/60... Step: 640... Loss: -0.292070... Val Loss: -0.844959
# Epoch: 38/60... Step: 645... Loss: -0.745548... Val Loss: -0.972807
# Epoch: 39/60... Step: 650... Loss: -0.270394... Val Loss: -0.672930
# Epoch: 39/60... Step: 655... Loss: -0.457750... Val Loss: -0.660342
# Epoch: 39/60... Step: 660... Loss: -0.633081... Val Loss: -0.761030
# Epoch: 40/60... Step: 665... Loss: -0.416730... Val Loss: -0.967220
# Epoch: 40/60... Step: 670... Loss: -0.623049... Val Loss: -0.968349
# Epoch: 40/60... Step: 675... Loss: -0.473342... Val Loss: -0.962897
# Epoch: 40/60... Step: 680... Loss: -1.460575... Val Loss: -0.635575
# Epoch: 41/60... Step: 685... Loss: -0.306486... Val Loss: -0.776101
# Epoch: 41/60... Step: 690... Loss: -0.934681... Val Loss: -0.834682
# Epoch: 41/60... Step: 695... Loss: -0.507455... Val Loss: -0.897351
# Epoch: 42/60... Step: 700... Loss: -0.611431... Val Loss: -0.946757
# Epoch: 42/60... Step: 705... Loss: -0.360709... Val Loss: -1.043983
# Epoch: 42/60... Step: 710... Loss: -1.166687... Val Loss: -0.940614
# Epoch: 43/60... Step: 715... Loss: -0.843333... Val Loss: -0.659803
# Epoch: 43/60... Step: 720... Loss: -1.384303... Val Loss: -0.806585
# Epoch: 43/60... Step: 725... Loss: -0.246429... Val Loss: -0.833780
# Epoch: 43/60... Step: 730... Loss: -0.993885... Val Loss: -0.847614
# Epoch: 44/60... Step: 735... Loss: -0.304318... Val Loss: -0.926576
# Epoch: 44/60... Step: 740... Loss: -1.072340... Val Loss: -0.769032
# Epoch: 44/60... Step: 745... Loss: -0.966562... Val Loss: -0.784675
# Epoch: 45/60... Step: 750... Loss: -0.740336... Val Loss: -0.834955
# Epoch: 45/60... Step: 755... Loss: -1.110998... Val Loss: -1.050649
# Epoch: 45/60... Step: 760... Loss: -0.888900... Val Loss: -0.919850
# Epoch: 45/60... Step: 765... Loss: -0.559645... Val Loss: -0.905920
# Epoch: 46/60... Step: 770... Loss: -1.100325... Val Loss: -0.956302
# Epoch: 46/60... Step: 775... Loss: -0.030003... Val Loss: -0.908796
# Epoch: 46/60... Step: 780... Loss: -0.391468... Val Loss: -1.069878
# Epoch: 47/60... Step: 785... Loss: -0.243570... Val Loss: -0.943970
# Epoch: 47/60... Step: 790... Loss: -0.415496... Val Loss: -0.914589
# Epoch: 47/60... Step: 795... Loss: -0.414985... Val Loss: -0.804707
# Epoch: 48/60... Step: 800... Loss: -0.512260... Val Loss: -0.979134
# Epoch: 48/60... Step: 805... Loss: -0.002069... Val Loss: -0.971175
# Epoch: 48/60... Step: 810... Loss: -0.687595... Val Loss: -1.136059
# Epoch: 48/60... Step: 815... Loss: -0.440665... Val Loss: -1.101426
# Epoch: 49/60... Step: 820... Loss: -0.364538... Val Loss: -1.020697
# Epoch: 49/60... Step: 825... Loss: -0.406996... Val Loss: -0.940356
# Epoch: 49/60... Step: 830... Loss: -0.166304... Val Loss: -0.800670
# Epoch: 50/60... Step: 835... Loss: -1.097794... Val Loss: -0.982021
# Epoch: 50/60... Step: 840... Loss: 0.227171... Val Loss: -1.001213
# Epoch: 50/60... Step: 845... Loss: -0.093917... Val Loss: -0.886711
# Epoch: 50/60... Step: 850... Loss: -0.977385... Val Loss: -0.998470
# Epoch: 51/60... Step: 855... Loss: -1.127971... Val Loss: -1.016206
# Epoch: 51/60... Step: 860... Loss: -1.188045... Val Loss: -0.850021
# Epoch: 51/60... Step: 865... Loss: -0.809410... Val Loss: -0.892008
# Epoch: 52/60... Step: 870... Loss: -0.627927... Val Loss: -0.986243
# Epoch: 52/60... Step: 875... Loss: -0.766436... Val Loss: -0.856229
# Epoch: 52/60... Step: 880... Loss: -0.300541... Val Loss: -1.011462
# Epoch: 53/60... Step: 885... Loss: -0.576466... Val Loss: -0.828999
# Epoch: 53/60... Step: 890... Loss: -0.939037... Val Loss: -0.838597
# Epoch: 53/60... Step: 895... Loss: -0.732022... Val Loss: -0.838468
# Epoch: 53/60... Step: 900... Loss: -0.383845... Val Loss: -0.987965
# Epoch: 54/60... Step: 905... Loss: -0.448862... Val Loss: -0.971658
# Epoch: 54/60... Step: 910... Loss: -0.461248... Val Loss: -0.920964
# Epoch: 54/60... Step: 915... Loss: -0.492630... Val Loss: -0.912640
# Epoch: 55/60... Step: 920... Loss: -0.343607... Val Loss: -1.077863
# Epoch: 55/60... Step: 925... Loss: -0.640774... Val Loss: -0.921664
# Epoch: 55/60... Step: 930... Loss: -0.515229... Val Loss: -0.935066
# Epoch: 55/60... Step: 935... Loss: -0.408374... Val Loss: -1.085064
# Epoch: 56/60... Step: 940... Loss: -0.741093... Val Loss: -0.640357
# Epoch: 56/60... Step: 945... Loss: -1.290078... Val Loss: -0.906273
# Epoch: 56/60... Step: 950... Loss: -0.246634... Val Loss: -0.998025
# Epoch: 57/60... Step: 955... Loss: -1.206413... Val Loss: -1.012332
# Epoch: 57/60... Step: 960... Loss: -0.361920... Val Loss: -1.035770
# Epoch: 57/60... Step: 965... Loss: -1.138362... Val Loss: -1.073378
# Epoch: 58/60... Step: 970... Loss: -0.364371... Val Loss: -0.932063
# Epoch: 58/60... Step: 975... Loss: -0.438965... Val Loss: -1.015465
# Epoch: 58/60... Step: 980... Loss: -1.191623... Val Loss: -0.902466
# Epoch: 58/60... Step: 985... Loss: -1.344314... Val Loss: -1.051271
# Epoch: 59/60... Step: 990... Loss: -1.112338... Val Loss: -0.944572
# Epoch: 59/60... Step: 995... Loss: -0.694656... Val Loss: -1.103028
# Epoch: 59/60... Step: 1000... Loss: -0.167380... Val Loss: -1.087217
# Epoch: 60/60... Step: 1005... Loss: -0.406562... Val Loss: -0.879608
# Epoch: 60/60... Step: 1010... Loss: -1.119696... Val Loss: -1.008285
# Epoch: 60/60... Step: 1015... Loss: -0.568773... Val Loss: -1.155373
# Epoch: 60/60... Step: 1020... Loss: -0.885832... Val Loss: -1.187654

# %%
plt.plot(acc_list)

# %%
model_GRU_bce = GRU(input_size=input_size, output_size=output_size, hidden_dim=hidden_dim, n_layers=n_layers)
bce_loss_function = torch.nn.BCELoss()
model_GRU_bce.to(device)
# Out:
# GRU(
#   (gru): GRU(561, 8, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (linear_1): Linear(in_features=8, out_features=4, bias=True)
#   (linear_2): Linear(in_features=4, out_features=1, bias=True)
#   (activation): Sigmoid()
#   (relu): ReLU()
# )

# %%
model_GRU_bce, (bce_loss_list, bce_acc_list, bce_overall_val_loss_list) = train_model(model_GRU_bce, bce_loss_function, 
                                                                                       60, 5, RNN_flag=True)

model_GRU_bce = model_GRU_bce.eval()
torch.save(model_GRU_bce, "experiments/model_GRU_bce.pth")
# Out:
# Epoch: 1/60... Step: 5... Loss: 0.717643... Val Loss: 0.707734
# Epoch: 1/60... Step: 10... Loss: 0.697684... Val Loss: 0.705299
# Epoch: 1/60... Step: 15... Loss: 0.703181... Val Loss: 0.700004
# Epoch: 2/60... Step: 20... Loss: 0.676534... Val Loss: 0.695873
# Epoch: 2/60... Step: 25... Loss: 0.682544... Val Loss: 0.686407
# Epoch: 2/60... Step: 30... Loss: 0.680458... Val Loss: 0.679524
# Epoch: 3/60... Step: 35... Loss: 0.696028... Val Loss: 0.674762
# Epoch: 3/60... Step: 40... Loss: 0.681240... Val Loss: 0.672316
# Epoch: 3/60... Step: 45... Loss: 0.668775... Val Loss: 0.668585
# Epoch: 3/60... Step: 50... Loss: 0.678106... Val Loss: 0.665330
# Epoch: 4/60... Step: 55... Loss: 0.655585... Val Loss: 0.663919
# Epoch: 4/60... Step: 60... Loss: 0.675609... Val Loss: 0.660508
# Epoch: 4/60... Step: 65... Loss: 0.661970... Val Loss: 0.653940
# Epoch: 5/60... Step: 70... Loss: 0.662828... Val Loss: 0.656452
# Epoch: 5/60... Step: 75... Loss: 0.665078... Val Loss: 0.654398
# Epoch: 5/60... Step: 80... Loss: 0.675710... Val Loss: 0.649355
# Epoch: 5/60... Step: 85... Loss: 0.659397... Val Loss: 0.643424
# Epoch: 6/60... Step: 90... Loss: 0.636364... Val Loss: 0.641767
# Epoch: 6/60... Step: 95... Loss: 0.642530... Val Loss: 0.636443
# Epoch: 6/60... Step: 100... Loss: 0.655714... Val Loss: 0.635415
# Epoch: 7/60... Step: 105... Loss: 0.646962... Val Loss: 0.637604
# Epoch: 7/60... Step: 110... Loss: 0.631715... Val Loss: 0.628038
# Epoch: 7/60... Step: 115... Loss: 0.642312... Val Loss: 0.624160
# Epoch: 8/60... Step: 120... Loss: 0.626799... Val Loss: 0.619139
# Epoch: 8/60... Step: 125... Loss: 0.597295... Val Loss: 0.617602
# Epoch: 8/60... Step: 130... Loss: 0.672191... Val Loss: 0.611625
# Epoch: 8/60... Step: 135... Loss: 0.569721... Val Loss: 0.614158
# Epoch: 9/60... Step: 140... Loss: 0.552837... Val Loss: 0.601648
# Epoch: 9/60... Step: 145... Loss: 0.645509... Val Loss: 0.605293
# Epoch: 9/60... Step: 150... Loss: 0.605578... Val Loss: 0.594404
# Epoch: 10/60... Step: 155... Loss: 0.577363... Val Loss: 0.585914
# Epoch: 10/60... Step: 160... Loss: 0.578874... Val Loss: 0.592996
# Epoch: 10/60... Step: 165... Loss: 0.588499... Val Loss: 0.584580
# Epoch: 10/60... Step: 170... Loss: 0.600377... Val Loss: 0.584239
# Epoch: 11/60... Step: 175... Loss: 0.630713... Val Loss: 0.593979
# Epoch: 11/60... Step: 180... Loss: 0.579471... Val Loss: 0.574697
# Epoch: 11/60... Step: 185... Loss: 0.578547... Val Loss: 0.573178
# Epoch: 12/60... Step: 190... Loss: 0.605962... Val Loss: 0.571579
# Epoch: 12/60... Step: 195... Loss: 0.564522... Val Loss: 0.564975
# Epoch: 12/60... Step: 200... Loss: 0.537204... Val Loss: 0.558170
# Epoch: 13/60... Step: 205... Loss: 0.578350... Val Loss: 0.573226
# Epoch: 13/60... Step: 210... Loss: 0.546057... Val Loss: 0.552666
# Epoch: 13/60... Step: 215... Loss: 0.505982... Val Loss: 0.553988
# Epoch: 13/60... Step: 220... Loss: 0.585476... Val Loss: 0.556994
# Epoch: 14/60... Step: 225... Loss: 0.539980... Val Loss: 0.552088
# Epoch: 14/60... Step: 230... Loss: 0.545310... Val Loss: 0.595695
# Epoch: 14/60... Step: 235... Loss: 0.542690... Val Loss: 0.555523
# Epoch: 15/60... Step: 240... Loss: 0.578110... Val Loss: 0.552605
# Epoch: 15/60... Step: 245... Loss: 0.543952... Val Loss: 0.548395
# Epoch: 15/60... Step: 250... Loss: 0.473330... Val Loss: 0.553852
# Epoch: 15/60... Step: 255... Loss: 0.569215... Val Loss: 0.541056
# Epoch: 16/60... Step: 260... Loss: 0.569609... Val Loss: 0.539623
# Epoch: 16/60... Step: 265... Loss: 0.533614... Val Loss: 0.584184
# Epoch: 16/60... Step: 270... Loss: 0.593512... Val Loss: 0.547908
# Epoch: 17/60... Step: 275... Loss: 0.584853... Val Loss: 0.539427
# Epoch: 17/60... Step: 280... Loss: 0.672041... Val Loss: 0.567960
# Epoch: 17/60... Step: 285... Loss: 0.567488... Val Loss: 0.559217
# Epoch: 18/60... Step: 290... Loss: 0.544079... Val Loss: 0.540975
# Epoch: 18/60... Step: 295... Loss: 0.515766... Val Loss: 0.575044
# Epoch: 18/60... Step: 300... Loss: 0.509329... Val Loss: 0.537959
# Epoch: 18/60... Step: 305... Loss: 0.591080... Val Loss: 0.537860
# Epoch: 19/60... Step: 310... Loss: 0.581886... Val Loss: 0.552764
# Epoch: 19/60... Step: 315... Loss: 0.559742... Val Loss: 0.540635
# Epoch: 19/60... Step: 320... Loss: 0.539576... Val Loss: 0.537100
# Epoch: 20/60... Step: 325... Loss: 0.549722... Val Loss: 0.554823
# Epoch: 20/60... Step: 330... Loss: 0.515523... Val Loss: 0.532444
# Epoch: 20/60... Step: 335... Loss: 0.638106... Val Loss: 0.532320
# Epoch: 20/60... Step: 340... Loss: 0.573458... Val Loss: 0.552756
# Epoch: 21/60... Step: 345... Loss: 0.514563... Val Loss: 0.536331
# Epoch: 21/60... Step: 350... Loss: 0.557402... Val Loss: 0.539475
# Epoch: 21/60... Step: 355... Loss: 0.579706... Val Loss: 0.536186
# Epoch: 22/60... Step: 360... Loss: 0.499400... Val Loss: 0.538531
# Epoch: 22/60... Step: 365... Loss: 0.559088... Val Loss: 0.529031
# Epoch: 22/60... Step: 370... Loss: 0.495457... Val Loss: 0.541917
# Epoch: 23/60... Step: 375... Loss: 0.532470... Val Loss: 0.528348
# Epoch: 23/60... Step: 380... Loss: 0.481877... Val Loss: 0.531180
# Epoch: 23/60... Step: 385... Loss: 0.579318... Val Loss: 0.541486
# Epoch: 23/60... Step: 390... Loss: 0.604708... Val Loss: 0.537307
# Epoch: 24/60... Step: 395... Loss: 0.513029... Val Loss: 0.527663
# Epoch: 24/60... Step: 400... Loss: 0.536076... Val Loss: 0.527381
# Epoch: 24/60... Step: 405... Loss: 0.501017... Val Loss: 0.532508
# Epoch: 25/60... Step: 410... Loss: 0.500068... Val Loss: 0.535125
# Epoch: 25/60... Step: 415... Loss: 0.564220... Val Loss: 0.543938
# Epoch: 25/60... Step: 420... Loss: 0.595650... Val Loss: 0.534242
# Epoch: 25/60... Step: 425... Loss: 0.529009... Val Loss: 0.555627
# Epoch: 26/60... Step: 430... Loss: 0.526217... Val Loss: 0.537651
# Epoch: 26/60... Step: 435... Loss: 0.523550... Val Loss: 0.534654
# Epoch: 26/60... Step: 440... Loss: 0.539170... Val Loss: 0.543926
# Epoch: 27/60... Step: 445... Loss: 0.600701... Val Loss: 0.527723
# Epoch: 27/60... Step: 450... Loss: 0.501236... Val Loss: 0.535835
# Epoch: 27/60... Step: 455... Loss: 0.449535... Val Loss: 0.525518
# Epoch: 28/60... Step: 460... Loss: 0.554077... Val Loss: 0.527677
# Epoch: 28/60... Step: 465... Loss: 0.537531... Val Loss: 0.549790
# Epoch: 28/60... Step: 470... Loss: 0.472198... Val Loss: 0.543515
# Epoch: 28/60... Step: 475... Loss: 0.554411... Val Loss: 0.530526
# Epoch: 29/60... Step: 480... Loss: 0.531348... Val Loss: 0.537073
# Epoch: 29/60... Step: 485... Loss: 0.529122... Val Loss: 0.524605
# Epoch: 29/60... Step: 490... Loss: 0.513273... Val Loss: 0.547325
# Epoch: 30/60... Step: 495... Loss: 0.623614... Val Loss: 0.523336
# Epoch: 30/60... Step: 500... Loss: 0.518302... Val Loss: 0.532421
# Epoch: 30/60... Step: 505... Loss: 0.566142... Val Loss: 0.537150
# Epoch: 30/60... Step: 510... Loss: 0.576336... Val Loss: 0.532871
# Epoch: 31/60... Step: 515... Loss: 0.539351... Val Loss: 0.545410
# Epoch: 31/60... Step: 520... Loss: 0.480546... Val Loss: 0.552693
# Epoch: 31/60... Step: 525... Loss: 0.541587... Val Loss: 0.539251
# Epoch: 32/60... Step: 530... Loss: 0.504310... Val Loss: 0.529740
# Epoch: 32/60... Step: 535... Loss: 0.684338... Val Loss: 0.561261
# Epoch: 32/60... Step: 540... Loss: 0.524508... Val Loss: 0.529570
# Epoch: 33/60... Step: 545... Loss: 0.563994... Val Loss: 0.522045
# Epoch: 33/60... Step: 550... Loss: 0.453013... Val Loss: 0.542498
# Epoch: 33/60... Step: 555... Loss: 0.516427... Val Loss: 0.524766
# Epoch: 33/60... Step: 560... Loss: 0.450253... Val Loss: 0.524356
# Epoch: 34/60... Step: 565... Loss: 0.481355... Val Loss: 0.528670
# Epoch: 34/60... Step: 570... Loss: 0.547256... Val Loss: 0.538076
# Epoch: 34/60... Step: 575... Loss: 0.579455... Val Loss: 0.525328
# Epoch: 35/60... Step: 580... Loss: 0.487409... Val Loss: 0.537298
# Epoch: 35/60... Step: 585... Loss: 0.538145... Val Loss: 0.522754
# Epoch: 35/60... Step: 590... Loss: 0.522432... Val Loss: 0.524328
# Epoch: 35/60... Step: 595... Loss: 0.481991... Val Loss: 0.538963
# Epoch: 36/60... Step: 600... Loss: 0.447282... Val Loss: 0.522840
# Epoch: 36/60... Step: 605... Loss: 0.555831... Val Loss: 0.526566
# Epoch: 36/60... Step: 610... Loss: 0.449761... Val Loss: 0.523261
# Epoch: 37/60... Step: 615... Loss: 0.541799... Val Loss: 0.519250
# Epoch: 37/60... Step: 620... Loss: 0.539586... Val Loss: 0.536058
# Epoch: 37/60... Step: 625... Loss: 0.591614... Val Loss: 0.524348
# Epoch: 38/60... Step: 630... Loss: 0.477794... Val Loss: 0.529171
# Epoch: 38/60... Step: 635... Loss: 0.530794... Val Loss: 0.539906
# Epoch: 38/60... Step: 640... Loss: 0.485558... Val Loss: 0.527511
# Epoch: 38/60... Step: 645... Loss: 0.519273... Val Loss: 0.521712
# Epoch: 39/60... Step: 650... Loss: 0.540296... Val Loss: 0.542136
# Epoch: 39/60... Step: 655... Loss: 0.486229... Val Loss: 0.528606
# Epoch: 39/60... Step: 660... Loss: 0.482154... Val Loss: 0.520080
# Epoch: 40/60... Step: 665... Loss: 0.600104... Val Loss: 0.555495
# Epoch: 40/60... Step: 670... Loss: 0.454909... Val Loss: 0.520250
# Epoch: 40/60... Step: 675... Loss: 0.478915... Val Loss: 0.519522
# Epoch: 40/60... Step: 680... Loss: 0.512793... Val Loss: 0.532664
# Epoch: 41/60... Step: 685... Loss: 0.491941... Val Loss: 0.531203
# Epoch: 41/60... Step: 690... Loss: 0.603633... Val Loss: 0.523777
# Epoch: 41/60... Step: 695... Loss: 0.531751... Val Loss: 0.524051
# Epoch: 42/60... Step: 700... Loss: 0.500229... Val Loss: 0.524054
# Epoch: 42/60... Step: 705... Loss: 0.540766... Val Loss: 0.533433
# Epoch: 42/60... Step: 710... Loss: 0.547783... Val Loss: 0.526869
# Epoch: 43/60... Step: 715... Loss: 0.448968... Val Loss: 0.521799
# Epoch: 43/60... Step: 720... Loss: 0.528926... Val Loss: 0.522526
# Epoch: 43/60... Step: 725... Loss: 0.516409... Val Loss: 0.552700
# Epoch: 43/60... Step: 730... Loss: 0.483457... Val Loss: 0.528060
# Epoch: 44/60... Step: 735... Loss: 0.524772... Val Loss: 0.531268
# Epoch: 44/60... Step: 740... Loss: 0.499280... Val Loss: 0.551848
# Epoch: 44/60... Step: 745... Loss: 0.502781... Val Loss: 0.523460
# Epoch: 45/60... Step: 750... Loss: 0.534253... Val Loss: 0.523724
# Epoch: 45/60... Step: 755... Loss: 0.531636... Val Loss: 0.533953
# Epoch: 45/60... Step: 760... Loss: 0.556120... Val Loss: 0.527262
# Epoch: 45/60... Step: 765... Loss: 0.538969... Val Loss: 0.531674
# Epoch: 46/60... Step: 770... Loss: 0.537019... Val Loss: 0.525432
# Epoch: 46/60... Step: 775... Loss: 0.510974... Val Loss: 0.528122
# Epoch: 46/60... Step: 780... Loss: 0.557753... Val Loss: 0.523915
# Epoch: 47/60... Step: 785... Loss: 0.453200... Val Loss: 0.526633
# Epoch: 47/60... Step: 790... Loss: 0.519719... Val Loss: 0.531865
# Epoch: 47/60... Step: 795... Loss: 0.463040... Val Loss: 0.520447
# Epoch: 48/60... Step: 800... Loss: 0.466061... Val Loss: 0.523431
# Epoch: 48/60... Step: 805... Loss: 0.471437... Val Loss: 0.544662
# Epoch: 48/60... Step: 810... Loss: 0.486134... Val Loss: 0.521706
# Epoch: 48/60... Step: 815... Loss: 0.501191... Val Loss: 0.523311
# Epoch: 49/60... Step: 820... Loss: 0.449933... Val Loss: 0.522206
# Epoch: 49/60... Step: 825... Loss: 0.487846... Val Loss: 0.537564
# Epoch: 49/60... Step: 830... Loss: 0.511004... Val Loss: 0.525826
# Epoch: 50/60... Step: 835... Loss: 0.491224... Val Loss: 0.527475
# Epoch: 50/60... Step: 840... Loss: 0.458675... Val Loss: 0.545580
# Epoch: 50/60... Step: 845... Loss: 0.506242... Val Loss: 0.522374
# Epoch: 50/60... Step: 850... Loss: 0.563411... Val Loss: 0.521116
# Epoch: 51/60... Step: 855... Loss: 0.456623... Val Loss: 0.540207
# Epoch: 51/60... Step: 860... Loss: 0.495810... Val Loss: 0.520308
# Epoch: 51/60... Step: 865... Loss: 0.399764... Val Loss: 0.518435
# Epoch: 52/60... Step: 870... Loss: 0.529050... Val Loss: 0.520593
# Epoch: 52/60... Step: 875... Loss: 0.487650... Val Loss: 0.518678
# Epoch: 52/60... Step: 880... Loss: 0.502906... Val Loss: 0.520366
# Epoch: 53/60... Step: 885... Loss: 0.415048... Val Loss: 0.515370
# Epoch: 53/60... Step: 890... Loss: 0.557510... Val Loss: 0.516205
# Epoch: 53/60... Step: 895... Loss: 0.445362... Val Loss: 0.514243
# Epoch: 53/60... Step: 900... Loss: 0.484457... Val Loss: 0.521426
# Epoch: 54/60... Step: 905... Loss: 0.414757... Val Loss: 0.516594
# Epoch: 54/60... Step: 910... Loss: 0.487108... Val Loss: 0.517520
# Epoch: 54/60... Step: 915... Loss: 0.440089... Val Loss: 0.524719
# Epoch: 55/60... Step: 920... Loss: 0.441152... Val Loss: 0.537326
# Epoch: 55/60... Step: 925... Loss: 0.535237... Val Loss: 0.526220
# Epoch: 55/60... Step: 930... Loss: 0.455982... Val Loss: 0.527806
# Epoch: 55/60... Step: 935... Loss: 0.450605... Val Loss: 0.526963
# Epoch: 56/60... Step: 940... Loss: 0.433421... Val Loss: 0.527343
# Epoch: 56/60... Step: 945... Loss: 0.543419... Val Loss: 0.529213
# Epoch: 56/60... Step: 950... Loss: 0.501338... Val Loss: 0.522483
# Epoch: 57/60... Step: 955... Loss: 0.526471... Val Loss: 0.526216
# Epoch: 57/60... Step: 960... Loss: 0.440936... Val Loss: 0.521618
# Epoch: 57/60... Step: 965... Loss: 0.532122... Val Loss: 0.519947
# Epoch: 58/60... Step: 970... Loss: 0.522166... Val Loss: 0.534330
# Epoch: 58/60... Step: 975... Loss: 0.443210... Val Loss: 0.531573
# Epoch: 58/60... Step: 980... Loss: 0.477797... Val Loss: 0.522475
# Epoch: 58/60... Step: 985... Loss: 0.421789... Val Loss: 0.528813
# Epoch: 59/60... Step: 990... Loss: 0.470207... Val Loss: 0.525329
# Epoch: 59/60... Step: 995... Loss: 0.466292... Val Loss: 0.521124
# Epoch: 59/60... Step: 1000... Loss: 0.517362... Val Loss: 0.535681
# Epoch: 60/60... Step: 1005... Loss: 0.396719... Val Loss: 0.520322
# Epoch: 60/60... Step: 1010... Loss: 0.565727... Val Loss: 0.519459
# Epoch: 60/60... Step: 1015... Loss: 0.481421... Val Loss: 0.545834
# Epoch: 60/60... Step: 1020... Loss: 0.433877... Val Loss: 0.525246

# %%
model_GRU_combined = GRU(input_size=input_size, output_size=output_size, hidden_dim=hidden_dim, n_layers=n_layers)
first_bce_loss_function = torch.nn.BCELoss()
second_custom_loss_function = CustomLoss()
model_GRU_combined.to(device)
# Out:
# GRU(
#   (gru): GRU(561, 8, num_layers=2, batch_first=True, dropout=0.5)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (linear_1): Linear(in_features=8, out_features=4, bias=True)
#   (linear_2): Linear(in_features=4, out_features=1, bias=True)
#   (activation): Sigmoid()
#   (relu): ReLU()
# )

# %%
model_GRU_combined, (bce_loss_list, bce_acc_list, bce_overall_val_loss_list) = train_model(model_GRU_combined, first_bce_loss_function, 60, 5, 
                                    RNN_flag=True)


model_GRU_combined, (bce_loss_list, bce_acc_list, bce_overall_val_loss_list) = train_model(model_GRU_combined, second_custom_loss_function, 60, 5, 
                                    RNN_flag=True)

model_GRU_combined = model_GRU_combined.eval()
torch.save(model_GRU_combined, "experiments/model_GRU_combined.pth")
# Out:
# Epoch: 1/60... Step: 5... Loss: 0.721765... Val Loss: 0.694601
# Epoch: 1/60... Step: 10... Loss: 0.724038... Val Loss: 0.689226
# Epoch: 1/60... Step: 15... Loss: 0.683339... Val Loss: 0.685706
# Epoch: 2/60... Step: 20... Loss: 0.740093... Val Loss: 0.684404
# Epoch: 2/60... Step: 25... Loss: 0.708672... Val Loss: 0.682236
# Epoch: 2/60... Step: 30... Loss: 0.671450... Val Loss: 0.680093
# Epoch: 3/60... Step: 35... Loss: 0.666986... Val Loss: 0.679399
# Epoch: 3/60... Step: 40... Loss: 0.674301... Val Loss: 0.678125
# Epoch: 3/60... Step: 45... Loss: 0.681747... Val Loss: 0.676516
# Epoch: 3/60... Step: 50... Loss: 0.715550... Val Loss: 0.673151
# Epoch: 4/60... Step: 55... Loss: 0.683047... Val Loss: 0.669103
# Epoch: 4/60... Step: 60... Loss: 0.667443... Val Loss: 0.665931
# Epoch: 4/60... Step: 65... Loss: 0.656649... Val Loss: 0.663744
# Epoch: 5/60... Step: 70... Loss: 0.669481... Val Loss: 0.661859
# Epoch: 5/60... Step: 75... Loss: 0.667373... Val Loss: 0.659107
# Epoch: 5/60... Step: 80... Loss: 0.640564... Val Loss: 0.655770
# Epoch: 5/60... Step: 85... Loss: 0.676987... Val Loss: 0.652974
# Epoch: 6/60... Step: 90... Loss: 0.639761... Val Loss: 0.648724
# Epoch: 6/60... Step: 95... Loss: 0.630302... Val Loss: 0.648365
# Epoch: 6/60... Step: 100... Loss: 0.639885... Val Loss: 0.638775
# Epoch: 7/60... Step: 105... Loss: 0.626387... Val Loss: 0.636889
# Epoch: 7/60... Step: 110... Loss: 0.671515... Val Loss: 0.634211
# Epoch: 7/60... Step: 115... Loss: 0.631648... Val Loss: 0.629351
# Epoch: 8/60... Step: 120... Loss: 0.681155... Val Loss: 0.623271
# Epoch: 8/60... Step: 125... Loss: 0.625290... Val Loss: 0.616771
# Epoch: 8/60... Step: 130... Loss: 0.627042... Val Loss: 0.613025
# Epoch: 8/60... Step: 135... Loss: 0.606506... Val Loss: 0.609411
# Epoch: 9/60... Step: 140... Loss: 0.592227... Val Loss: 0.602566
# Epoch: 9/60... Step: 145... Loss: 0.584436... Val Loss: 0.597050
# Epoch: 9/60... Step: 150... Loss: 0.585646... Val Loss: 0.601328
# Epoch: 10/60... Step: 155... Loss: 0.606047... Val Loss: 0.585143
# Epoch: 10/60... Step: 160... Loss: 0.593029... Val Loss: 0.583978
# Epoch: 10/60... Step: 165... Loss: 0.615876... Val Loss: 0.576782
# Epoch: 10/60... Step: 170... Loss: 0.558358... Val Loss: 0.575131
# Epoch: 11/60... Step: 175... Loss: 0.614892... Val Loss: 0.571534
# Epoch: 11/60... Step: 180... Loss: 0.537109... Val Loss: 0.570558
# Epoch: 11/60... Step: 185... Loss: 0.604715... Val Loss: 0.563202
# Epoch: 12/60... Step: 190... Loss: 0.582242... Val Loss: 0.561676
# Epoch: 12/60... Step: 195... Loss: 0.587828... Val Loss: 0.561080
# Epoch: 12/60... Step: 200... Loss: 0.595062... Val Loss: 0.554997
# Epoch: 13/60... Step: 205... Loss: 0.531190... Val Loss: 0.550946
# Epoch: 13/60... Step: 210... Loss: 0.545684... Val Loss: 0.554894
# Epoch: 13/60... Step: 215... Loss: 0.546533... Val Loss: 0.569152
# Epoch: 13/60... Step: 220... Loss: 0.510877... Val Loss: 0.551015
# Epoch: 14/60... Step: 225... Loss: 0.510541... Val Loss: 0.563108
# Epoch: 14/60... Step: 230... Loss: 0.497146... Val Loss: 0.561363
# Epoch: 14/60... Step: 235... Loss: 0.466028... Val Loss: 0.542255
# Epoch: 15/60... Step: 240... Loss: 0.589809... Val Loss: 0.548596
# Epoch: 15/60... Step: 245... Loss: 0.541583... Val Loss: 0.550413
# Epoch: 15/60... Step: 250... Loss: 0.590255... Val Loss: 0.552940
# Epoch: 15/60... Step: 255... Loss: 0.538217... Val Loss: 0.569558
# Epoch: 16/60... Step: 260... Loss: 0.557831... Val Loss: 0.538323
# Epoch: 16/60... Step: 265... Loss: 0.549668... Val Loss: 0.536552
# Epoch: 16/60... Step: 270... Loss: 0.523279... Val Loss: 0.534773
# Epoch: 17/60... Step: 275... Loss: 0.512726... Val Loss: 0.536492
# Epoch: 17/60... Step: 280... Loss: 0.520948... Val Loss: 0.538170
# Epoch: 17/60... Step: 285... Loss: 0.445076... Val Loss: 0.540623
# Epoch: 18/60... Step: 290... Loss: 0.585516... Val Loss: 0.545930
# Epoch: 18/60... Step: 295... Loss: 0.547239... Val Loss: 0.542729
# Epoch: 18/60... Step: 300... Loss: 0.463913... Val Loss: 0.540200
# Epoch: 18/60... Step: 305... Loss: 0.473229... Val Loss: 0.534177
# Epoch: 19/60... Step: 310... Loss: 0.503240... Val Loss: 0.537227
# Epoch: 19/60... Step: 315... Loss: 0.559372... Val Loss: 0.545463
# Epoch: 19/60... Step: 320... Loss: 0.491453... Val Loss: 0.556714
# Epoch: 20/60... Step: 325... Loss: 0.499126... Val Loss: 0.550081
# Epoch: 20/60... Step: 330... Loss: 0.520584... Val Loss: 0.532555
# Epoch: 20/60... Step: 335... Loss: 0.517630... Val Loss: 0.535463
# Epoch: 20/60... Step: 340... Loss: 0.542358... Val Loss: 0.537145
# Epoch: 21/60... Step: 345... Loss: 0.448804... Val Loss: 0.535881
# Epoch: 21/60... Step: 350... Loss: 0.474460... Val Loss: 0.534982
# Epoch: 21/60... Step: 355... Loss: 0.542777... Val Loss: 0.540725
# Epoch: 22/60... Step: 360... Loss: 0.520027... Val Loss: 0.538730
# Epoch: 22/60... Step: 365... Loss: 0.442631... Val Loss: 0.537922
# Epoch: 22/60... Step: 370... Loss: 0.562591... Val Loss: 0.537325
# Epoch: 23/60... Step: 375... Loss: 0.512553... Val Loss: 0.534880
# Epoch: 23/60... Step: 380... Loss: 0.519981... Val Loss: 0.547357
# Epoch: 23/60... Step: 385... Loss: 0.516061... Val Loss: 0.544791
# Epoch: 23/60... Step: 390... Loss: 0.541692... Val Loss: 0.531162
# Epoch: 24/60... Step: 395... Loss: 0.573533... Val Loss: 0.542477
# Epoch: 24/60... Step: 400... Loss: 0.496203... Val Loss: 0.533487
# Epoch: 24/60... Step: 405... Loss: 0.469597... Val Loss: 0.530871
# Epoch: 25/60... Step: 410... Loss: 0.475189... Val Loss: 0.534711
# Epoch: 25/60... Step: 415... Loss: 0.477952... Val Loss: 0.532772
# Epoch: 25/60... Step: 420... Loss: 0.600802... Val Loss: 0.532712
# Epoch: 25/60... Step: 425... Loss: 0.506209... Val Loss: 0.528429
# Epoch: 26/60... Step: 430... Loss: 0.506305... Val Loss: 0.527890
# Epoch: 26/60... Step: 435... Loss: 0.491599... Val Loss: 0.529798
# Epoch: 26/60... Step: 440... Loss: 0.561164... Val Loss: 0.532861
# Epoch: 27/60... Step: 445... Loss: 0.536435... Val Loss: 0.535982
# Epoch: 27/60... Step: 450... Loss: 0.542095... Val Loss: 0.542056
# Epoch: 27/60... Step: 455... Loss: 0.427343... Val Loss: 0.528219
# Epoch: 28/60... Step: 460... Loss: 0.484659... Val Loss: 0.530354
# Epoch: 28/60... Step: 465... Loss: 0.450380... Val Loss: 0.535563
# Epoch: 28/60... Step: 470... Loss: 0.534709... Val Loss: 0.535407
# Epoch: 28/60... Step: 475... Loss: 0.516816... Val Loss: 0.538632
# Epoch: 29/60... Step: 480... Loss: 0.499461... Val Loss: 0.534147
# Epoch: 29/60... Step: 485... Loss: 0.476562... Val Loss: 0.529747
# Epoch: 29/60... Step: 490... Loss: 0.517405... Val Loss: 0.535451
# Epoch: 30/60... Step: 495... Loss: 0.479261... Val Loss: 0.532592
# Epoch: 30/60... Step: 500... Loss: 0.519493... Val Loss: 0.525517
# Epoch: 30/60... Step: 505... Loss: 0.573129... Val Loss: 0.527626
# Epoch: 30/60... Step: 510... Loss: 0.533334... Val Loss: 0.529808
# Epoch: 31/60... Step: 515... Loss: 0.482090... Val Loss: 0.526761
# Epoch: 31/60... Step: 520... Loss: 0.418984... Val Loss: 0.528753
# Epoch: 31/60... Step: 525... Loss: 0.435503... Val Loss: 0.526624
# Epoch: 32/60... Step: 530... Loss: 0.506949... Val Loss: 0.536714
# Epoch: 32/60... Step: 535... Loss: 0.449936... Val Loss: 0.533644
# Epoch: 32/60... Step: 540... Loss: 0.451090... Val Loss: 0.527849
# Epoch: 33/60... Step: 545... Loss: 0.460825... Val Loss: 0.548487
# Epoch: 33/60... Step: 550... Loss: 0.554495... Val Loss: 0.540182
# Epoch: 33/60... Step: 555... Loss: 0.517669... Val Loss: 0.528773
# Epoch: 33/60... Step: 560... Loss: 0.525030... Val Loss: 0.533161
# Epoch: 34/60... Step: 565... Loss: 0.410890... Val Loss: 0.523485
# Epoch: 34/60... Step: 570... Loss: 0.490452... Val Loss: 0.522355
# Epoch: 34/60... Step: 575... Loss: 0.533756... Val Loss: 0.523088
# Epoch: 35/60... Step: 580... Loss: 0.457027... Val Loss: 0.525145
# Epoch: 35/60... Step: 585... Loss: 0.495173... Val Loss: 0.526804
# Epoch: 35/60... Step: 590... Loss: 0.472376... Val Loss: 0.524624
# Epoch: 35/60... Step: 595... Loss: 0.475895... Val Loss: 0.523611
# Epoch: 36/60... Step: 600... Loss: 0.569875... Val Loss: 0.526827
# Epoch: 36/60... Step: 605... Loss: 0.487044... Val Loss: 0.528855
# Epoch: 36/60... Step: 610... Loss: 0.433579... Val Loss: 0.527623
# Epoch: 37/60... Step: 615... Loss: 0.482975... Val Loss: 0.525737
# Epoch: 37/60... Step: 620... Loss: 0.510022... Val Loss: 0.522526
# Epoch: 37/60... Step: 625... Loss: 0.521047... Val Loss: 0.522804
# Epoch: 38/60... Step: 630... Loss: 0.461320... Val Loss: 0.528364
# Epoch: 38/60... Step: 635... Loss: 0.538481... Val Loss: 0.526440
# Epoch: 38/60... Step: 640... Loss: 0.557174... Val Loss: 0.528667
# Epoch: 38/60... Step: 645... Loss: 0.434933... Val Loss: 0.536054
# Epoch: 39/60... Step: 650... Loss: 0.440912... Val Loss: 0.528140
# Epoch: 39/60... Step: 655... Loss: 0.463744... Val Loss: 0.530778
# Epoch: 39/60... Step: 660... Loss: 0.525690... Val Loss: 0.528918
# Epoch: 40/60... Step: 665... Loss: 0.441498... Val Loss: 0.526421
# Epoch: 40/60... Step: 670... Loss: 0.421699... Val Loss: 0.529627
# Epoch: 40/60... Step: 675... Loss: 0.461873... Val Loss: 0.533410
# Epoch: 40/60... Step: 680... Loss: 0.471789... Val Loss: 0.547271
# Epoch: 41/60... Step: 685... Loss: 0.454831... Val Loss: 0.535259
# Epoch: 41/60... Step: 690... Loss: 0.396985... Val Loss: 0.535095
# Epoch: 41/60... Step: 695... Loss: 0.500850... Val Loss: 0.535144
# Epoch: 42/60... Step: 700... Loss: 0.474661... Val Loss: 0.531311
# Epoch: 42/60... Step: 705... Loss: 0.489003... Val Loss: 0.534188
# Epoch: 42/60... Step: 710... Loss: 0.575484... Val Loss: 0.529908
# Epoch: 43/60... Step: 715... Loss: 0.461050... Val Loss: 0.530346
# Epoch: 43/60... Step: 720... Loss: 0.525579... Val Loss: 0.530541
# Epoch: 43/60... Step: 725... Loss: 0.454386... Val Loss: 0.537625
# Epoch: 43/60... Step: 730... Loss: 0.456474... Val Loss: 0.532040
# Epoch: 44/60... Step: 735... Loss: 0.457767... Val Loss: 0.532789
# Epoch: 44/60... Step: 740... Loss: 0.428082... Val Loss: 0.534791
# Epoch: 44/60... Step: 745... Loss: 0.513687... Val Loss: 0.534013
# Epoch: 45/60... Step: 750... Loss: 0.396495... Val Loss: 0.533428
# Epoch: 45/60... Step: 755... Loss: 0.469210... Val Loss: 0.532283
# Epoch: 45/60... Step: 760... Loss: 0.428554... Val Loss: 0.528011
# Epoch: 45/60... Step: 765... Loss: 0.484380... Val Loss: 0.527943
# Epoch: 46/60... Step: 770... Loss: 0.626373... Val Loss: 0.535256
# Epoch: 46/60... Step: 775... Loss: 0.524239... Val Loss: 0.528492
# Epoch: 46/60... Step: 780... Loss: 0.519586... Val Loss: 0.530035
# Epoch: 47/60... Step: 785... Loss: 0.496606... Val Loss: 0.541453
# Epoch: 47/60... Step: 790... Loss: 0.461313... Val Loss: 0.533510
# Epoch: 47/60... Step: 795... Loss: 0.492278... Val Loss: 0.534504
# Epoch: 48/60... Step: 800... Loss: 0.457542... Val Loss: 0.532274
# Epoch: 48/60... Step: 805... Loss: 0.515882... Val Loss: 0.536182
# Epoch: 48/60... Step: 810... Loss: 0.477052... Val Loss: 0.534611
# Epoch: 48/60... Step: 815... Loss: 0.464932... Val Loss: 0.534918
# Epoch: 49/60... Step: 820... Loss: 0.425709... Val Loss: 0.531326
# Epoch: 49/60... Step: 825... Loss: 0.509312... Val Loss: 0.529913
# Epoch: 49/60... Step: 830... Loss: 0.459556... Val Loss: 0.540404
# Epoch: 50/60... Step: 835... Loss: 0.410357... Val Loss: 0.531243
# Epoch: 50/60... Step: 840... Loss: 0.601787... Val Loss: 0.534070
# Epoch: 50/60... Step: 845... Loss: 0.492238... Val Loss: 0.534478
# Epoch: 50/60... Step: 850... Loss: 0.461325... Val Loss: 0.537967
# Epoch: 51/60... Step: 855... Loss: 0.496566... Val Loss: 0.527299
# Epoch: 51/60... Step: 860... Loss: 0.414915... Val Loss: 0.528268
# Epoch: 51/60... Step: 865... Loss: 0.468330... Val Loss: 0.536714
# Epoch: 52/60... Step: 870... Loss: 0.450492... Val Loss: 0.530970
# Epoch: 52/60... Step: 875... Loss: 0.578929... Val Loss: 0.534534
# Epoch: 52/60... Step: 880... Loss: 0.421542... Val Loss: 0.534341
# Epoch: 53/60... Step: 885... Loss: 0.467506... Val Loss: 0.531390
# Epoch: 53/60... Step: 890... Loss: 0.557320... Val Loss: 0.556646
# Epoch: 53/60... Step: 895... Loss: 0.416487... Val Loss: 0.531063
# Epoch: 53/60... Step: 900... Loss: 0.530404... Val Loss: 0.536535
# Epoch: 54/60... Step: 905... Loss: 0.512403... Val Loss: 0.531622
# Epoch: 54/60... Step: 910... Loss: 0.493218... Val Loss: 0.540891
# Epoch: 54/60... Step: 915... Loss: 0.440210... Val Loss: 0.532981
# Epoch: 55/60... Step: 920... Loss: 0.535646... Val Loss: 0.531602
# Epoch: 55/60... Step: 925... Loss: 0.384694... Val Loss: 0.532611
# Epoch: 55/60... Step: 930... Loss: 0.497732... Val Loss: 0.528509
# Epoch: 55/60... Step: 935... Loss: 0.417311... Val Loss: 0.530731
# Epoch: 56/60... Step: 940... Loss: 0.606399... Val Loss: 0.533649
# Epoch: 56/60... Step: 945... Loss: 0.377155... Val Loss: 0.536831
# Epoch: 56/60... Step: 950... Loss: 0.543849... Val Loss: 0.534629
# Epoch: 57/60... Step: 955... Loss: 0.423221... Val Loss: 0.532037
# Epoch: 57/60... Step: 960... Loss: 0.510710... Val Loss: 0.530524
# Epoch: 57/60... Step: 965... Loss: 0.493762... Val Loss: 0.541635
# Epoch: 58/60... Step: 970... Loss: 0.398221... Val Loss: 0.533458
# Epoch: 58/60... Step: 975... Loss: 0.461131... Val Loss: 0.531857
# Epoch: 58/60... Step: 980... Loss: 0.525554... Val Loss: 0.532295
# Epoch: 58/60... Step: 985... Loss: 0.393493... Val Loss: 0.535016
# Epoch: 59/60... Step: 990... Loss: 0.434774... Val Loss: 0.537597
# Epoch: 59/60... Step: 995... Loss: 0.405410... Val Loss: 0.532088
# Epoch: 59/60... Step: 1000... Loss: 0.438795... Val Loss: 0.535337
# Epoch: 60/60... Step: 1005... Loss: 0.485604... Val Loss: 0.534172
# Epoch: 60/60... Step: 1010... Loss: 0.529297... Val Loss: 0.535100
# Epoch: 60/60... Step: 1015... Loss: 0.482507... Val Loss: 0.531095
# Epoch: 60/60... Step: 1020... Loss: 0.359707... Val Loss: 0.531742
# Epoch: 1/60... Step: 5... Loss: -0.786378... Val Loss: -0.485685
# Epoch: 1/60... Step: 10... Loss: -0.783481... Val Loss: -0.495490
# Epoch: 1/60... Step: 15... Loss: -0.355951... Val Loss: -0.555607
# Epoch: 2/60... Step: 20... Loss: -0.461357... Val Loss: -0.564544
# Epoch: 2/60... Step: 25... Loss: -0.766525... Val Loss: -0.642985
# Epoch: 2/60... Step: 30... Loss: -0.471974... Val Loss: -0.617239
# Epoch: 3/60... Step: 35... Loss: -0.967314... Val Loss: -0.747133
# Epoch: 3/60... Step: 40... Loss: -0.527114... Val Loss: -0.660214
# Epoch: 3/60... Step: 45... Loss: -1.041997... Val Loss: -0.717186
# Epoch: 3/60... Step: 50... Loss: -0.713075... Val Loss: -0.794302
# Epoch: 4/60... Step: 55... Loss: -0.154880... Val Loss: -0.723919
# Epoch: 4/60... Step: 60... Loss: -1.018329... Val Loss: -0.611878
# Epoch: 4/60... Step: 65... Loss: -1.084282... Val Loss: -0.735164
# Epoch: 5/60... Step: 70... Loss: -0.203213... Val Loss: -0.770197
# Epoch: 5/60... Step: 75... Loss: -1.225339... Val Loss: -0.753332
# Epoch: 5/60... Step: 80... Loss: -1.055904... Val Loss: -0.651160
# Epoch: 5/60... Step: 85... Loss: -0.756585... Val Loss: -0.657793
# Epoch: 6/60... Step: 90... Loss: -0.838408... Val Loss: -0.835113
# Epoch: 6/60... Step: 95... Loss: -0.917146... Val Loss: -0.696851
# Epoch: 6/60... Step: 100... Loss: -1.058355... Val Loss: -0.822293
# Epoch: 7/60... Step: 105... Loss: -0.702564... Val Loss: -0.866284
# Epoch: 7/60... Step: 110... Loss: -0.684175... Val Loss: -0.823500
# Epoch: 7/60... Step: 115... Loss: -1.032742... Val Loss: -0.877937
# Epoch: 8/60... Step: 120... Loss: -0.915757... Val Loss: -0.841465
# Epoch: 8/60... Step: 125... Loss: -1.284070... Val Loss: -0.968512
# Epoch: 8/60... Step: 130... Loss: -0.754404... Val Loss: -0.748894
# Epoch: 8/60... Step: 135... Loss: -0.644294... Val Loss: -0.859761
# Epoch: 9/60... Step: 140... Loss: -1.026450... Val Loss: -0.889612
# Epoch: 9/60... Step: 145... Loss: -1.288487... Val Loss: -0.737233
# Epoch: 9/60... Step: 150... Loss: -1.061717... Val Loss: -1.172059
# Epoch: 10/60... Step: 155... Loss: -0.794867... Val Loss: -0.849330
# Epoch: 10/60... Step: 160... Loss: -0.740267... Val Loss: -1.015622
# Epoch: 10/60... Step: 165... Loss: -1.477348... Val Loss: -0.924643
# Epoch: 10/60... Step: 170... Loss: -0.776063... Val Loss: -1.007522
# Epoch: 11/60... Step: 175... Loss: -1.359435... Val Loss: -1.025519
# Epoch: 11/60... Step: 180... Loss: -0.711921... Val Loss: -0.808605
# Epoch: 11/60... Step: 185... Loss: -0.610570... Val Loss: -0.962002
# Epoch: 12/60... Step: 190... Loss: -0.478272... Val Loss: -1.006410
# Epoch: 12/60... Step: 195... Loss: -0.810795... Val Loss: -1.015900
# Epoch: 12/60... Step: 200... Loss: -1.763862... Val Loss: -1.209655
# Epoch: 13/60... Step: 205... Loss: -1.042134... Val Loss: -0.844607
# Epoch: 13/60... Step: 210... Loss: -0.671698... Val Loss: -0.839200
# Epoch: 13/60... Step: 215... Loss: -1.363445... Val Loss: -1.093958
# Epoch: 13/60... Step: 220... Loss: -0.287149... Val Loss: -0.769347
# Epoch: 14/60... Step: 225... Loss: -0.488342... Val Loss: -0.934912
# Epoch: 14/60... Step: 230... Loss: -0.950767... Val Loss: -0.751008
# Epoch: 14/60... Step: 235... Loss: -0.916897... Val Loss: -0.783235
# Epoch: 15/60... Step: 240... Loss: -1.012142... Val Loss: -1.015947
# Epoch: 15/60... Step: 245... Loss: -1.209298... Val Loss: -1.230953
# Epoch: 15/60... Step: 250... Loss: -0.657227... Val Loss: -1.030052
# Epoch: 15/60... Step: 255... Loss: -1.430649... Val Loss: -0.936718
# Epoch: 16/60... Step: 260... Loss: -1.298984... Val Loss: -0.962391
# Epoch: 16/60... Step: 265... Loss: -1.161953... Val Loss: -0.964117
# Epoch: 16/60... Step: 270... Loss: -0.885339... Val Loss: -1.001577
# Epoch: 17/60... Step: 275... Loss: -0.928313... Val Loss: -0.817806
# Epoch: 17/60... Step: 280... Loss: -1.258981... Val Loss: -0.752573
# Epoch: 17/60... Step: 285... Loss: -1.098783... Val Loss: -1.074650
# Epoch: 18/60... Step: 290... Loss: -1.373781... Val Loss: -1.292530
# Epoch: 18/60... Step: 295... Loss: -0.502028... Val Loss: -0.976400
# Epoch: 18/60... Step: 300... Loss: -1.593515... Val Loss: -1.012267
# Epoch: 18/60... Step: 305... Loss: -1.149336... Val Loss: -1.127778
# Epoch: 19/60... Step: 310... Loss: -1.088228... Val Loss: -1.126429
# Epoch: 19/60... Step: 315... Loss: -1.104303... Val Loss: -0.844652
# Epoch: 19/60... Step: 320... Loss: -0.932840... Val Loss: -1.097907
# Epoch: 20/60... Step: 325... Loss: -0.952286... Val Loss: -0.803275
# Epoch: 20/60... Step: 330... Loss: -1.605121... Val Loss: -1.219964
# Epoch: 20/60... Step: 335... Loss: -0.931096... Val Loss: -1.135601
# Epoch: 20/60... Step: 340... Loss: -1.510677... Val Loss: -1.017288
# Epoch: 21/60... Step: 345... Loss: -0.730963... Val Loss: -1.169592
# Epoch: 21/60... Step: 350... Loss: -1.682532... Val Loss: -1.012779
# Epoch: 21/60... Step: 355... Loss: -1.187615... Val Loss: -1.087413
# Epoch: 22/60... Step: 360... Loss: -1.411320... Val Loss: -1.061508
# Epoch: 22/60... Step: 365... Loss: -1.063325... Val Loss: -1.033769
# Epoch: 22/60... Step: 370... Loss: -0.405621... Val Loss: -1.022300
# Epoch: 23/60... Step: 375... Loss: -1.027004... Val Loss: -0.968179
# Epoch: 23/60... Step: 380... Loss: -1.282802... Val Loss: -0.828449
# Epoch: 23/60... Step: 385... Loss: -1.014044... Val Loss: -1.249549
# Epoch: 23/60... Step: 390... Loss: -0.699693... Val Loss: -1.315249
# Epoch: 24/60... Step: 395... Loss: -1.633682... Val Loss: -1.250949
# Epoch: 24/60... Step: 400... Loss: -1.536515... Val Loss: -1.151100
# Epoch: 24/60... Step: 405... Loss: -0.681624... Val Loss: -1.077165
# Epoch: 25/60... Step: 410... Loss: -2.111238... Val Loss: -0.740009
# Epoch: 25/60... Step: 415... Loss: -0.879290... Val Loss: -1.141601
# Epoch: 25/60... Step: 420... Loss: -1.586825... Val Loss: -0.893258
# Epoch: 25/60... Step: 425... Loss: -1.215515... Val Loss: -1.098678
# Epoch: 26/60... Step: 430... Loss: -1.019335... Val Loss: -1.010324
# Epoch: 26/60... Step: 435... Loss: -0.763061... Val Loss: -1.061570
# Epoch: 26/60... Step: 440... Loss: -0.756126... Val Loss: -1.325696
# Epoch: 27/60... Step: 445... Loss: -1.128427... Val Loss: -1.023302
# Epoch: 27/60... Step: 450... Loss: -0.844008... Val Loss: -1.124868
# Epoch: 27/60... Step: 455... Loss: -1.006655... Val Loss: -0.819668
# Epoch: 28/60... Step: 460... Loss: -1.041592... Val Loss: -1.007442
# Epoch: 28/60... Step: 465... Loss: -1.201757... Val Loss: -0.759646
# Epoch: 28/60... Step: 470... Loss: -0.976822... Val Loss: -0.978285
# Epoch: 28/60... Step: 475... Loss: -1.478904... Val Loss: -0.928510
# Epoch: 29/60... Step: 480... Loss: -1.705626... Val Loss: -1.025253
# Epoch: 29/60... Step: 485... Loss: -0.861829... Val Loss: -0.988403
# Epoch: 29/60... Step: 490... Loss: -1.816781... Val Loss: -1.180286
# Epoch: 30/60... Step: 495... Loss: -1.550808... Val Loss: -1.070701
# Epoch: 30/60... Step: 500... Loss: -1.329397... Val Loss: -1.070629
# Epoch: 30/60... Step: 505... Loss: -0.560121... Val Loss: -1.269986
# Epoch: 30/60... Step: 510... Loss: -1.443073... Val Loss: -1.250938
# Epoch: 31/60... Step: 515... Loss: -1.849161... Val Loss: -1.181172
# Epoch: 31/60... Step: 520... Loss: -0.649258... Val Loss: -0.917677
# Epoch: 31/60... Step: 525... Loss: -0.986782... Val Loss: -1.363499
# Epoch: 32/60... Step: 530... Loss: -1.399102... Val Loss: -1.282818
# Epoch: 32/60... Step: 535... Loss: -0.724915... Val Loss: -1.024509
# Epoch: 32/60... Step: 540... Loss: -1.283162... Val Loss: -1.109676
# Epoch: 33/60... Step: 545... Loss: -0.975994... Val Loss: -1.158997
# Epoch: 33/60... Step: 550... Loss: -1.118784... Val Loss: -1.195891
# Epoch: 33/60... Step: 555... Loss: -0.848762... Val Loss: -0.808569
# Epoch: 33/60... Step: 560... Loss: -1.428627... Val Loss: -1.088635
# Epoch: 34/60... Step: 565... Loss: -1.058627... Val Loss: -1.150578
# Epoch: 34/60... Step: 570... Loss: -0.926577... Val Loss: -1.150925
# Epoch: 34/60... Step: 575... Loss: -1.241015... Val Loss: -1.217216
# Epoch: 35/60... Step: 580... Loss: -1.148156... Val Loss: -0.713951
# Epoch: 35/60... Step: 585... Loss: -1.342971... Val Loss: -1.096279
# Epoch: 35/60... Step: 590... Loss: -0.723779... Val Loss: -1.040628
# Epoch: 35/60... Step: 595... Loss: -1.021625... Val Loss: -1.161567
# Epoch: 36/60... Step: 600... Loss: -1.077387... Val Loss: -1.409381
# Epoch: 36/60... Step: 605... Loss: -1.193296... Val Loss: -1.378739
# Epoch: 36/60... Step: 610... Loss: -1.110202... Val Loss: -1.100758
# Epoch: 37/60... Step: 615... Loss: -0.609703... Val Loss: -1.270209
# Epoch: 37/60... Step: 620... Loss: -0.877566... Val Loss: -1.022539
# Epoch: 37/60... Step: 625... Loss: -0.555396... Val Loss: -1.294593
# Epoch: 38/60... Step: 630... Loss: -0.875283... Val Loss: -1.057968
# Epoch: 38/60... Step: 635... Loss: -1.271559... Val Loss: -1.168304
# Epoch: 38/60... Step: 640... Loss: -1.936207... Val Loss: -1.222912
# Epoch: 38/60... Step: 645... Loss: -1.287070... Val Loss: -1.065727
# Epoch: 39/60... Step: 650... Loss: -1.862661... Val Loss: -0.967552
# Epoch: 39/60... Step: 655... Loss: -1.832225... Val Loss: -1.020422
# Epoch: 39/60... Step: 660... Loss: -1.172082... Val Loss: -0.892052
# Epoch: 40/60... Step: 665... Loss: -1.222327... Val Loss: -0.904312
# Epoch: 40/60... Step: 670... Loss: -1.140848... Val Loss: -1.056762
# Epoch: 40/60... Step: 675... Loss: -1.039095... Val Loss: -1.106717
# Epoch: 40/60... Step: 680... Loss: -0.867005... Val Loss: -1.192819
# Epoch: 41/60... Step: 685... Loss: -1.631346... Val Loss: -1.027186
# Epoch: 41/60... Step: 690... Loss: -0.709308... Val Loss: -0.910746
# Epoch: 41/60... Step: 695... Loss: -0.725013... Val Loss: -1.330866
# Epoch: 42/60... Step: 700... Loss: -1.195700... Val Loss: -1.084624
# Epoch: 42/60... Step: 705... Loss: -0.908422... Val Loss: -1.035864
# Epoch: 42/60... Step: 710... Loss: -1.073829... Val Loss: -1.162163
# Epoch: 43/60... Step: 715... Loss: -0.367183... Val Loss: -1.155629
# Epoch: 43/60... Step: 720... Loss: -1.478731... Val Loss: -1.045218
# Epoch: 43/60... Step: 725... Loss: -0.790921... Val Loss: -1.285359
# Epoch: 43/60... Step: 730... Loss: -1.032661... Val Loss: -0.975509
# Epoch: 44/60... Step: 735... Loss: -1.550543... Val Loss: -1.069887
# Epoch: 44/60... Step: 740... Loss: -0.910846... Val Loss: -1.116076
# Epoch: 44/60... Step: 745... Loss: -0.965958... Val Loss: -1.386250
# Epoch: 45/60... Step: 750... Loss: -0.957769... Val Loss: -1.033052
# Epoch: 45/60... Step: 755... Loss: -0.538802... Val Loss: -1.155832
# Epoch: 45/60... Step: 760... Loss: -1.812190... Val Loss: -1.100333
# Epoch: 45/60... Step: 765... Loss: -1.187845... Val Loss: -1.108655
# Epoch: 46/60... Step: 770... Loss: -1.334604... Val Loss: -0.958443
# Epoch: 46/60... Step: 775... Loss: -1.345502... Val Loss: -0.838072
# Epoch: 46/60... Step: 780... Loss: -1.356992... Val Loss: -1.113682
# Epoch: 47/60... Step: 785... Loss: -0.794206... Val Loss: -1.119194
# Epoch: 47/60... Step: 790... Loss: -1.232479... Val Loss: -1.415205
# Epoch: 47/60... Step: 795... Loss: -1.630875... Val Loss: -1.068185
# Epoch: 48/60... Step: 800... Loss: -1.102255... Val Loss: -1.193771
# Epoch: 48/60... Step: 805... Loss: -0.719600... Val Loss: -1.552374
# Epoch: 48/60... Step: 810... Loss: -0.930103... Val Loss: -1.289342
# Epoch: 48/60... Step: 815... Loss: -1.439013... Val Loss: -0.862679
# Epoch: 49/60... Step: 820... Loss: -1.580480... Val Loss: -0.913149
# Epoch: 49/60... Step: 825... Loss: -1.134389... Val Loss: -0.982588
# Epoch: 49/60... Step: 830... Loss: -1.745136... Val Loss: -1.032208
# Epoch: 50/60... Step: 835... Loss: -1.043357... Val Loss: -1.005170
# Epoch: 50/60... Step: 840... Loss: -0.092225... Val Loss: -1.118759
# Epoch: 50/60... Step: 845... Loss: -1.752324... Val Loss: -0.881346
# Epoch: 50/60... Step: 850... Loss: -0.468264... Val Loss: -0.992894
# Epoch: 51/60... Step: 855... Loss: -1.022787... Val Loss: -0.853644
# Epoch: 51/60... Step: 860... Loss: -1.447273... Val Loss: -0.872228
# Epoch: 51/60... Step: 865... Loss: -0.625484... Val Loss: -1.012352
# Epoch: 52/60... Step: 870... Loss: -0.866117... Val Loss: -0.871247
# Epoch: 52/60... Step: 875... Loss: -0.784093... Val Loss: -0.984813
# Epoch: 52/60... Step: 880... Loss: -1.439879... Val Loss: -1.014752
# Epoch: 53/60... Step: 885... Loss: -1.977766... Val Loss: -1.054573
# Epoch: 53/60... Step: 890... Loss: -1.269587... Val Loss: -0.699185
# Epoch: 53/60... Step: 895... Loss: -1.439893... Val Loss: -1.157660
# Epoch: 53/60... Step: 900... Loss: -0.465010... Val Loss: -1.041793
# Epoch: 54/60... Step: 905... Loss: -1.456559... Val Loss: -1.079397
# Epoch: 54/60... Step: 910... Loss: -0.785926... Val Loss: -1.170100
# Epoch: 54/60... Step: 915... Loss: -0.653647... Val Loss: -1.218042
# Epoch: 55/60... Step: 920... Loss: -1.632893... Val Loss: -0.778154
# Epoch: 55/60... Step: 925... Loss: -0.805140... Val Loss: -1.249914
# Epoch: 55/60... Step: 930... Loss: -0.925469... Val Loss: -1.130278
# Epoch: 55/60... Step: 935... Loss: -0.406654... Val Loss: -1.240394
# Epoch: 56/60... Step: 940... Loss: -1.158499... Val Loss: -1.263225
# Epoch: 56/60... Step: 945... Loss: -1.603497... Val Loss: -1.240733
# Epoch: 56/60... Step: 950... Loss: -1.409356... Val Loss: -1.012400
# Epoch: 57/60... Step: 955... Loss: -1.376591... Val Loss: -1.284166
# Epoch: 57/60... Step: 960... Loss: -1.211271... Val Loss: -1.029746
# Epoch: 57/60... Step: 965... Loss: -0.818993... Val Loss: -1.174216
# Epoch: 58/60... Step: 970... Loss: -1.098920... Val Loss: -1.286843
# Epoch: 58/60... Step: 975... Loss: -1.540503... Val Loss: -0.950879
# Epoch: 58/60... Step: 980... Loss: -0.863051... Val Loss: -1.098603
# Epoch: 58/60... Step: 985... Loss: -1.138099... Val Loss: -0.770587
# Epoch: 59/60... Step: 990... Loss: -1.107139... Val Loss: -1.017747
# Epoch: 59/60... Step: 995... Loss: -0.629966... Val Loss: -0.834313
# Epoch: 59/60... Step: 1000... Loss: -0.484289... Val Loss: -1.100789
# Epoch: 60/60... Step: 1005... Loss: -1.870901... Val Loss: -1.037029
# Epoch: 60/60... Step: 1010... Loss: -1.706996... Val Loss: -1.178551
# Epoch: 60/60... Step: 1015... Loss: -0.601689... Val Loss: -1.262074
# Epoch: 60/60... Step: 1020... Loss: -1.462888... Val Loss: -0.992153

# %% [markdown]
# # Calculate metrics for different models

# %%
def evaluate_metrics(y_true, y_pred, threshold=0.5):
    """
    Evaluate metrics for change point detection
    We assume, that there is no more than one change index in data (so, either 0 or 1 change)
    Inputs
    y_true : torch.Tensor
      true labels
    y_pred : torch.Tensor
      change probabiltiy
    threshold : float
      detection threshold
      
    Returns
    false_positive : int
      number of false positives
    false_negative : int
      number of false negatives
    delay : int
      detection delay
    accuracy : float
      y_pred accuracy given y_truei
    """
    delay = 0
    false_positive = 0
    false_negative = 0
    true_negative = 0

    index_real = torch.where(y_true != y_true[0])[0] # indexes with real changes
    index_detected = torch.where((y_pred > threshold).long() != y_true[0])[0] # indexes with predicted changes

    if len(index_real) > 0:
        real_change_index = index_real[0]

        if len(index_detected) > 0:
            index_sub_detected = torch.where(index_detected >= real_change_index)[0]

            if len(index_sub_detected) == len(index_detected):
                false_positive_delay = real_change_index.item()
                detected_change_index = index_detected[0]
                delay = (detected_change_index - real_change_index).item()
            else:
                false_positive_delay = index_detected[0].item()
                delay = 0
                false_positive += 1
                
        else:
            false_positive_delay = seq_len
            delay = (seq_len - real_change_index).item()
            false_negative += 1

    else:
        if len(index_detected) > 0:
            false_positive_delay = index_detected[0].item()
            false_positive += 1
        else:
            false_positive_delay = seq_len
            true_negative += 1
    
    accuracy = ((y_pred > threshold).long() == y_true).float().mean().item()
    
    return false_positive, false_negative, delay, false_positive_delay, accuracy

# %%
test_batch_size = 16

# %%
def get_quality_metrics(test_loader, model, threshold=0.5, LSTM_flag=False, RNN_flag=False):
    test_loss_list = []
    test_acc_list = []

    positive_number = 0 
    negative_number = 0
    fp_list = []
    fn_list = []
    delay_list = []
    fp_delay_list = []
    accuracy_list = []

    model.eval()
    for test_inputs, test_true_labels in test_loader:
            
        test_inputs, test_true_labels = test_inputs.to(device), test_true_labels.to(device)
        
        if LSTM_flag:
            test_hidden = model.init_hidden(test_batch_size)
            test_hidden = tuple([each.data for each in test_hidden])
            #test_hidden = torch.zeros(1, len(test_inputs), hidden_dim).to(device)
            #test_hidden = tuple([test_hidden, test_hidden])
            test_predictions, test_hidden = model(test_inputs, test_hidden)
        elif RNN_flag:
            test_hidden = torch.zeros(2, len(test_inputs), hidden_dim).to(device)
            test_predictions, test_hidden = model(test_inputs, test_hidden)            
        else:
            test_predictions = model(test_inputs)
            
        test_loss = loss_function(test_predictions.squeeze(), test_true_labels.float())
        test_loss_list += [test_loss.cpu().clone().detach()]

        for i in range(0, test_batch_size):
            curr_labels = test_true_labels[i]
            curr_predictions = test_predictions[i]
            
            # torch.rand_like
            curr_fp, curr_fn, curr_delay, curr_fp_delay, curr_accuracy = evaluate_metrics(curr_labels, curr_predictions, 
                                                                           threshold)

            max_difference = np.abs((curr_labels.max() - curr_labels.min()).item())
            if max_difference: 
                delay_list.append(curr_delay)
            positive_number += (max_difference > 0)
            negative_number += 1 - (max_difference > 0)

            fp_list.append(curr_fp)
            fn_list.append(curr_fn)
            fp_delay_list.append(curr_fp_delay)
            accuracy_list.append(curr_accuracy)

        test_acc_list.append(np.mean(accuracy_list[-test_batch_size:]))
        
    return (positive_number, negative_number, np.mean(test_loss_list), np.mean(test_acc_list), np.mean(delay_list),
            np.mean(fp_delay_list), np.sum(fp_list), np.sum(fn_list))

# %%
def get_pareto_metrics_for_threshold(model, test_loader, threshold_list, LSTM_flag=False, RNN_flag=False):
    fp_number_list = []
    fn_number_list = []
    delay_list = []
    fp_delay_list = []
    for threshold in threshold_list:
        # test_loader = prepare_loader(test_data, test_labels, seq_len, input_size, batch_size)

        (positive_number, negative_number, test_loss, 
         test_acc, mean_delay, mean_fp_delay, fp_number, fn_number) = get_quality_metrics(test_loader, model, threshold, LSTM_flag, RNN_flag)

        fp_number_list.append(fp_number)
        fn_number_list.append(fn_number)
        delay_list.append(mean_delay)
        fp_delay_list.append(mean_fp_delay)
        #print(threshold, fp_number, fn_number, mean_delay, mean_fp_delay)
    
    return fp_number_list, fn_number_list, delay_list, fp_delay_list

# %%
threshold_number = 100
threshold_list = np.linspace(-15, 15, threshold_number)
threshold_list = 1 / (1 + np.exp(-threshold_list))
#threshold_list = np.append([-0.01], threshold_list)
#threshold_list = np.append(threshold_list, [1.01])
plt.plot(np.linspace(0.01, 1, threshold_number), threshold_list)

# %% [markdown]
# ### Evaluate LSTM

# %%
model_LSTM_bce = torch.load("experiments/model_LSTM_bce.pth")
model_LSTM_custom = torch.load("experiments/model_LSTM_custom.pth")
model_LSTM_combined = torch.load("experiments/model_LSTM_combined.pth")

# %%
test_batch_size = 4
loss_function = torch.nn.BCELoss()
final_test_loader = prepare_loader(test_data, test_labels, seq_len, input_size, test_batch_size, shuffle=False)

(fp_number_list_LSTM_bce, fn_number_list_LSTM_bce, 
 delay_list_LSTM_bce, fp_delay_list_LSTM_bce) = get_pareto_metrics_for_threshold(model_LSTM_bce, final_test_loader, 
                                                                                 threshold_list, LSTM_flag=True)

# %%
test_batch_size = 4
final_test_loader = prepare_loader(test_data, test_labels, seq_len, input_size, test_batch_size, shuffle=False)

(fp_number_list_LSTM_custom, fn_number_list_LSTM_custom, 
 delay_list_LSTM_custom, fp_delay_list_LSTM_custom) = get_pareto_metrics_for_threshold(model_LSTM_custom, final_test_loader, 
                                                                                       threshold_list, LSTM_flag=True)

# %%
test_batch_size = 4
final_test_loader = prepare_loader(test_data, test_labels, seq_len, input_size, test_batch_size, shuffle=False)

(fp_number_list_LSTM_combined, fn_number_list_LSTM_combined, delay_list_LSTM_combined, fp_delay_list_LSTM_combined) = get_pareto_metrics_for_threshold(model_LSTM_combined, final_test_loader, threshold_list, LSTM_flag=True)

# %%
plt.figure(figsize=(12, 12))
plt.plot(fp_delay_list_LSTM_custom, delay_list_LSTM_custom, '-o', label='LSTM. CustomLoss model')
plt.plot(np.array(fp_delay_list_LSTM_bce), np.array(delay_list_LSTM_bce), '-d', label='LSTM.BCELoss model')
plt.plot(fp_delay_list_LSTM_combined, delay_list_LSTM_combined, '-s', label='LSTM. Combined model')

plt.xlabel('Mean FP delay')
plt.ylabel('Mean delay')
plt.title('LSTM')
#plt.yscale('log')
plt.legend(loc='upper left', fontsize=14);

# %% [markdown]
# ### Evaluate RNN

# %%
model_RNN_bce = torch.load("experiments/model_RNN_bce.pth")
model_RNN_custom = torch.load("experiments/model_RNN_custom.pth")
model_RNN_combined = torch.load("experiments/model_RNN_combined.pth")

# %%
test_batch_size = 4
final_test_loader = prepare_loader(test_data, test_labels, seq_len, input_size, test_batch_size, shuffle=False)

(fp_number_list_RNN_bce, fn_number_list_RNN_bce, 
 delay_list_RNN_bce, fp_delay_list_RNN_bce) = get_pareto_metrics_for_threshold(model_RNN_bce, final_test_loader, 
                                                                                 threshold_list, RNN_flag=True)

# %%
test_batch_size = 4
final_test_loader = prepare_loader(test_data, test_labels, seq_len, input_size, test_batch_size, shuffle=False)

(fp_number_list_RNN_custom, fn_number_list_RNN_custom, 
 delay_list_RNN_custom, fp_delay_list_RNN_custom) = get_pareto_metrics_for_threshold(model_RNN_custom, final_test_loader, 
                                                                                       threshold_list, RNN_flag=True)

# %%
test_batch_size = 4
final_test_loader = prepare_loader(test_data, test_labels, seq_len, input_size, test_batch_size, shuffle=False)

(fp_number_list_RNN_combined, fn_number_list_RNN_combined, delay_list_RNN_combined, fp_delay_list_RNN_combined) = get_pareto_metrics_for_threshold(model_RNN_combined, final_test_loader, threshold_list, RNN_flag=True)

# %%
plt.figure(figsize=(12, 12))
plt.plot(fp_delay_list_RNN_custom, delay_list_RNN_custom, '-o', label='RNN. CustomLoss model')
plt.plot(fp_delay_list_RNN_bce, delay_list_RNN_bce, '-d', label='RNN.BCELoss model')
plt.plot(fp_delay_list_RNN_combined, delay_list_RNN_combined, '-s', label='RNN. Combined model')

plt.xlabel('Mean FP delay')
plt.ylabel('Mean delay')
plt.title('RNN')
#plt.yscale('log')
plt.legend(loc='upper left', fontsize=14);

# %% [markdown]
# ### Evaluate GRU

# %%
model_GRU_bce = torch.load("experiments/model_GRU_bce.pth")
model_GRU_custom = torch.load("experiments/model_GRU_custom.pth")
model_GRU_combined = torch.load("experiments/model_GRU_combined.pth")

# %%
test_batch_size = 4
final_test_loader = prepare_loader(test_data, test_labels, seq_len, input_size, test_batch_size, shuffle=False)

(fp_number_list_GRU_bce, fn_number_list_GRU_bce, 
 delay_list_GRU_bce, fp_delay_list_GRU_bce) = get_pareto_metrics_for_threshold(model_GRU_bce, final_test_loader, 
                                                                                 threshold_list, RNN_flag=True)

# %%
test_batch_size = 4
final_test_loader = prepare_loader(test_data, test_labels, seq_len, input_size, test_batch_size, shuffle=False)

(fp_number_list_GRU_custom, fn_number_list_GRU_custom, 
 delay_list_GRU_custom, fp_delay_list_GRU_custom) = get_pareto_metrics_for_threshold(model_GRU_custom, final_test_loader, 
                                                                                       threshold_list, RNN_flag=True)

# %%
test_batch_size = 4
final_test_loader = prepare_loader(test_data, test_labels, seq_len, input_size, test_batch_size, shuffle=False)

(fp_number_list_GRU_combined, fn_number_list_GRU_combined, delay_list_GRU_combined, fp_delay_list_GRU_combined) = get_pareto_metrics_for_threshold(model_GRU_combined, final_test_loader, threshold_list, RNN_flag=True)

# %%
plt.figure(figsize=(12, 12))
plt.plot(fp_delay_list_GRU_custom, delay_list_GRU_custom, '-o', label='GRU. CustomLoss model')
plt.plot(fp_delay_list_GRU_bce, delay_list_GRU_bce, '-d', label='GRU.BCELoss model')
plt.plot(fp_delay_list_GRU_combined, delay_list_GRU_combined, '-s', label='GRU. Combined model')

plt.xlabel('Mean FP delay')
plt.ylabel('Mean delay')
plt.title('GRU')
#plt.yscale('log')
plt.legend(loc='upper left', fontsize=14);
